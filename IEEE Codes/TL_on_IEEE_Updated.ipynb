# %%
from keras.preprocessing.image import ImageDataGenerator
from tensorflow import keras
# Out:
# D:\Anaconda\envs\tf-gpu\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import tensorflow as tf
from keras.layers import Activation
from keras.utils.generic_utils import get_custom_objects
from keras import backend as K
from keras.layers import Conv2D, Lambda, MaxPooling2D, BatchNormalization, concatenate, GlobalAveragePooling2D, Dense
from keras.models import Model
from tensorflow.keras.optimizers import SGD
import matplotlib.pyplot as plt 
import time

# %%
from keras.preprocessing.image import ImageDataGenerator
train_dataset = ImageDataGenerator(rescale=1./255)
test_dataset = ImageDataGenerator(rescale=1./255)
validation_dataset = ImageDataGenerator(rescale=1./255)

batchsize = 10
train_generator=train_dataset.flow_from_directory('ieee/updated_train/', 
                                                  target_size=(224, 224), 
                                                  batch_size=batchsize, 
                                                  class_mode='categorical')
 
validation_generator = validation_dataset.flow_from_directory('ieee/updated_val/',
        target_size=(224, 224),
        batch_size=batchsize,
        class_mode='categorical',
        shuffle=False)
test_generator = test_dataset.flow_from_directory('ieee/updated_test/',
       target_size=(224, 224),
       batch_size=batchsize,
       class_mode='categorical',
       shuffle=False)
# Out:
# Found 784 images belonging to 2 classes.
# Found 448 images belonging to 2 classes.
# Found 171 images belonging to 2 classes.

# %% [markdown]
# # Model Creation
# VGG Net: VGG network has simplest structure with 3 x 3 filter in each convolutional layer. There are two variant available VGG-16 and VGG1-9. In the image above VGG network is presneted.
# Transfer Learning: The VGGNet pre-trained on ImageNet and Inception module for transfer learning, and trained the newly formed neural networks using new datasets. The approach combines the advantages of the VGGNet and Inception module.

# %%
#DENSENET121
base_model1=keras.applications.DenseNet121(
    include_top=True, weights="imagenet", input_tensor=None, 
    input_shape=None, pooling=None,classes=1000,
    #classifier_activation='softmax'
)

#DenseNet169
base_model2=keras.applications.DenseNet169(
    include_top=True, weights="imagenet", input_tensor=None, 
    input_shape=None, pooling=None,classes=1000,
    #classifier_activation='softmax'
)


#VGG19
base_model3=keras.applications.vgg19.VGG19(
    include_top=True, weights='imagenet', input_tensor=None,
    input_shape=None, pooling=None, classes=1000,
    classifier_activation='softmax'
)

#MobileNet
base_model4=tf.keras.applications.MobileNetV2(
    include_top=True, weights='imagenet', input_tensor=None,
    input_shape=None, pooling=None, classes=1000,
    classifier_activation='softmax'
)

#ResNet50 
base_model5 = tf.keras.applications.resnet50.ResNet50(
    include_top=True, weights='imagenet', input_tensor=None,
    input_shape=None, pooling=None, classes=1000,
    classifier_activation='softmax')

#Inception V3
base_model6=tf.keras.applications.InceptionV3(
    include_top=True, weights="imagenet", input_tensor=None,
    input_shape=None, pooling=None, classes=1000,
    classifier_activation="softmax",
)

# %% [markdown]
# ## setting all layers as non-trainable

# %%
for layer in base_model1.layers:
    layer.trainable=False
for layer in base_model2.layers:
    layer.trainable=False
for layer in base_model3.layers:
    layer.trainable=False
for layer in base_model4.layers:
    layer.trainable=False
for layer in base_model5.layers:
    layer.trainable=False
for layer in base_model6.layers:
    layer.trainable=False

# %% [markdown]
# ## Defining custom activation function
# As per the paper, custom activation function Swish is used in place of Relu in the model.

# %%
from keras.layers import Activation
from keras.utils.generic_utils import get_custom_objects
from keras import backend as K
def swish(x):
    return (K.sigmoid(x) * x)
get_custom_objects().update({'swish': Activation(swish)})

# %% [markdown]
# ## Defining convolution batch normalization function with Swish activation

# %%
def Conv2d_BN(x, nb_filter,kernel_size, padding='same',strides=(1,1)):   
    x = Conv2D(nb_filter,kernel_size,padding=padding,strides=strides)(x)
    x = Lambda(swish)(x)
    x = BatchNormalization(axis=3)(x)  
    return x

# %% [markdown]
# ## Defining Inception Block:
# Inception Modules are used in Convolutional Neural Networks to allow for more efficient computation and deeper Networks through a dimensionality reduction with stacked 1×1 convolutions. The modules were designed to solve the problem of computational expense, as well as overfitting, among other issues.

# %%
def Inception(x,nb_filter):  
    branch1x1 = Conv2d_BN(x,nb_filter,(1,1), padding='same',strides=(1,1))  
  
    branch3x3 = Conv2d_BN(x,nb_filter,(1,1), padding='same',strides=(1,1))  
    branch3x3 = Conv2d_BN(branch3x3,nb_filter,(3,3), padding='same',strides=(1,1))  
  
    branch5x5 = Conv2d_BN(x,nb_filter,(1,1), padding='same',strides=(1,1))  
    branch5x5 = Conv2d_BN(branch5x5,nb_filter,(3,3), padding='same',strides=(1,1))
    branch5x5 = Conv2d_BN(branch5x5,nb_filter,(3,3), padding='same',strides=(1,1))
  
    branchpool = MaxPooling2D(pool_size=(3,3),strides=(1,1),padding='same')(x)  
    branchpool = Conv2d_BN(branchpool,nb_filter,(1,1),padding='same',strides=(1,1))  
  
    x = concatenate([branch1x1,branch3x3,branch5x5,branchpool],axis=3)    
    return x

# %% [markdown]
# ## Adding new layers in model architechture
# Global Average Pooling
# Fully connected layers are replaced by a global pooling layer to conduct the dimension reduction of feature maps.

# %%
#DenseNet121
x = base_model1.layers[-6].output


x = Conv2d_BN(x,512,(3,3),strides=(1,1),padding='same')  
x = MaxPooling2D(pool_size=(2,2),strides=(1,1),padding='same')(x) 

x = Inception(x,512)  
x = Inception(x,512)  

x = GlobalAveragePooling2D()(x)
predictions_1 = Dense(2, activation='softmax')(x)
model1 = Model(inputs=base_model1.input, outputs=predictions_1)

# %%
#DenseNet169
x = base_model2.layers[-6].output


x = Conv2d_BN(x,512,(3,3),strides=(1,1),padding='same')  
x = MaxPooling2D(pool_size=(2,2),strides=(1,1),padding='same')(x) 

x = Inception(x,512)  
x = Inception(x,512)  

x = GlobalAveragePooling2D()(x)
predictions_2 = Dense(2, activation='softmax')(x)
model2 = Model(inputs=base_model2.input, outputs=predictions_2)

# %%
#VGG-19
x = base_model3.layers[-6].output


x = Conv2d_BN(x,512,(3,3),strides=(1,1),padding='same')  
x = MaxPooling2D(pool_size=(2,2),strides=(1,1),padding='same')(x) 

x = Inception(x,512)  
x = Inception(x,512)  

x = GlobalAveragePooling2D()(x)
predictions_3 = Dense(2, activation='softmax')(x)
model3 = Model(inputs=base_model3.input, outputs=predictions_3)

# %%
#MobileNet V2
x = base_model4.layers[-6].output


x = Conv2d_BN(x,512,(3,3),strides=(1,1),padding='same')  
x = MaxPooling2D(pool_size=(2,2),strides=(1,1),padding='same')(x) 

x = Inception(x,512)  
x = Inception(x,512)  

x = GlobalAveragePooling2D()(x)
predictions_4 = Dense(2, activation='softmax')(x)
model4 = Model(inputs=base_model4.input, outputs=predictions_4)

# %%
#ResNet 50
x = base_model5.layers[-6].output


x = Conv2d_BN(x,512,(3,3),strides=(1,1),padding='same')  
x = MaxPooling2D(pool_size=(2,2),strides=(1,1),padding='same')(x) 

x = Inception(x,512)  
x = Inception(x,512)  

x = GlobalAveragePooling2D()(x)
predictions_5 = Dense(2, activation='softmax')(x)
model5 = Model(inputs=base_model5.input, outputs=predictions_5)

# %%
#Inception V3
x = base_model6.layers[-6].output


x = Conv2d_BN(x,512,(3,3),strides=(1,1),padding='same')  
x = MaxPooling2D(pool_size=(2,2),strides=(1,1),padding='same')(x) 

x = Inception(x,512)  
x = Inception(x,512)  

x = GlobalAveragePooling2D()(x)
predictions_6 = Dense(2, activation='softmax')(x)
model6 = Model(inputs=base_model6.input, outputs=predictions_6)

# %%
model1.summary()
model2.summary()
model3.summary()
model4.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0          ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 112, 112, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 112, 112, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 114, 114, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 56, 56, 64)   0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 56, 56, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 56, 56, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 56, 56, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 56, 56, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 56, 56, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 56, 56, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 56, 56, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 56, 56, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 56, 56, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 56, 56, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 56, 56, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 56, 56, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 56, 56, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 56, 56, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 56, 56, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 56, 56, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 56, 56, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 56, 56, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 56, 56, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 56, 56, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 28, 28, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 28, 28, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 28, 28, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#  conv3_block2_0_relu (Activatio  (None, 28, 28, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 28, 28, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 28, 28, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 28, 28, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 28, 28, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 28, 28, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 28, 28, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 28, 28, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 28, 28, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 28, 28, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 28, 28, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 28, 28, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 28, 28, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 28, 28, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 28, 28, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 28, 28, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 28, 28, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 28, 28, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 28, 28, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 28, 28, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 28, 28, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 28, 28, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 28, 28, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 28, 28, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 28, 28, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 28, 28, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 28, 28, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 28, 28, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 28, 28, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 28, 28, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 28, 28, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 28, 28, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 28, 28, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 28, 28, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 28, 28, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 28, 28, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 28, 28, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 28, 28, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 28, 28, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 28, 28, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 28, 28, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 28, 28, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 14, 14, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 14, 14, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 14, 14, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 14, 14, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block2_1_relu[0][0]']
#  conv4_block2_concat (Concatena  (None, 14, 14, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 14, 14, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 14, 14, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 14, 14, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 14, 14, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 14, 14, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 14, 14, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 14, 14, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 14, 14, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 14, 14, 416)  0          ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 14, 14, 416)  1664       ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 14, 14, 416)  0          ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 128)  53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block6_1_bn[0][0]']
#  n)
# ...
#
#  conv5_block30_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 7, 7, 1600)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 7, 7, 1600)  6400        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 7, 7, 1600)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 7, 7, 128)    204800      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 7, 7, 1632)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 7, 7, 1632)  6528        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 7, 7, 1632)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 7, 7, 128)    208896      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 7, 7, 512)    147968      ['conv5_block32_2_conv[0][0]']
#
#  lambda_15 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_109[0][0]']
#
#  batch_normalization_109 (Batch  (None, 7, 7, 512)   2048        ['lambda_15[0][0]']
#  Normalization)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 7, 7, 512)   0           ['batch_normalization_109[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 7, 7, 512)    262656      ['max_pooling2d_7[0][0]']
#
#  lambda_19 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_113[0][0]']
#
#  batch_normalization_113 (Batch  (None, 7, 7, 512)   2048        ['lambda_19[0][0]']
#  Normalization)
#
#  conv2d_111 (Conv2D)            (None, 7, 7, 512)    262656      ['max_pooling2d_7[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_113[0][0]']
#
#  lambda_17 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_111[0][0]']
#
#  lambda_20 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_114[0][0]']
#  batch_normalization_111 (Batch  (None, 7, 7, 512)   2048        ['lambda_17[0][0]']
#  Normalization)
#
#  batch_normalization_114 (Batch  (None, 7, 7, 512)   2048        ['lambda_20[0][0]']
#  Normalization)
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 7, 7, 512)   0           ['max_pooling2d_7[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 7, 7, 512)    262656      ['max_pooling2d_7[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_111[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_114[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 7, 7, 512)    262656      ['max_pooling2d_8[0][0]']
#
#  lambda_16 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_110[0][0]']
#
#  lambda_18 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_112[0][0]']
#
#  lambda_21 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_115[0][0]']
#
#  lambda_22 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_116[0][0]']
#
#  batch_normalization_110 (Batch  (None, 7, 7, 512)   2048        ['lambda_16[0][0]']
#  Normalization)
#
#  batch_normalization_112 (Batch  (None, 7, 7, 512)   2048        ['lambda_18[0][0]']
#  Normalization)
#
#  batch_normalization_115 (Batch  (None, 7, 7, 512)   2048        ['lambda_21[0][0]']
#  Normalization)
#
#  batch_normalization_116 (Batch  (None, 7, 7, 512)   2048        ['lambda_22[0][0]']
#  Normalization)
#
#  concatenate_4 (Concatenate)    (None, 7, 7, 2048)   0           ['batch_normalization_110[0][0]',
#                                                                   'batch_normalization_112[0][0]',
#                                                                   'batch_normalization_115[0][0]',
#                                                                   'batch_normalization_116[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 7, 7, 512)    1049088     ['concatenate_4[0][0]']
#
#  lambda_26 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_120[0][0]']
#
#  batch_normalization_120 (Batch  (None, 7, 7, 512)   2048        ['lambda_26[0][0]']
#  Normalization)
#
#  conv2d_118 (Conv2D)            (None, 7, 7, 512)    1049088     ['concatenate_4[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_120[0][0]']
#
#  lambda_24 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_118[0][0]']
#
#  lambda_27 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_121[0][0]']
#
#  batch_normalization_118 (Batch  (None, 7, 7, 512)   2048        ['lambda_24[0][0]']
#  Normalization)
#
#  batch_normalization_121 (Batch  (None, 7, 7, 512)   2048        ['lambda_27[0][0]']
#  Normalization)
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 7, 7, 2048)  0           ['concatenate_4[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 7, 7, 512)    1049088     ['concatenate_4[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_118[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_121[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 7, 7, 512)    1049088     ['max_pooling2d_9[0][0]']
#
#  lambda_23 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_117[0][0]']
#
#  lambda_25 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_119[0][0]']
#
#  lambda_28 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_122[0][0]']
#
#  lambda_29 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_123[0][0]']
#
#  batch_normalization_117 (Batch  (None, 7, 7, 512)   2048        ['lambda_23[0][0]']
#  Normalization)
#  batch_normalization_119 (Batch  (None, 7, 7, 512)   2048        ['lambda_25[0][0]']
#  Normalization)
#
#  batch_normalization_122 (Batch  (None, 7, 7, 512)   2048        ['lambda_28[0][0]']
#  Normalization)
#
#  batch_normalization_123 (Batch  (None, 7, 7, 512)   2048        ['lambda_29[0][0]']
#  Normalization)
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## Compiling the Model

# %%
def comp():
    learning_rate=0.0001
    decay=1e-6
    momentum=0.8
    nesterov=True
    sgd_optimizer= SGD(lr = learning_rate, decay = decay, momentum = momentum, nesterov = nesterov)
    models=['DenseNet169','DenseNet121','VGG-19','MobileNet','ResNet50','Inception']
    
    for i in models:
        if i=='DenseNet121':
            model1.compile(loss='categorical_crossentropy',optimizer=sgd_optimizer,metrics=['accuracy','mse'])
        elif i=='DenseNet169':
            model2.compile(loss='categorical_crossentropy',optimizer=sgd_optimizer,metrics=['accuracy','mse'])
        if i=='VGG-19':
            model3.compile(loss='categorical_crossentropy',optimizer=sgd_optimizer,metrics=['accuracy','mse'])
        if i=='MobileNet':
            model4.compile(loss='categorical_crossentropy',optimizer=sgd_optimizer,metrics=['accuracy','mse'])
        if i=='ResNet50':
            model5.compile(loss='categorical_crossentropy',optimizer=sgd_optimizer,metrics=['accuracy','mse'])
        else:
            model6.compile(loss='categorical_crossentropy',optimizer=sgd_optimizer,metrics=['accuracy','mse'])

        
if __name__ == "__main__":
    comp()
# Out:
# D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %% [markdown]
# # Training the Models

# %% [markdown]
# ### 1.DenseNet-121

# %%
#DenseNet121
import time
epochs =50
batch_size = 10

start = time.time()
history_1 = model1.fit(
      train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=epochs, batch_size =batch_size,
      validation_data=validation_generator,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
end = time.time()
print("Execution Time : ", (end - start))
# Out:
# Epoch 1/50
# 78/78 [==============================] - 37s 335ms/step - loss: 0.4258 - accuracy: 0.7997 - mse: 0.1367 - val_loss: 0.7410 - val_accuracy: 0.3125 - val_mse: 0.2738
# Epoch 2/50
# 78/78 [==============================] - 18s 237ms/step - loss: 0.2669 - accuracy: 0.9056 - mse: 0.0771 - val_loss: 0.7792 - val_accuracy: 0.3125 - val_mse: 0.2925
# Epoch 3/50
# 78/78 [==============================] - 19s 239ms/step - loss: 0.2271 - accuracy: 0.9145 - mse: 0.0642 - val_loss: 0.8131 - val_accuracy: 0.3125 - val_mse: 0.3087
# Epoch 4/50
50
# 78/78 [==============================] - 18s 236ms/step - loss: 0.0468 - accuracy: 0.9962 - mse: 0.0091 - val_loss: 0.1709 - val_accuracy: 0.9286 - val_mse: 0.0472
# Epoch 38/50
# 78/78 [==============================] - 18s 236ms/step - loss: 0.0523 - accuracy: 0.9860 - mse: 0.0121 - val_loss: 0.1578 - val_accuracy: 0.9420 - val_mse: 0.0445
# Epoch 39/50
# 78/78 [==============================] - 18s 237ms/step - loss: 0.0507 - accuracy: 0.9923 - mse: 0.0105 - val_loss: 0.1475 - val_accuracy: 0.9464 - val_mse: 0.0411
# Epoch 40/50
# 78/78 [==============================] - 19s 237ms/step - loss: 0.0581 - accuracy: 0.9885 - mse: 0.0129 - val_loss: 0.1587 - val_accuracy: 0.9442 - val_mse: 0.0425
# Epoch 41/50
# 78/78 [==============================] - 18s 236ms/step - loss: 0.0521 - accuracy: 0.9847 - mse: 0.0124 - val_loss: 0.1659 - val_accuracy: 0.9375 - val_mse: 0.0456
# Epoch 42/50
# 78/78 [==============================] - 18s 236ms/step - loss: 0.0596 - accuracy: 0.9783 - mse: 0.0156 - val_loss: 0.1672 - val_accuracy: 0.9353 - val_mse: 0.0470
# Epoch 43/50
# 78/78 [==============================] - 19s 237ms/step - loss: 0.0599 - accuracy: 0.9821 - mse: 0.0150 - val_loss: 0.1677 - val_accuracy: 0.9375 - val_mse: 0.0467
# Epoch 44/50
# 78/78 [==============================] - 19s 238ms/step - loss: 0.0568 - accuracy: 0.9847 - mse: 0.0137 - val_loss: 0.1796 - val_accuracy: 0.9330 - val_mse: 0.0498
# Epoch 45/50
# 78/78 [==============================] - 19s 237ms/step - loss: 0.0592 - accuracy: 0.9821 - mse: 0.0146 - val_loss: 0.1631 - val_accuracy: 0.9420 - val_mse: 0.0440
# Epoch 46/50
# 78/78 [==============================] - 18s 237ms/step - loss: 0.0552 - accuracy: 0.9898 - mse: 0.0125 - val_loss: 0.1577 - val_accuracy: 0.9442 - val_mse: 0.0426
# Epoch 47/50
# 78/78 [==============================] - 18s 236ms/step - loss: 0.0542 - accuracy: 0.9821 - mse: 0.0131 - val_loss: 0.1737 - val_accuracy: 0.9420 - val_mse: 0.0477
# Epoch 48/50
# 78/78 [==============================] - 19s 237ms/step - loss: 0.0451 - accuracy: 0.9885 - mse: 0.0096 - val_loss: 0.1487 - val_accuracy: 0.9464 - val_mse: 0.0406
# Epoch 49/50
# 78/78 [==============================] - 19s 237ms/step - loss: 0.0429 - accuracy: 0.9872 - mse: 0.0094 - val_loss: 0.1498 - val_accuracy: 0.9464 - val_mse: 0.0401
# Epoch 50/50
# 78/78 [==============================] - 19s 238ms/step - loss: 0.0450 - accuracy: 0.9898 - mse: 0.0099 - val_loss: 0.1622 - val_accuracy: 0.9487 - val_mse: 0.0427
# Execution Time :  945.4625804424286

# %%
model1.save('SavedModels/IEEE Updated/D121.h5')

# %%
acc = history_1.history['accuracy']
val_acc = history_1.history['val_accuracy']

loss = history_1.history['loss']
val_loss = history_1.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
start=time.time()
test_output_1= model1.evaluate(test_generator, steps=test_generator.samples/test_generator.batch_size, verbose=1)
end=time.time()
print(model1.metrics_names)
print(test_output_1)
print("testing time : "+ str(end-start))
# Out:
# 17/17 [==============================] - 2s 114ms/step - loss: 0.0855 - accuracy: 0.9708 - mse: 0.0238
# ['loss', 'accuracy', 'mse']
# [0.08553437143564224, 0.9707602262496948, 0.023833876475691795]
# testing time : 2.3594541549682617

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


#Y_pred = model1.predict_generator(validation_generator, 171 // batch_size+1)
Y_pred=model1.predict(test_generator,test_generator.samples//batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
conf=confusion_matrix(test_generator.classes, y_pred)
print(conf)
print('Classification Report')
target_names = ['Gluacoma', 'Normal']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# 18/18 [==============================] - 2s 122ms/step
# Confusion Matrix
# [[82  5]
#  [ 0 84]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Gluacoma       1.00      0.94      0.97        87
#       Normal       0.94      1.00      0.97        84
#
#     accuracy                           0.97       171
#    macro avg       0.97      0.97      0.97       171
# weighted avg       0.97      0.97      0.97       171

# %%
import itertools

# %%
classes = [0, 1]
# plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.BuGn)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %% [markdown]
# ### DenseNet-169

# %%
#DenseNet169
import time
epochs =50
batch_size = 10

start = time.time()
history_2 = model2.fit(
      train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=epochs, batch_size =batch_size,
      validation_data=validation_generator,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
end = time.time()
print("Execution Time : ", (end - start))
# Out:
# Epoch 1/50
# 78/78 [==============================] - 36s 346ms/step - loss: 0.4259 - accuracy: 0.8138 - mse: 0.1352 - val_loss: 0.6203 - val_accuracy: 0.6875 - val_mse: 0.2145
# Epoch 2/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.2655 - accuracy: 0.9005 - mse: 0.0787 - val_loss: 0.6183 - val_accuracy: 0.6875 - val_mse: 0.2138
# Epoch 3/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.2271 - accuracy: 0.9133 - mse: 0.0643 - val_loss: 0.6076 - val_accuracy: 0.6875 - val_mse: 0.2096
# Epoch 4/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.2259 - accuracy: 0.9209 - mse: 0.0644 - val_loss: 0.5810 - val_accuracy: 0.6875 - val_mse: 0.1988
# Epoch 5/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1860 - accuracy: 0.9273 - mse: 0.0523 - val_loss: 0.5236 - val_accuracy: 0.6875 - val_mse: 0.1757
# Epoch 6/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1636 - accuracy: 0.9464 - mse: 0.0425 - val_loss: 0.4174 - val_accuracy: 0.8415 - val_mse: 0.1265
# Epoch 7/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1679 - accuracy: 0.9401 - mse: 0.0454 - val_loss: 0.3041 - val_accuracy: 0.9129 - val_mse: 0.0821
# Epoch 8/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1656 - accuracy: 0.9388 - mse: 0.0455 - val_loss: 0.2344 - val_accuracy: 0.9286 - val_mse: 0.0617
# Epoch 9/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1445 - accuracy: 0.9528 - mse: 0.0379 - val_loss: 0.2010 - val_accuracy: 0.9308 - val_mse: 0.0550
# Epoch 10/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1460 - accuracy: 0.9541 - mse: 0.0383 - val_loss: 0.1892 - val_accuracy: 0.9286 - val_mse: 0.0523
# Epoch 11/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1408 - accuracy: 0.9541 - mse: 0.0371 - val_loss: 0.1751 - val_accuracy: 0.9353 - val_mse: 0.0486
# Epoch 12/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1181 - accuracy: 0.9643 - mse: 0.0290 - val_loss: 0.1762 - val_accuracy: 0.9397 - val_mse: 0.0487
# Epoch 13/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.1189 - accuracy: 0.9643 - mse: 0.0304 - val_loss: 0.1820 - val_accuracy: 0.9330 - val_mse: 0.0491
# Epoch 14/50
# 78/78 [==============================] - 21s 275ms/step - loss: 0.1285 - accuracy: 0.9592 - mse: 0.0339 - val_loss: 0.1843 - val_accuracy: 0.9286 - val_mse: 0.0514
# Epoch 15/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.1102 - accuracy: 0.9719 - mse: 0.0274 - val_loss: 0.1836 - val_accuracy: 0.9330 - val_mse: 0.0508
# Epoch 16/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1087 - accuracy: 0.9605 - mse: 0.0282 - val_loss: 0.1936 - val_accuracy: 0.9196 - val_mse: 0.0538
# Epoch 17/50
# 78/78 [==============================] - 21s 275ms/step - loss: 0.0948 - accuracy: 0.9681 - mse: 0.0234 - val_loss: 0.1992 - val_accuracy: 0.9219 - val_mse: 0.0556
# Epoch 18/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1204 - accuracy: 0.9592 - mse: 0.0330 - val_loss: 0.1755 - val_accuracy: 0.9330 - val_mse: 0.0492
# Epoch 19/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1223 - accuracy: 0.9554 - mse: 0.0339 - val_loss: 0.1737 - val_accuracy: 0.9330 - val_mse: 0.0481
# Epoch 20/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0840 - accuracy: 0.9809 - mse: 0.0192 - val_loss: 0.1763 - val_accuracy: 0.9375 - val_mse: 0.0488
# Epoch 21/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0764 - accuracy: 0.9770 - mse: 0.0180 - val_loss: 0.1790 - val_accuracy: 0.9353 - val_mse: 0.0498
# Epoch 22/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0756 - accuracy: 0.9821 - mse: 0.0176 - val_loss: 0.1786 - val_accuracy: 0.9353 - val_mse: 0.0493
# Epoch 23/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0903 - accuracy: 0.9732 - mse: 0.0225 - val_loss: 0.1852 - val_accuracy: 0.9353 - val_mse: 0.0512
# Epoch 24/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0637 - accuracy: 0.9872 - mse: 0.0132 - val_loss: 0.1802 - val_accuracy: 0.9308 - val_mse: 0.0499
# Epoch 25/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0928 - accuracy: 0.9745 - mse: 0.0231 - val_loss: 0.1721 - val_accuracy: 0.9353 - val_mse: 0.0481
# Epoch 26/50
# 78/78 [==============================] - 21s 272ms/step - loss: 0.0850 - accuracy: 0.9732 - mse: 0.0214 - val_loss: 0.1672 - val_accuracy: 0.9375 - val_mse: 0.0471
# Epoch 27/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0772 - accuracy: 0.9809 - mse: 0.0182 - val_loss: 0.1745 - val_accuracy: 0.9308 - val_mse: 0.0487
# Epoch 28/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.0694 - accuracy: 0.9809 - mse: 0.0160 - val_loss: 0.1854 - val_accuracy: 0.9286 - val_mse: 0.0518
# Epoch 29/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.0602 - accuracy: 0.9872 - mse: 0.0125 - val_loss: 0.1779 - val_accuracy: 0.9286 - val_mse: 0.0496
# Epoch 30/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.0836 - accuracy: 0.9821 - mse: 0.0193 - val_loss: 0.1811 - val_accuracy: 0.9375 - val_mse: 0.0510
# Epoch 31/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.0638 - accuracy: 0.9860 - mse: 0.0138 - val_loss: 0.1751 - val_accuracy: 0.9330 - val_mse: 0.0496
# Epoch 32/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.0920 - accuracy: 0.9668 - mse: 0.0242 - val_loss: 0.1707 - val_accuracy: 0.9286 - val_mse: 0.0491
# Epoch 33/50
# 78/78 [==============================] - 21s 275ms/step - loss: 0.0702 - accuracy: 0.9834 - mse: 0.0164 - val_loss: 0.1744 - val_accuracy: 0.9308 - val_mse: 0.0500
# Epoch 34/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0571 - accuracy: 0.9885 - mse: 0.0115 - val_loss: 0.1644 - val_accuracy: 0.9420 - val_mse: 0.0467
# Epoch 35/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0647 - accuracy: 0.9809 - mse: 0.0151 - val_loss: 0.1932 - val_accuracy: 0.9308 - val_mse: 0.0531
# Epoch 36/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0509 - accuracy: 0.9911 - mse: 0.0103 - val_loss: 0.1787 - val_accuracy: 0.9397 - val_mse: 0.0506
# Epoch 37/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1013 - accuracy: 0.9681 - mse: 0.0267 - val_loss: 0.1715 - val_accuracy: 0.9397 - val_mse: 0.0486
# Epoch 38/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.0475 - accuracy: 0.9923 - mse: 0.0090 - val_loss: 0.1765 - val_accuracy: 0.9286 - val_mse: 0.0506
# Epoch 39/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0519 - accuracy: 0.9885 - mse: 0.0113 - val_loss: 0.1724 - val_accuracy: 0.9375 - val_mse: 0.0486
# Epoch 40/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.0543 - accuracy: 0.9872 - mse: 0.0119 - val_loss: 0.1917 - val_accuracy: 0.9330 - val_mse: 0.0542
# Epoch 41/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0489 - accuracy: 0.9936 - mse: 0.0103 - val_loss: 0.1764 - val_accuracy: 0.9375 - val_mse: 0.0501
# Epoch 42/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0631 - accuracy: 0.9860 - mse: 0.0146 - val_loss: 0.1791 - val_accuracy: 0.9375 - val_mse: 0.0502
# Epoch 43/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0558 - accuracy: 0.9860 - mse: 0.0125 - val_loss: 0.1859 - val_accuracy: 0.9375 - val_mse: 0.0516
# Epoch 44/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0547 - accuracy: 0.9860 - mse: 0.0123 - val_loss: 0.1946 - val_accuracy: 0.9286 - val_mse: 0.0528
# Epoch 45/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.0499 - accuracy: 0.9923 - mse: 0.0103 - val_loss: 0.1697 - val_accuracy: 0.9397 - val_mse: 0.0479
# Epoch 46/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.0576 - accuracy: 0.9821 - mse: 0.0144 - val_loss: 0.1643 - val_accuracy: 0.9397 - val_mse: 0.0460
# Epoch 47/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0464 - accuracy: 0.9885 - mse: 0.0104 - val_loss: 0.1803 - val_accuracy: 0.9353 - val_mse: 0.0499
# Epoch 48/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0554 - accuracy: 0.9847 - mse: 0.0132 - val_loss: 0.1678 - val_accuracy: 0.9353 - val_mse: 0.0480
# Epoch 49/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0463 - accuracy: 0.9923 - mse: 0.0098 - val_loss: 0.1811 - val_accuracy: 0.9330 - val_mse: 0.0514
# Epoch 50/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0624 - accuracy: 0.9847 - mse: 0.0155 - val_loss: 0.1654 - val_accuracy: 0.9353 - val_mse: 0.0466
# Execution Time :  1084.274442911148

# %%
model2.save('SavedModels/IEEE Updated/D169.h5')

# %%
acc = history_2.history['accuracy']
val_acc = history_2.history['val_accuracy']

loss = history_2.history['loss']
val_loss = history_2.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
start=time.time()
test_output_2= model2.evaluate(test_generator, steps=test_generator.samples/test_generator.batch_size, verbose=1)
end=time.time()
print(model2.metrics_names)
print(test_output_2)
print("testing time : "+ str(end-start))
# Out:
# 17/17 [==============================] - 3s 140ms/step - loss: 0.0646 - accuracy: 0.9825 - mse: 0.0148
# ['loss', 'accuracy', 'mse']
# [0.06464745104312897, 0.9824561476707458, 0.014809038490056992]
# testing time : 2.748819351196289

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


#Y_pred = model1.predict_generator(validation_generator, 171 // batch_size+1)
Y_pred=model2.predict(test_generator,test_generator.samples//batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
conf=confusion_matrix(test_generator.classes, y_pred)
print(conf)
print('Classification Report')
target_names = ['Gluacoma', 'Normal']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# 18/18 [==============================] - 3s 144ms/step
# Confusion Matrix
# [[86  1]
#  [ 2 82]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Gluacoma       0.98      0.99      0.98        87
#       Normal       0.99      0.98      0.98        84
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171

# %%
classes = [0, 1]
# plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.BuGn)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %% [markdown]
# ### 3. VGG-19

# %%
#Vgg-19
import time
epochs =50
batch_size = 10

start = time.time()
history_3 = model3.fit(
      train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=epochs, batch_size =batch_size,
      validation_data=validation_generator,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
end = time.time()
print("Execution Time : ", (end - start))
# Out:
# Epoch 1/50
# 78/78 [==============================] - 66s 676ms/step - loss: 0.4445 - accuracy: 0.8227 - mse: 0.1401 - val_loss: 0.8451 - val_accuracy: 0.3125 - val_mse: 0.3236
# Epoch 2/50
# 78/78 [==============================] - 46s 594ms/step - loss: 0.2926 - accuracy: 0.9120 - mse: 0.0815 - val_loss: 1.0184 - val_accuracy: 0.3125 - val_mse: 0.3969
# Epoch 3/50
# 78/78 [==============================] - 46s 593ms/step - loss: 0.2598 - accuracy: 0.9133 - mse: 0.0736 - val_loss: 1.1369 - val_accuracy: 0.3125 - val_mse: 0.4384
# Epoch 4/50
# 78/78 [==============================] - 46s 593ms/step - loss: 0
50
# 78/78 [==============================] - 46s 594ms/step - loss: 0.0628 - accuracy: 0.9821 - mse: 0.0153 - val_loss: 0.2292 - val_accuracy: 0.9464 - val_mse: 0.0485
# Epoch 43/50
# 78/78 [==============================] - 46s 593ms/step - loss: 0.0618 - accuracy: 0.9809 - mse: 0.0153 - val_loss: 0.1912 - val_accuracy: 0.9576 - val_mse: 0.0402
# Epoch 44/50
# 78/78 [==============================] - 46s 593ms/step - loss: 0.0441 - accuracy: 0.9911 - mse: 0.0093 - val_loss: 0.2318 - val_accuracy: 0.9464 - val_mse: 0.0483
# Epoch 45/50
# 78/78 [==============================] - 46s 593ms/step - loss: 0.0714 - accuracy: 0.9719 - mse: 0.0194 - val_loss: 0.1763 - val_accuracy: 0.9598 - val_mse: 0.0386
# Epoch 46/50
# 78/78 [==============================] - 46s 594ms/step - loss: 0.0615 - accuracy: 0.9796 - mse: 0.0155 - val_loss: 0.2129 - val_accuracy: 0.9509 - val_mse: 0.0444
# Epoch 47/50
# 78/78 [==============================] - 46s 593ms/step - loss: 0.0578 - accuracy: 0.9821 - mse: 0.0141 - val_loss: 0.2423 - val_accuracy: 0.9442 - val_mse: 0.0517
# Epoch 48/50
# 78/78 [==============================] - 46s 594ms/step - loss: 0.0409 - accuracy: 0.9898 - mse: 0.0090 - val_loss: 0.2890 - val_accuracy: 0.9353 - val_mse: 0.0605
# Epoch 49/50
# 78/78 [==============================] - 46s 593ms/step - loss: 0.0389 - accuracy: 0.9936 - mse: 0.0078 - val_loss: 0.2198 - val_accuracy: 0.9509 - val_mse: 0.0443
# Epoch 50/50
# 78/78 [==============================] - 46s 594ms/step - loss: 0.0486 - accuracy: 0.9872 - mse: 0.0118 - val_loss: 0.2611 - val_accuracy: 0.9442 - val_mse: 0.0534
# Execution Time :  2339.2869198322296

# %%
model3.save('SavedModels/IEEE Updated/VGG19.h5')

# %%
acc = history_3.history['accuracy']
val_acc = history_3.history['val_accuracy']

loss = history_3.history['loss']
val_loss = history_3.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
start=time.time()
test_output_3= model3.evaluate(test_generator, steps=test_generator.samples/test_generator.batch_size, verbose=1)
end=time.time()
print(model3.metrics_names)
print(test_output_3)
print("testing time : "+ str(end-start))
# Out:
# 17/17 [==============================] - 5s 292ms/step - loss: 0.0372 - accuracy: 1.0000 - mse: 0.0063
# ['loss', 'accuracy', 'mse']
# [0.03717963397502899, 1.0, 0.006261845119297504]
# testing time : 5.35501503944397

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


#Y_pred = model1.predict_generator(validation_generator, 171 // batch_size+1)
Y_pred=model3.predict(test_generator,test_generator.samples//batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
conf=confusion_matrix(test_generator.classes, y_pred)
print(conf)
print('Classification Report')
target_names = ['Gluacoma', 'Normal']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# 18/18 [==============================] - 5s 304ms/step
# Confusion Matrix
# [[87  0]
#  [ 0 84]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Gluacoma       1.00      1.00      1.00        87
#       Normal       1.00      1.00      1.00        84
#
#     accuracy                           1.00       171
#    macro avg       1.00      1.00      1.00       171
# weighted avg       1.00      1.00      1.00       171

# %%
import itertools
classes = [0, 1]
# plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.BuGn)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %% [markdown]
# ### 4. MobileNet V2

# %%
#MobileNet 
import time
epochs =50
batch_size = 10

start = time.time()
history_4 = model4.fit(
      train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=epochs, batch_size =batch_size,
      validation_data=validation_generator,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
end = time.time()
print("Execution Time : ", (end - start))
# Out:
# Epoch 1/50
# 78/78 [==============================] - 20s 204ms/step - loss: 0.4038 - accuracy: 0.8036 - mse: 0.1294 - val_loss: 0.3651 - val_accuracy: 0.9531 - val_mse: 0.0989
# Epoch 2/50
# 78/78 [==============================] - 13s 168ms/step - loss: 0.1955 - accuracy: 0.9401 - mse: 0.0519 - val_loss: 0.2299 - val_accuracy: 0.9621 - val_mse: 0.0536
# Epoch 3/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.1561 - accuracy: 0.9528 - mse: 0.0403 - val_loss: 0.1560 - val_accuracy: 0.9576 - val_mse: 0.0368
# Epoch 4/50
# 78/78 [==============================] - 13s 162ms/step - loss: 0.1263 - accuracy: 0.9719 - mse: 0.0304 - val_loss: 0.1247 - val_accuracy: 0.9576 - val_mse: 0.0316
# Epoch 5/50
# 78/78 [==============================] - 13s 163ms/step - loss: 0.1270 - accuracy: 0.9566 - mse: 0.0330 - val_loss: 0.1139 - val_accuracy: 0.9598 - val_mse: 0.0303
# Epoch 6/50
# 78/78 [==============================] - 13s 163ms/step - loss: 0.1110 - accuracy: 0.9668 - mse: 0.0278 - val_loss: 0.0967 - val_accuracy: 0.9621 - val_mse: 0.0261
# Epoch 7/50
# 78/78 [==============================] - 13s 165ms/step - loss: 0.1100 - accuracy: 0.9745 - mse: 0.0259 - val_loss: 0.0884 - val_accuracy: 0.9621 - val_mse: 0.0242
# Epoch 8/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0967 - accuracy: 0.9783 - mse: 0.0230 - val_loss: 0.0792 - val_accuracy: 0.9621 - val_mse: 0.0217
# Epoch 9/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0652 - accuracy: 0.9936 - mse: 0.0127 - val_loss: 0.0787 - val_accuracy: 0.9621 - val_mse: 0.0223
# Epoch 10/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0976 - accuracy: 0.9732 - mse: 0.0242 - val_loss: 0.0725 - val_accuracy: 0.9621 - val_mse: 0.0201
# Epoch 11/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0766 - accuracy: 0.9770 - mse: 0.0189 - val_loss: 0.0719 - val_accuracy: 0.9621 - val_mse: 0.0206
# Epoch 12/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0561 - accuracy: 0.9898 - mse: 0.0110 - val_loss: 0.0709 - val_accuracy: 0.9621 - val_mse: 0.0204
# Epoch 13/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0465 - accuracy: 0.9962 - mse: 0.0080 - val_loss: 0.0705 - val_accuracy: 0.9643 - val_mse: 0.0205
# Epoch 14/50
# 78/78 [==============================] - 13s 165ms/step - loss: 0.0473 - accuracy: 0.9898 - mse: 0.0103 - val_loss: 0.0709 - val_accuracy: 0.9643 - val_mse: 0.0207
# Epoch 15/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0511 - accuracy: 0.9898 - mse: 0.0105 - val_loss: 0.0658 - val_accuracy: 0.9643 - val_mse: 0.0194
# Epoch 16/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0568 - accuracy: 0.9809 - mse: 0.0137 - val_loss: 0.0675 - val_accuracy: 0.9643 - val_mse: 0.0200
# Epoch 17/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0580 - accuracy: 0.9834 - mse: 0.0135 - val_loss: 0.0680 - val_accuracy: 0.9665 - val_mse: 0.0205
# Epoch 18/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0593 - accuracy: 0.9872 - mse: 0.0137 - val_loss: 0.0682 - val_accuracy: 0.9665 - val_mse: 0.0203
# Epoch 19/50
# 78/78 [==============================] - 13s 165ms/step - loss: 0.0318 - accuracy: 0.9962 - mse: 0.0055 - val_loss: 0.0670 - val_accuracy: 0.9688 - val_mse: 0.0201
# Epoch 20/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0513 - accuracy: 0.9860 - mse: 0.0120 - val_loss: 0.0647 - val_accuracy: 0.9688 - val_mse: 0.0193
# Epoch 21/50
# 78/78 [==============================] - 13s 165ms/step - loss: 0.0474 - accuracy: 0.9885 - mse: 0.0110 - val_loss: 0.0632 - val_accuracy: 0.9688 - val_mse: 0.0190
# Epoch 22/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0644 - accuracy: 0.9821 - mse: 0.0163 - val_loss: 0.0620 - val_accuracy: 0.9688 - val_mse: 0.0189
# Epoch 23/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0276 - accuracy: 0.9949 - mse: 0.0045 - val_loss: 0.0613 - val_accuracy: 0.9688 - val_mse: 0.0188
# Epoch 24/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0282 - accuracy: 0.9936 - mse: 0.0052 - val_loss: 0.0626 - val_accuracy: 0.9665 - val_mse: 0.0194
# Epoch 25/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0282 - accuracy: 0.9949 - mse: 0.0048 - val_loss: 0.0625 - val_accuracy: 0.9665 - val_mse: 0.0193
# Epoch 26/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0371 - accuracy: 0.9872 - mse: 0.0084 - val_loss: 0.0621 - val_accuracy: 0.9688 - val_mse: 0.0192
# Epoch 27/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0646 - accuracy: 0.9847 - mse: 0.0156 - val_loss: 0.0602 - val_accuracy: 0.9688 - val_mse: 0.0183
# Epoch 28/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0220 - accuracy: 0.9974 - mse: 0.0034 - val_loss: 0.0612 - val_accuracy: 0.9732 - val_mse: 0.0186
# Epoch 29/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0391 - accuracy: 0.9936 - mse: 0.0083 - val_loss: 0.0622 - val_accuracy: 0.9732 - val_mse: 0.0188
# Epoch 30/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0453 - accuracy: 0.9885 - mse: 0.0101 - val_loss: 0.0589 - val_accuracy: 0.9754 - val_mse: 0.0175
# Epoch 31/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0408 - accuracy: 0.9898 - mse: 0.0099 - val_loss: 0.0604 - val_accuracy: 0.9710 - val_mse: 0.0184
# Epoch 32/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0164 - accuracy: 1.0000 - mse: 0.0019 - val_loss: 0.0607 - val_accuracy: 0.9732 - val_mse: 0.0186
# Epoch 33/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0196 - accuracy: 0.9974 - mse: 0.0032 - val_loss: 0.0588 - val_accuracy: 0.9732 - val_mse: 0.0180
# Epoch 34/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0258 - accuracy: 0.9936 - mse: 0.0053 - val_loss: 0.0579 - val_accuracy: 0.9754 - val_mse: 0.0176
# Epoch 35/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0189 - accuracy: 1.0000 - mse: 0.0027 - val_loss: 0.0599 - val_accuracy: 0.9732 - val_mse: 0.0184
# Epoch 36/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0301 - accuracy: 0.9936 - mse: 0.0068 - val_loss: 0.0596 - val_accuracy: 0.9710 - val_mse: 0.0184
# Epoch 37/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0440 - accuracy: 0.9847 - mse: 0.0115 - val_loss: 0.0548 - val_accuracy: 0.9777 - val_mse: 0.0165
# Epoch 38/50
# 78/78 [==============================] - 13s 165ms/step - loss: 0.0422 - accuracy: 0.9821 - mse: 0.0119 - val_loss: 0.0573 - val_accuracy: 0.9732 - val_mse: 0.0174
# Epoch 39/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0167 - accuracy: 1.0000 - mse: 0.0023 - val_loss: 0.0573 - val_accuracy: 0.9732 - val_mse: 0.0175
# Epoch 40/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0132 - accuracy: 0.9987 - mse: 0.0014 - val_loss: 0.0564 - val_accuracy: 0.9732 - val_mse: 0.0175
# Epoch 41/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0224 - accuracy: 0.9949 - mse: 0.0046 - val_loss: 0.0548 - val_accuracy: 0.9732 - val_mse: 0.0170
# Epoch 42/50
# 78/78 [==============================] - 13s 165ms/step - loss: 0.0118 - accuracy: 1.0000 - mse: 0.0012 - val_loss: 0.0539 - val_accuracy: 0.9732 - val_mse: 0.0167
# Epoch 43/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0161 - accuracy: 0.9974 - mse: 0.0024 - val_loss: 0.0532 - val_accuracy: 0.9732 - val_mse: 0.0163
# Epoch 44/50
# 78/78 [==============================] - 13s 165ms/step - loss: 0.0569 - accuracy: 0.9745 - mse: 0.0167 - val_loss: 0.0517 - val_accuracy: 0.9732 - val_mse: 0.0161
# Epoch 45/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0087 - accuracy: 1.0000 - mse: 6.0224e-04 - val_loss: 0.0541 - val_accuracy: 0.9732 - val_mse: 0.0169
# Epoch 46/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0181 - accuracy: 0.9962 - mse: 0.0031 - val_loss: 0.0539 - val_accuracy: 0.9777 - val_mse: 0.0165
# Epoch 47/50
# 78/78 [==============================] - 13s 165ms/step - loss: 0.0264 - accuracy: 0.9911 - mse: 0.0060 - val_loss: 0.0558 - val_accuracy: 0.9777 - val_mse: 0.0171
# Epoch 48/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0396 - accuracy: 0.9885 - mse: 0.0099 - val_loss: 0.0544 - val_accuracy: 0.9777 - val_mse: 0.0168
# Epoch 49/50
# 78/78 [==============================] - 13s 165ms/step - loss: 0.0205 - accuracy: 0.9923 - mse: 0.0047 - val_loss: 0.0516 - val_accuracy: 0.9732 - val_mse: 0.0159
# Epoch 50/50
# 78/78 [==============================] - 13s 164ms/step - loss: 0.0254 - accuracy: 0.9949 - mse: 0.0052 - val_loss: 0.0515 - val_accuracy: 0.9754 - val_mse: 0.0157
# Execution Time :  651.1595680713654

# %%
model4.save('SavedModels/IEEE Updated/MobileNet.h5')

# %%
acc = history_4.history['accuracy']
val_acc = history_4.history['val_accuracy']

loss = history_4.history['loss']
val_loss = history_4.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
start=time.time()
test_output_4= model4.evaluate(test_generator, steps=test_generator.samples/test_generator.batch_size, verbose=1)
end=time.time()
print(model4.metrics_names)
print(test_output_4)
print("testing time : "+ str(end-start))
# Out:
# 17/17 [==============================] - 2s 108ms/step - loss: 0.0283 - accuracy: 0.9883 - mse: 0.0072
# ['loss', 'accuracy', 'mse']
# [0.02834666147828102, 0.988304078578949, 0.007199219893664122]
# testing time : 1.8625824451446533

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


#Y_pred = model1.predict_generator(validation_generator, 171 // batch_size+1)
Y_pred=model4.predict(test_generator,test_generator.samples//batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
conf=confusion_matrix(test_generator.classes, y_pred)
print(conf)
print('Classification Report')
target_names = ['Gluacoma', 'Normal']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# 18/18 [==============================] - 2s 59ms/step
# Confusion Matrix
# [[85  2]
#  [ 0 84]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Gluacoma       1.00      0.98      0.99        87
#       Normal       0.98      1.00      0.99        84
#
#     accuracy                           0.99       171
#    macro avg       0.99      0.99      0.99       171
# weighted avg       0.99      0.99      0.99       171

# %%
classes = [0, 1]
# plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.BuGn)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %% [markdown]
# ## ResNet50

# %%
#ResNet 50
import time
epochs =50
batch_size = 10

start = time.time()
history_5 = model5.fit(
      train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=epochs, batch_size =batch_size,
      validation_data=validation_generator,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
end = time.time()
print("Execution Time : ", (end - start))
# Out:
# Epoch 1/50
# 78/78 [==============================] - 31s 343ms/step - loss: 0.6479 - accuracy: 0.7181 - mse: 0.2275 - val_loss: 0.8672 - val_accuracy: 0.3125 - val_mse: 0.3337
# Epoch 2/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.5886 - accuracy: 0.8163 - mse: 0.1988 - val_loss: 1.2073 - val_accuracy: 0.3125 - val_mse: 0.4623
# Epoch 3/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.5285 - accuracy: 0.8457 - mse: 0.1711 - val_loss: 1.6080 - val_accuracy: 0.3125 - val_mse: 0.5585
# Epoch 4/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.4660 - accuracy: 0.8584 - mse: 0.1446 - val_loss: 1.8561 - val_accuracy: 0.3125 - val_mse: 0.5968
# Epoch 5/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.4135 - accuracy: 0.8763 - mse: 0.1240 - val_loss: 1.4576 - val_accuracy: 0.3125 - val_mse: 0.5280
# Epoch 6/50
# 78/78 [==============================] - 24s 310ms/step - loss: 0.3732 - accuracy: 0.8941 - mse: 0.1094 - val_loss: 0.6826 - val_accuracy: 0.3862 - val_mse: 0.2456
# Epoch 7/50
# 78/78 [==============================] - 24s 310ms/step - loss: 0.3204 - accuracy: 0.9133 - mse: 0.0901 - val_loss: 0.4661 - val_accuracy: 0.8438 - val_mse: 0.1439
# Epoch 8/50
# 78/78 [==============================] - 24s 310ms/step - loss: 0.3208 - accuracy: 0.8865 - mse: 0.0935 - val_loss: 0.6497 - val_accuracy: 0.6875 - val_mse: 0.2260
# Epoch 9/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.2967 - accuracy: 0.8980 - mse: 0.0851 - val_loss: 0.2830 - val_accuracy: 0.9397 - val_mse: 0.0749
# Epoch 10/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.2889 - accuracy: 0.9031 - mse: 0.0829 - val_loss: 0.3025 - val_accuracy: 0.9018 - val_mse: 0.0856
# Epoch 11/50
# 78/78 [==============================] - 24s 310ms/step - loss: 0.2575 - accuracy: 0.9031 - mse: 0.0735 - val_loss: 0.2970 - val_accuracy: 0.8638 - val_mse: 0.0932
# Epoch 12/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.2514 - accuracy: 0.9107 - mse: 0.0697 - val_loss: 0.2598 - val_accuracy: 0.8817 - val_mse: 0.0781
# Epoch 13/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.2474 - accuracy: 0.9018 - mse: 0.0718 - val_loss: 0.3674 - val_accuracy: 0.8170 - val_mse: 0.1196
# Epoch 14/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.2123 - accuracy: 0.9120 - mse: 0.0614 - val_loss: 0.5731 - val_accuracy: 0.7388 - val_mse: 0.1840
# Epoch 15/50
# 78/78 [==============================] - 24s 310ms/step - loss: 0.2159 - accuracy: 0.9235 - mse: 0.0608 - val_loss: 1.4963 - val_accuracy: 0.4353 - val_mse: 0.4373
# Epoch 16/50
# 78/78 [==============================] - 24s 310ms/step - loss: 0.1979 - accuracy: 0.9311 - mse: 0.0557 - val_loss: 0.1735 - val_accuracy: 0.9509 - val_mse: 0.0451
# Epoch 17/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1985 - accuracy: 0.9222 - mse: 0.0564 - val_loss: 0.3445 - val_accuracy: 0.8438 - val_mse: 0.1107
# Epoch 18/50
# 78/78 [==============================] - 24s 312ms/step - loss: 0.1867 - accuracy: 0.9324 - mse: 0.0525 - val_loss: 0.3958 - val_accuracy: 0.8080 - val_mse: 0.1289
# Epoch 19/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.2007 - accuracy: 0.9426 - mse: 0.0544 - val_loss: 1.9329 - val_accuracy: 0.6875 - val_mse: 0.3087
# Epoch 20/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1795 - accuracy: 0.9362 - mse: 0.0507 - val_loss: 0.6098 - val_accuracy: 0.7388 - val_mse: 0.1903
# Epoch 21/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1869 - accuracy: 0.9222 - mse: 0.0526 - val_loss: 0.7282 - val_accuracy: 0.6607 - val_mse: 0.2324
# Epoch 22/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1792 - accuracy: 0.9477 - mse: 0.0489 - val_loss: 3.5474 - val_accuracy: 0.3237 - val_mse: 0.6326
# Epoch 23/50
# 78/78 [==============================] - 24s 310ms/step - loss: 0.1426 - accuracy: 0.9477 - mse: 0.0391 - val_loss: 0.2330 - val_accuracy: 0.8951 - val_mse: 0.0699
# Epoch 24/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1562 - accuracy: 0.9515 - mse: 0.0430 - val_loss: 0.4445 - val_accuracy: 0.8013 - val_mse: 0.1405
# Epoch 25/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1800 - accuracy: 0.9349 - mse: 0.0508 - val_loss: 9.8580 - val_accuracy: 0.6875 - val_mse: 0.3125
# Epoch 26/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1698 - accuracy: 0.9528 - mse: 0.0450 - val_loss: 0.2400 - val_accuracy: 0.9062 - val_mse: 0.0728
# Epoch 27/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1495 - accuracy: 0.9426 - mse: 0.0421 - val_loss: 6.0745 - val_accuracy: 0.3214 - val_mse: 0.6751
# Epoch 28/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1417 - accuracy: 0.9464 - mse: 0.0391 - val_loss: 5.3159 - val_accuracy: 0.3214 - val_mse: 0.6677
# Epoch 29/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1382 - accuracy: 0.9477 - mse: 0.0393 - val_loss: 1.3538 - val_accuracy: 0.6897 - val_mse: 0.2861
# Epoch 30/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1550 - accuracy: 0.9579 - mse: 0.0408 - val_loss: 10.6495 - val_accuracy: 0.6875 - val_mse: 0.3125
# Epoch 31/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1626 - accuracy: 0.9452 - mse: 0.0457 - val_loss: 0.1610 - val_accuracy: 0.9420 - val_mse: 0.0446
# Epoch 32/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1359 - accuracy: 0.9566 - mse: 0.0373 - val_loss: 4.1368 - val_accuracy: 0.6875 - val_mse: 0.3125
# Epoch 33/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1861 - accuracy: 0.9413 - mse: 0.0516 - val_loss: 13.2105 - val_accuracy: 0.3125 - val_mse: 0.6874
# Epoch 34/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1225 - accuracy: 0.9566 - mse: 0.0332 - val_loss: 6.8258 - val_accuracy: 0.3192 - val_mse: 0.6790
# Epoch 35/50
# 78/78 [==============================] - 24s 310ms/step - loss: 0.1452 - accuracy: 0.9349 - mse: 0.0420 - val_loss: 1.3178 - val_accuracy: 0.6920 - val_mse: 0.2812
# Epoch 36/50
# 78/78 [==============================] - 24s 310ms/step - loss: 0.1378 - accuracy: 0.9554 - mse: 0.0372 - val_loss: 32.1722 - val_accuracy: 0.3125 - val_mse: 0.6875
# Epoch 37/50
# 78/78 [==============================] - 24s 310ms/step - loss: 0.1384 - accuracy: 0.9515 - mse: 0.0387 - val_loss: 1.8209 - val_accuracy: 0.6897 - val_mse: 0.3027
# Epoch 38/50
# 78/78 [==============================] - 24s 310ms/step - loss: 0.1734 - accuracy: 0.9401 - mse: 0.0471 - val_loss: 8.4009 - val_accuracy: 0.3192 - val_mse: 0.6812
# Epoch 39/50
# 78/78 [==============================] - 24s 310ms/step - loss: 0.1382 - accuracy: 0.9541 - mse: 0.0376 - val_loss: 12.1836 - val_accuracy: 0.3125 - val_mse: 0.6860
# Epoch 40/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1415 - accuracy: 0.9515 - mse: 0.0382 - val_loss: 9.8754 - val_accuracy: 0.3170 - val_mse: 0.6821
# Epoch 41/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1277 - accuracy: 0.9515 - mse: 0.0362 - val_loss: 7.2148 - val_accuracy: 0.3192 - val_mse: 0.6751
# Epoch 42/50
# 78/78 [==============================] - 24s 310ms/step - loss: 0.1351 - accuracy: 0.9554 - mse: 0.0371 - val_loss: 0.4479 - val_accuracy: 0.8036 - val_mse: 0.1398
# Epoch 43/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1648 - accuracy: 0.9477 - mse: 0.0444 - val_loss: 9.8673 - val_accuracy: 0.6875 - val_mse: 0.3125
# Epoch 44/50
# 78/78 [==============================] - 24s 310ms/step - loss: 0.1465 - accuracy: 0.9464 - mse: 0.0404 - val_loss: 3.6721 - val_accuracy: 0.3259 - val_mse: 0.6208
# Epoch 45/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1130 - accuracy: 0.9617 - mse: 0.0311 - val_loss: 1.5455 - val_accuracy: 0.4955 - val_mse: 0.4016
# Epoch 46/50
# 78/78 [==============================] - 24s 310ms/step - loss: 0.1336 - accuracy: 0.9515 - mse: 0.0371 - val_loss: 22.0528 - val_accuracy: 0.3125 - val_mse: 0.6875
# Epoch 47/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1130 - accuracy: 0.9630 - mse: 0.0301 - val_loss: 1.8890 - val_accuracy: 0.6920 - val_mse: 0.3026
# Epoch 48/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1525 - accuracy: 0.9592 - mse: 0.0390 - val_loss: 3.0053 - val_accuracy: 0.3527 - val_mse: 0.5844
# Epoch 49/50
# 78/78 [==============================] - 24s 310ms/step - loss: 0.1255 - accuracy: 0.9617 - mse: 0.0313 - val_loss: 0.7324 - val_accuracy: 0.7321 - val_mse: 0.2108
# Epoch 50/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1079 - accuracy: 0.9617 - mse: 0.0295 - val_loss: 2.2960 - val_accuracy: 0.4085 - val_mse: 0.5064
# Execution Time :  1222.1298699378967

# %%
model5.save('SavedModels/IEEE Updated/ResNet.h5')

# %%
acc = history_5.history['accuracy']
val_acc = history_5.history['val_accuracy']

loss = history_5.history['loss']
val_loss = history_5.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
start=time.time()
test_output_5= model5.evaluate(test_generator, steps=test_generator.samples/test_generator.batch_size, verbose=1)
end=time.time()
print(model5.metrics_names)
print(test_output_5)
print("testing time : "+ str(end-start))
# Out:
# 17/17 [==============================] - 3s 180ms/step - loss: 1.7798 - accuracy: 0.5088 - mse: 0.4271
# ['loss', 'accuracy', 'mse']
# [1.7797945737838745, 0.5087719559669495, 0.4271060526371002]
# testing time : 3.1183691024780273

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


#Y_pred = model1.predict_generator(validation_generator, 171 // batch_size+1)
Y_pred=model5.predict(test_generator,test_generator.samples//batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
conf=confusion_matrix(test_generator.classes, y_pred)
print(conf)
print('Classification Report')
target_names = ['Gluacoma', 'Normal']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# 18/18 [==============================] - 3s 141ms/step
# Confusion Matrix
# [[ 3 84]
#  [ 0 84]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Gluacoma       1.00      0.03      0.07        87
#       Normal       0.50      1.00      0.67        84
#
#     accuracy                           0.51       171
#    macro avg       0.75      0.52      0.37       171
# weighted avg       0.75      0.51      0.36       171

# %%
classes = [0, 1]
# plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.BuGn)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %% [markdown]
# ### 6. Inception V3

# %%
#Inception V3
import time
epochs =50
batch_size = 10

start = time.time()
history_6 = model6.fit(
      train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=epochs, batch_size =batch_size,
      validation_data=validation_generator,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
end = time.time()
print("Execution Time : ", (end - start))
# Out:
# Epoch 1/50
# 78/78 [==============================] - 27s 275ms/step - loss: 0.4872 - accuracy: 0.7423 - mse: 0.1629 - val_loss: 0.5286 - val_accuracy: 0.8571 - val_mse: 0.1707
# Epoch 2/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.2780 - accuracy: 0.8941 - mse: 0.0818 - val_loss: 0.4226 - val_accuracy: 0.8862 - val_mse: 0.1263
# Epoch 3/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.2026 - accuracy: 0.9349 - mse: 0.0554 - val_loss: 0.3398 - val_accuracy: 0.9018 - val_mse: 0.0966
# Epoch 4/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.1876 - accuracy: 0.9388 - mse: 0.0516 - val_loss: 0.3048 - val_accuracy: 0.8996 - val_mse: 0.0840
# Epoch 5/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.1729 - accuracy: 0.9401 - mse: 0.0468 - val_loss: 0.2935 - val_accuracy: 0.8973 - val_mse: 0.0788
# Epoch 6/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.1459 - accuracy: 0.9579 - mse: 0.0369 - val_loss: 0.2746 - val_accuracy: 0.9062 - val_mse: 0.0722
# Epoch 7/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.1114 - accuracy: 0.9783 - mse: 0.0243 - val_loss: 0.2944 - val_accuracy: 0.9040 - val_mse: 0.0746
# Epoch 8/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.1124 - accuracy: 0.9707 - mse: 0.0265 - val_loss: 0.3078 - val_accuracy: 0.9085 - val_mse: 0.0762
# Epoch 9/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0873 - accuracy: 0.9821 - mse: 0.0188 - val_loss: 0.3039 - val_accuracy: 0.9129 - val_mse: 0.0734
# Epoch 10/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0810 - accuracy: 0.9860 - mse: 0.0173 - val_loss: 0.2949 - val_accuracy: 0.9129 - val_mse: 0.0706
# Epoch 11/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.1076 - accuracy: 0.9719 - mse: 0.0265 - val_loss: 0.3067 - val_accuracy: 0.9129 - val_mse: 0.0722
# Epoch 12/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0760 - accuracy: 0.9847 - mse: 0.0153 - val_loss: 0.3068 - val_accuracy: 0.9152 - val_mse: 0.0704
# Epoch 13/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0771 - accuracy: 0.9821 - mse: 0.0175 - val_loss: 0.3253 - val_accuracy: 0.9174 - val_mse: 0.0728
# Epoch 14/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0964 - accuracy: 0.9617 - mse: 0.0258 - val_loss: 0.3060 - val_accuracy: 0.9196 - val_mse: 0.0679
# Epoch 15/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0626 - accuracy: 0.9885 - mse: 0.0123 - val_loss: 0.2823 - val_accuracy: 0.9196 - val_mse: 0.0632
# Epoch 16/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0542 - accuracy: 0.9911 - mse: 0.0098 - val_loss: 0.3097 - val_accuracy: 0.9174 - val_mse: 0.0670
# Epoch 17/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0476 - accuracy: 0.9949 - mse: 0.0081 - val_loss: 0.3106 - val_accuracy: 0.9174 - val_mse: 0.0664
# Epoch 18/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0708 - accuracy: 0.9847 - mse: 0.0166 - val_loss: 0.3022 - val_accuracy: 0.9219 - val_mse: 0.0639
# Epoch 19/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0450 - accuracy: 0.9923 - mse: 0.0078 - val_loss: 0.3098 - val_accuracy: 0.9219 - val_mse: 0.0646
# Epoch 20/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0704 - accuracy: 0.9783 - mse: 0.0176 - val_loss: 0.2945 - val_accuracy: 0.9219 - val_mse: 0.0616
# Epoch 21/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0383 - accuracy: 0.9987 - mse: 0.0055 - val_loss: 0.3171 - val_accuracy: 0.9263 - val_mse: 0.0643
# Epoch 22/50
# 78/78 [==============================] - 17s 215ms/step - loss: 0.0382 - accuracy: 0.9936 - mse: 0.0066 - val_loss: 0.3111 - val_accuracy: 0.9263 - val_mse: 0.0633
# Epoch 23/50
# 78/78 [==============================] - 17s 215ms/step - loss: 0.0536 - accuracy: 0.9885 - mse: 0.0117 - val_loss: 0.3259 - val_accuracy: 0.9263 - val_mse: 0.0651
# Epoch 24/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0483 - accuracy: 0.9872 - mse: 0.0107 - val_loss: 0.3163 - val_accuracy: 0.9308 - val_mse: 0.0620
# Epoch 25/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0516 - accuracy: 0.9872 - mse: 0.0116 - val_loss: 0.3225 - val_accuracy: 0.9286 - val_mse: 0.0631
# Epoch 26/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0355 - accuracy: 0.9974 - mse: 0.0067 - val_loss: 0.3238 - val_accuracy: 0.9263 - val_mse: 0.0631
# Epoch 27/50
# 78/78 [==============================] - 17s 215ms/step - loss: 0.0286 - accuracy: 1.0000 - mse: 0.0036 - val_loss: 0.3229 - val_accuracy: 0.9286 - val_mse: 0.0614
# Epoch 28/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0355 - accuracy: 0.9962 - mse: 0.0067 - val_loss: 0.3381 - val_accuracy: 0.9308 - val_mse: 0.0631
# Epoch 29/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0474 - accuracy: 0.9911 - mse: 0.0105 - val_loss: 0.3273 - val_accuracy: 0.9308 - val_mse: 0.0608
# Epoch 30/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0461 - accuracy: 0.9872 - mse: 0.0112 - val_loss: 0.3232 - val_accuracy: 0.9308 - val_mse: 0.0598
# Epoch 31/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0214 - accuracy: 0.9987 - mse: 0.0025 - val_loss: 0.3231 - val_accuracy: 0.9330 - val_mse: 0.0586
# Epoch 32/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0290 - accuracy: 0.9962 - mse: 0.0053 - val_loss: 0.3426 - val_accuracy: 0.9263 - val_mse: 0.0623
# Epoch 33/50
# 78/78 [==============================] - 17s 215ms/step - loss: 0.0431 - accuracy: 0.9898 - mse: 0.0091 - val_loss: 0.3310 - val_accuracy: 0.9286 - val_mse: 0.0611
# Epoch 34/50
# 78/78 [==============================] - 17s 215ms/step - loss: 0.0330 - accuracy: 0.9974 - mse: 0.0058 - val_loss: 0.3388 - val_accuracy: 0.9263 - val_mse: 0.0622
# Epoch 35/50
# 78/78 [==============================] - 17s 215ms/step - loss: 0.0292 - accuracy: 0.9987 - mse: 0.0047 - val_loss: 0.3515 - val_accuracy: 0.9263 - val_mse: 0.0633
# Epoch 36/50
# 78/78 [==============================] - 17s 215ms/step - loss: 0.0290 - accuracy: 0.9898 - mse: 0.0064 - val_loss: 0.3362 - val_accuracy: 0.9286 - val_mse: 0.0607
# Epoch 37/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0238 - accuracy: 0.9962 - mse: 0.0035 - val_loss: 0.3220 - val_accuracy: 0.9308 - val_mse: 0.0571
# Epoch 38/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0322 - accuracy: 0.9923 - mse: 0.0073 - val_loss: 0.3221 - val_accuracy: 0.9308 - val_mse: 0.0570
# Epoch 39/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0352 - accuracy: 0.9936 - mse: 0.0069 - val_loss: 0.3240 - val_accuracy: 0.9330 - val_mse: 0.0565
# Epoch 40/50
# 78/78 [==============================] - 17s 215ms/step - loss: 0.0234 - accuracy: 0.9974 - mse: 0.0034 - val_loss: 0.3467 - val_accuracy: 0.9308 - val_mse: 0.0600
# Epoch 41/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0364 - accuracy: 0.9936 - mse: 0.0070 - val_loss: 0.3545 - val_accuracy: 0.9308 - val_mse: 0.0609
# Epoch 42/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0275 - accuracy: 0.9949 - mse: 0.0052 - val_loss: 0.3231 - val_accuracy: 0.9353 - val_mse: 0.0550
# Epoch 43/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0198 - accuracy: 0.9987 - mse: 0.0025 - val_loss: 0.3352 - val_accuracy: 0.9330 - val_mse: 0.0568
# Epoch 44/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0394 - accuracy: 0.9898 - mse: 0.0093 - val_loss: 0.3408 - val_accuracy: 0.9375 - val_mse: 0.0573
# Epoch 45/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0325 - accuracy: 0.9898 - mse: 0.0076 - val_loss: 0.3225 - val_accuracy: 0.9330 - val_mse: 0.0540
# Epoch 46/50
# 78/78 [==============================] - 17s 215ms/step - loss: 0.0230 - accuracy: 1.0000 - mse: 0.0034 - val_loss: 0.3361 - val_accuracy: 0.9330 - val_mse: 0.0553
# Epoch 47/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0280 - accuracy: 0.9962 - mse: 0.0057 - val_loss: 0.3364 - val_accuracy: 0.9286 - val_mse: 0.0552
# Epoch 48/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0204 - accuracy: 0.9987 - mse: 0.0027 - val_loss: 0.3546 - val_accuracy: 0.9286 - val_mse: 0.0577
# Epoch 49/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0160 - accuracy: 0.9974 - mse: 0.0024 - val_loss: 0.3480 - val_accuracy: 0.9286 - val_mse: 0.0563
# Epoch 50/50
# 78/78 [==============================] - 17s 216ms/step - loss: 0.0275 - accuracy: 0.9949 - mse: 0.0059 - val_loss: 0.3387 - val_accuracy: 0.9308 - val_mse: 0.0543
# Execution Time :  854.9026534557343

# %%
model6.save('SavedModels/IEEE Updated/Inception.h5')

# %%
acc = history_6.history['accuracy']
val_acc = history_6.history['val_accuracy']

loss = history_6.history['loss']
val_loss = history_6.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
start=time.time()
test_output_6= model6.evaluate(test_generator, steps=test_generator.samples/test_generator.batch_size, verbose=1)
end=time.time()
print(model6.metrics_names)
print(test_output_6)
print("testing time : "+ str(end-start))
# Out:
# 17/17 [==============================] - 3s 184ms/step - loss: 0.0964 - accuracy: 0.9708 - mse: 0.0270
# ['loss', 'accuracy', 'mse']
# [0.096351757645607, 0.9707602262496948, 0.026985038071870804]
# testing time : 3.111793041229248

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


#Y_pred = model1.predict_generator(validation_generator, 171 // batch_size+1)
Y_pred=model6.predict(test_generator,test_generator.samples//batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
conf=confusion_matrix(test_generator.classes, y_pred)
print(conf)
print('Classification Report')
target_names = ['Gluacoma', 'Normal']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# 18/18 [==============================] - 3s 94ms/step
# Confusion Matrix
# [[85  2]
#  [ 3 81]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Gluacoma       0.97      0.98      0.97        87
#       Normal       0.98      0.96      0.97        84
#
#     accuracy                           0.97       171
#    macro avg       0.97      0.97      0.97       171
# weighted avg       0.97      0.97      0.97       171

# %%
classes = [0, 1]
# plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.BuGn)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')
