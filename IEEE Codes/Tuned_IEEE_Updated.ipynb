# %%
from keras.preprocessing.image import ImageDataGenerator
from tensorflow import keras
# Out:
# D:\Anaconda\envs\tf-gpu\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import tensorflow as tf
from keras.layers import Activation
from keras.utils.generic_utils import get_custom_objects
from keras import backend as K
from keras.layers import Conv2D, Lambda, MaxPooling2D, BatchNormalization, concatenate, GlobalAveragePooling2D, Dense
from keras.models import Model
from tensorflow.keras.optimizers import SGD
import matplotlib.pyplot as plt 
import time

# %%
from keras.preprocessing.image import ImageDataGenerator
train_dataset = ImageDataGenerator(rescale=1./255)
test_dataset = ImageDataGenerator(rescale=1./255)
validation_dataset = ImageDataGenerator(rescale=1./255)

batchsize = 10
train_generator=train_dataset.flow_from_directory('ieee/updated_train/', 
                                                  target_size=(224, 224), 
                                                  batch_size=batchsize, 
                                                  class_mode='categorical')
 
validation_generator = validation_dataset.flow_from_directory('ieee/updated_val/',
        target_size=(224, 224),
        batch_size=batchsize,
        class_mode='categorical',
        shuffle=False)
test_generator = test_dataset.flow_from_directory('ieee/updated_test/',
       target_size=(224, 224),
       batch_size=batchsize,
       class_mode='categorical',
       shuffle=False)
# Out:
# Found 784 images belonging to 2 classes.
# Found 448 images belonging to 2 classes.
# Found 171 images belonging to 2 classes.

# %% [markdown]
# # Model Creation
# VGG Net: VGG network has simplest structure with 3 x 3 filter in each convolutional layer. There are two variant available VGG-16 and VGG1-9. In the image above VGG network is presneted.
# Transfer Learning: The VGGNet pre-trained on ImageNet and Inception module for transfer learning, and trained the newly formed neural networks using new datasets. The approach combines the advantages of the VGGNet and Inception module.

# %%
#DENSENET121
base_model1=keras.applications.DenseNet121(
    include_top=True, weights="imagenet", input_tensor=None, 
    input_shape=None, pooling=None,classes=1000,
    #classifier_activation='softmax'
)

#DenseNet169
base_model2=keras.applications.DenseNet169(
    include_top=True, weights="imagenet", input_tensor=None, 
    input_shape=None, pooling=None,classes=1000,
    #classifier_activation='softmax'
)


#VGG19
base_model3=keras.applications.vgg19.VGG19(
    include_top=True, weights='imagenet', input_tensor=None,
    input_shape=None, pooling=None, classes=1000,
    classifier_activation='softmax'
)

#MobileNet
base_model4=tf.keras.applications.MobileNetV2(
    include_top=True, weights='imagenet', input_tensor=None,
    input_shape=None, pooling=None, classes=1000,
    classifier_activation='softmax'
)

#ResNet50 
base_model5 = tf.keras.applications.resnet50.ResNet50(
    include_top=True, weights='imagenet', input_tensor=None,
    input_shape=None, pooling=None, classes=1000,
    classifier_activation='softmax')

#Inception V3
base_model6=tf.keras.applications.InceptionV3(
    include_top=True, weights="imagenet", input_tensor=None,
    input_shape=None, pooling=None, classes=1000,
    classifier_activation="softmax",
)

# %% [markdown]
# ## setting all layers as non-trainable

# %%
for layer in base_model1.layers:
    layer.trainable=False
for layer in base_model2.layers:
    layer.trainable=False
for layer in base_model3.layers:
    layer.trainable=False
for layer in base_model4.layers:
    layer.trainable=False
for layer in base_model5.layers:
    layer.trainable=False
for layer in base_model6.layers:
    layer.trainable=False

# %% [markdown]
# ## Defining custom activation function
# As per the paper, custom activation function Swish is used in place of Relu in the model.

# %%
from keras.layers import Activation
from keras.utils.generic_utils import get_custom_objects
from keras import backend as K
def swish(x):
    return (K.sigmoid(x) * x)
get_custom_objects().update({'swish': Activation(swish)})

# %% [markdown]
# ## Defining convolution batch normalization function with Swish activation

# %%
def Conv2d_BN(x, nb_filter,kernel_size, padding='same',strides=(1,1)):   
    x = Conv2D(nb_filter,kernel_size,padding=padding,strides=strides)(x)
    x = Lambda(swish)(x)
    x = BatchNormalization(axis=3)(x)  
    return x

# %% [markdown]
# ## Defining Inception Block:
# Inception Modules are used in Convolutional Neural Networks to allow for more efficient computation and deeper Networks through a dimensionality reduction with stacked 1×1 convolutions. The modules were designed to solve the problem of computational expense, as well as overfitting, among other issues.

# %%
def Inception(x,nb_filter):  
    branch1x1 = Conv2d_BN(x,nb_filter,(1,1), padding='same',strides=(1,1))  
  
    branch3x3 = Conv2d_BN(x,nb_filter,(1,1), padding='same',strides=(1,1))  
    branch3x3 = Conv2d_BN(branch3x3,nb_filter,(3,3), padding='same',strides=(1,1))  
  
    branch5x5 = Conv2d_BN(x,nb_filter,(1,1), padding='same',strides=(1,1))  
    branch5x5 = Conv2d_BN(branch5x5,nb_filter,(3,3), padding='same',strides=(1,1))
    branch5x5 = Conv2d_BN(branch5x5,nb_filter,(3,3), padding='same',strides=(1,1))
  
    branchpool = MaxPooling2D(pool_size=(3,3),strides=(1,1),padding='same')(x)  
    branchpool = Conv2d_BN(branchpool,nb_filter,(1,1),padding='same',strides=(1,1))  
  
    x = concatenate([branch1x1,branch3x3,branch5x5,branchpool],axis=3)    
    return x

# %% [markdown]
# ## Adding new layers in model architechture
# Global Average Pooling
# Fully connected layers are replaced by a global pooling layer to conduct the dimension reduction of feature maps.

# %%
#DenseNet121
x = base_model1.layers[-6].output


x = Conv2d_BN(x,512,(3,3),strides=(1,1),padding='same')  
x = MaxPooling2D(pool_size=(2,2),strides=(1,1),padding='same')(x) 

x = Inception(x,512)  
x = Inception(x,512)  

x = GlobalAveragePooling2D()(x)
predictions_1 = Dense(2, activation='softmax')(x)
model1 = Model(inputs=base_model1.input, outputs=predictions_1)

# %%
#DenseNet169
x = base_model2.layers[-6].output


x = Conv2d_BN(x,512,(3,3),strides=(1,1),padding='same')  
x = MaxPooling2D(pool_size=(2,2),strides=(1,1),padding='same')(x) 

x = Inception(x,512)  
x = Inception(x,512)  

x = GlobalAveragePooling2D()(x)
predictions_2 = Dense(2, activation='softmax')(x)
model2 = Model(inputs=base_model2.input, outputs=predictions_2)

# %%
#VGG-19
x = base_model3.layers[-6].output


x = Conv2d_BN(x,512,(3,3),strides=(1,1),padding='same')  
x = MaxPooling2D(pool_size=(2,2),strides=(1,1),padding='same')(x) 

x = Inception(x,512)  
x = Inception(x,512)  

x = GlobalAveragePooling2D()(x)
predictions_3 = Dense(2, activation='softmax')(x)
model3 = Model(inputs=base_model3.input, outputs=predictions_3)

# %%
#MobileNet V2
x = base_model4.layers[-6].output


x = Conv2d_BN(x,512,(3,3),strides=(1,1),padding='same')  
x = MaxPooling2D(pool_size=(2,2),strides=(1,1),padding='same')(x) 

x = Inception(x,512)  
x = Inception(x,512)  

x = GlobalAveragePooling2D()(x)
predictions_4 = Dense(2, activation='softmax')(x)
model4 = Model(inputs=base_model4.input, outputs=predictions_4)

# %%
#ResNet 50
x = base_model5.layers[-6].output


x = Conv2d_BN(x,512,(3,3),strides=(1,1),padding='same')  
x = MaxPooling2D(pool_size=(2,2),strides=(1,1),padding='same')(x) 

x = Inception(x,512)  
x = Inception(x,512)  

x = GlobalAveragePooling2D()(x)
predictions_5 = Dense(2, activation='softmax')(x)
model5 = Model(inputs=base_model5.input, outputs=predictions_5)

# %%
#Inception V3
x = base_model6.layers[-6].output


x = Conv2d_BN(x,512,(3,3),strides=(1,1),padding='same')  
x = MaxPooling2D(pool_size=(2,2),strides=(1,1),padding='same')(x) 

x = Inception(x,512)  
x = Inception(x,512)  

x = GlobalAveragePooling2D()(x)
predictions_6 = Dense(2, activation='softmax')(x)
model6 = Model(inputs=base_model6.input, outputs=predictions_6)

# %%
model1.summary()
model2.summary()
model3.summary()
model4.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0          ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 112, 112, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 112, 112, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 114, 114, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 56, 56, 64)   0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 56, 56, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 56, 56, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 56, 56, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 56, 56, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 56, 56, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 56, 56, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 56, 56, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 56, 56, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 56, 56, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 56, 56, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 56, 56, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 56, 56, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 56, 56, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 56, 56, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 56, 56, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 56, 56, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 56, 56, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 56, 56, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 56, 56, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 56, 56, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 28, 28, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 28, 28, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 28, 28, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#  conv3_block2_0_relu (Activatio  (None, 28, 28, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 28, 28, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 28, 28, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 28, 28, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 28, 28, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 28, 28, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 28, 28, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 28, 28, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 28, 28, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 28, 28, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 28, 28, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 28, 28, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 28, 28, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 28, 28, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 28, 28, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 28, 28, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 28, 28, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 28, 28, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 28, 28, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 28, 28, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 28, 28, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 28, 28, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 28, 28, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 28, 28, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 28, 28, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 28, 28, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 28, 28, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 28, 28, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 28, 28, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 28, 28, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 28, 28, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 28, 28, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 28, 28, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 28, 28, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 28, 28, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 28, 28, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 28, 28, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 28, 28, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 28, 28, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 28, 28, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 28, 28, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 28, 28, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 14, 14, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 14, 14, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 14, 14, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 14, 14, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block2_1_relu[0][0]']
#  conv4_block2_concat (Concatena  (None, 14, 14, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 14, 14, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 14, 14, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 14, 14, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 14, 14, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 14, 14, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 14, 14, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 14, 14, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 14, 14, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 14, 14, 416)  0          ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 14, 14, 416)  1664       ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 14, 14, 416)  0          ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 128)  53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block6_1_bn[0][0]']
#  n)
# ...
#  conv5_block31_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 7, 7, 1632)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 7, 7, 1632)  6528        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 7, 7, 1632)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 7, 7, 128)    208896      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 7, 7, 512)    147968      ['conv5_block32_2_conv[0][0]']
#
#  lambda_15 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_109[0][0]']
#
#  batch_normalization_109 (Batch  (None, 7, 7, 512)   2048        ['lambda_15[0][0]']
#  Normalization)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 7, 7, 512)   0           ['batch_normalization_109[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 7, 7, 512)    262656      ['max_pooling2d_7[0][0]']
#
#  lambda_19 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_113[0][0]']
#
#  batch_normalization_113 (Batch  (None, 7, 7, 512)   2048        ['lambda_19[0][0]']
#  Normalization)
#
#  conv2d_111 (Conv2D)            (None, 7, 7, 512)    262656      ['max_pooling2d_7[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_113[0][0]']
#
#  lambda_17 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_111[0][0]']
#
#  lambda_20 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_114[0][0]']
#  batch_normalization_111 (Batch  (None, 7, 7, 512)   2048        ['lambda_17[0][0]']
#  Normalization)
#
#  batch_normalization_114 (Batch  (None, 7, 7, 512)   2048        ['lambda_20[0][0]']
#  Normalization)
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 7, 7, 512)   0           ['max_pooling2d_7[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 7, 7, 512)    262656      ['max_pooling2d_7[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_111[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_114[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 7, 7, 512)    262656      ['max_pooling2d_8[0][0]']
#
#  lambda_16 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_110[0][0]']
#
#  lambda_18 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_112[0][0]']
#
#  lambda_21 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_115[0][0]']
#
#  lambda_22 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_116[0][0]']
#
#  batch_normalization_110 (Batch  (None, 7, 7, 512)   2048        ['lambda_16[0][0]']
#  Normalization)
#
#  batch_normalization_112 (Batch  (None, 7, 7, 512)   2048        ['lambda_18[0][0]']
#  Normalization)
#
#  batch_normalization_115 (Batch  (None, 7, 7, 512)   2048        ['lambda_21[0][0]']
#  Normalization)
#
#  batch_normalization_116 (Batch  (None, 7, 7, 512)   2048        ['lambda_22[0][0]']
#  Normalization)
#
#  concatenate_4 (Concatenate)    (None, 7, 7, 2048)   0           ['batch_normalization_110[0][0]',
#                                                                   'batch_normalization_112[0][0]',
#                                                                   'batch_normalization_115[0][0]',
#                                                                   'batch_normalization_116[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 7, 7, 512)    1049088     ['concatenate_4[0][0]']
#
#  lambda_26 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_120[0][0]']
#
#  batch_normalization_120 (Batch  (None, 7, 7, 512)   2048        ['lambda_26[0][0]']
#  Normalization)
#
#  conv2d_118 (Conv2D)            (None, 7, 7, 512)    1049088     ['concatenate_4[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_120[0][0]']
#
#  lambda_24 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_118[0][0]']
#
#  lambda_27 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_121[0][0]']
#
#  batch_normalization_118 (Batch  (None, 7, 7, 512)   2048        ['lambda_24[0][0]']
#  Normalization)
#
#  batch_normalization_121 (Batch  (None, 7, 7, 512)   2048        ['lambda_27[0][0]']
#  Normalization)
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 7, 7, 2048)  0           ['concatenate_4[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 7, 7, 512)    1049088     ['concatenate_4[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_118[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_121[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 7, 7, 512)    1049088     ['max_pooling2d_9[0][0]']
#
#  lambda_23 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_117[0][0]']
#
#  lambda_25 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_119[0][0]']
#
#  lambda_28 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_122[0][0]']
#
#  lambda_29 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_123[0][0]']
#
#  batch_normalization_117 (Batch  (None, 7, 7, 512)   2048        ['lambda_23[0][0]']
#  Normalization)
#  batch_normalization_119 (Batch  (None, 7, 7, 512)   2048        ['lambda_25[0][0]']
#  Normalization)
#
#  batch_normalization_122 (Batch  (None, 7, 7, 512)   2048        ['lambda_28[0][0]']
#  Normalization)
#
#  batch_normalization_123 (Batch  (None, 7, 7, 512)   2048        ['lambda_29[0][0]']
#  Normalization)
#
#  concatenate_5 (Concatenate)    (None, 7, 7, 2048)   0           ['batch_normalization_117[0][0]',
#                                                                   'batch_normalization_119[0][0]',
#                                                                   'batch_normalization_122[0][0]',
#                                                                   'batch_normalization_123[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 2048)        0           ['concatenate_5[0][0]']
#  obalAveragePooling2D)
#
#  dense_1 (Dense)                (None, 2)            4098        ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 32,224,834
# Trainable params: 19,573,250
# Non-trainable params: 12,651,584
# __________________________________________________________________________________________________
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## Tuning

# %%
base_model1.trainable = True
base_model2.trainable = True
base_model3.trainable = True
base_model4.trainable = True
base_model5.trainable = True
base_model6.trainable = True

# %%
fine_tune_at = 100

# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model1.layers[:fine_tune_at]:
    layer.trainable = False

for layer in base_model2.layers[:fine_tune_at]:
    layer.trainable = False


for layer in base_model3.layers[:fine_tune_at]:
    layer.trainable = False

for layer in base_model4.layers[:fine_tune_at]:
    layer.trainable = False


for layer in base_model5.layers[:fine_tune_at]:
    layer.trainable = False

for layer in base_model6.layers[:fine_tune_at]:
    layer.trainable = False

# %%
base_learning_rate=0.0001

# %%
model1.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer = tf.keras.optimizers.RMSprop(learning_rate=base_learning_rate/10),
              metrics=['accuracy'])

model2.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer = tf.keras.optimizers.RMSprop(learning_rate=base_learning_rate/10),
              metrics=['accuracy'])

# %%
def comp():
    learning_rate=0.0001
    decay=1e-6
    momentum=0.8
    nesterov=True
    sgd_optimizer= SGD(lr = learning_rate, decay = decay, momentum = momentum, nesterov = nesterov)
    models=['VGG-19','MobileNet','ResNet50','Inception']
    
    for i in models:
        if i=='VGG-19':
            model3.compile(loss='categorical_crossentropy',optimizer=sgd_optimizer,metrics=['accuracy'])
        elif i=='MobileNet':
            model4.compile(loss='categorical_crossentropy',optimizer=sgd_optimizer,metrics=['accuracy'])
        elif i=='ResNet50':
            model5.compile(loss='categorical_crossentropy',optimizer=sgd_optimizer,metrics=['accuracy'])
        else:
            model6.compile(loss='categorical_crossentropy',optimizer=sgd_optimizer,metrics=['accuracy'])

        
if __name__ == "__main__":
    comp()
# Out:
# D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %% [markdown]
# # Training the Models

# %% [markdown]
# ### 1.DenseNet-121

# %%
fine_tune_epochs = 25
initial_epochs=25
batch_size=10
total_epochs =  initial_epochs + fine_tune_epochs

history_fine1 = model1.fit(train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=total_epochs, batch_size =batch_size,
      validation_data=validation_generator,
     #initial_epoch=50,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
# Out:
# Epoch 1/50
# D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\backend.py:5673: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Sigmoid activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(

# %%
model1.save('SavedModels/IEEE Updated/Tuned/D121.h5')

# %%
acc = history_1.history['accuracy']
val_acc = history_1.history['val_accuracy']

loss = history_1.history['loss']
val_loss = history_1.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
start=time.time()
test_output_1= model1.evaluate(test_generator, steps=test_generator.samples/test_generator.batch_size, verbose=1)
end=time.time()
print(model1.metrics_names)
print(test_output_1)
print("testing time : "+ str(end-start))
# Out:
# 17/17 [==============================] - 2s 114ms/step - loss: 0.0855 - accuracy: 0.9708 - mse: 0.0238
# ['loss', 'accuracy', 'mse']
# [0.08553437143564224, 0.9707602262496948, 0.023833876475691795]
# testing time : 2.3594541549682617

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


#Y_pred = model1.predict_generator(validation_generator, 171 // batch_size+1)
Y_pred=model1.predict(test_generator,test_generator.samples//batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
conf=confusion_matrix(test_generator.classes, y_pred)
print(conf)
print('Classification Report')
target_names = ['Gluacoma', 'Normal']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# 18/18 [==============================] - 2s 122ms/step
# Confusion Matrix
# [[82  5]
#  [ 0 84]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Gluacoma       1.00      0.94      0.97        87
#       Normal       0.94      1.00      0.97        84
#
#     accuracy                           0.97       171
#    macro avg       0.97      0.97      0.97       171
# weighted avg       0.97      0.97      0.97       171

# %%
import itertools

# %%
classes = [0, 1]
# plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.BuGn)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %% [markdown]
# ### DenseNet-169

# %%
fine_tune_epochs = 25
initial_epochs=25
batch_size=10
total_epochs =  initial_epochs + fine_tune_epochs

history_fine2 = model2.fit(train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=total_epochs, batch_size =batch_size,
      validation_data=validation_generator,
     #initial_epoch=50,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
# Out:
# Epoch 1/50
# 78/78 [==============================] - 36s 346ms/step - loss: 0.4259 - accuracy: 0.8138 - mse: 0.1352 - val_loss: 0.6203 - val_accuracy: 0.6875 - val_mse: 0.2145
# Epoch 2/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.2655 - accuracy: 0.9005 - mse: 0.0787 - val_loss: 0.6183 - val_accuracy: 0.6875 - val_mse: 0.2138
# Epoch 3/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.2271 - accuracy: 0.9133 - mse: 0.0643 - val_loss: 0.6076 - val_accuracy: 0.6875 - val_mse: 0.2096
# Epoch 4/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.2259 - accuracy: 0.9209 - mse: 0.0644 - val_loss: 0.5810 - val_accuracy: 0.6875 - val_mse: 0.1988
# Epoch 5/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1860 - accuracy: 0.9273 - mse: 0.0523 - val_loss: 0.5236 - val_accuracy: 0.6875 - val_mse: 0.1757
# Epoch 6/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1636 - accuracy: 0.9464 - mse: 0.0425 - val_loss: 0.4174 - val_accuracy: 0.8415 - val_mse: 0.1265
# Epoch 7/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1679 - accuracy: 0.9401 - mse: 0.0454 - val_loss: 0.3041 - val_accuracy: 0.9129 - val_mse: 0.0821
# Epoch 8/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1656 - accuracy: 0.9388 - mse: 0.0455 - val_loss: 0.2344 - val_accuracy: 0.9286 - val_mse: 0.0617
# Epoch 9/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1445 - accuracy: 0.9528 - mse: 0.0379 - val_loss: 0.2010 - val_accuracy: 0.9308 - val_mse: 0.0550
# Epoch 10/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1460 - accuracy: 0.9541 - mse: 0.0383 - val_loss: 0.1892 - val_accuracy: 0.9286 - val_mse: 0.0523
# Epoch 11/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1408 - accuracy: 0.9541 - mse: 0.0371 - val_loss: 0.1751 - val_accuracy: 0.9353 - val_mse: 0.0486
# Epoch 12/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1181 - accuracy: 0.9643 - mse: 0.0290 - val_loss: 0.1762 - val_accuracy: 0.9397 - val_mse: 0.0487
# Epoch 13/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.1189 - accuracy: 0.9643 - mse: 0.0304 - val_loss: 0.1820 - val_accuracy: 0.9330 - val_mse: 0.0491
# Epoch 14/50
# 78/78 [==============================] - 21s 275ms/step - loss: 0.1285 - accuracy: 0.9592 - mse: 0.0339 - val_loss: 0.1843 - val_accuracy: 0.9286 - val_mse: 0.0514
# Epoch 15/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.1102 - accuracy: 0.9719 - mse: 0.0274 - val_loss: 0.1836 - val_accuracy: 0.9330 - val_mse: 0.0508
# Epoch 16/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1087 - accuracy: 0.9605 - mse: 0.0282 - val_loss: 0.1936 - val_accuracy: 0.9196 - val_mse: 0.0538
# Epoch 17/50
# 78/78 [==============================] - 21s 275ms/step - loss: 0.0948 - accuracy: 0.9681 - mse: 0.0234 - val_loss: 0.1992 - val_accuracy: 0.9219 - val_mse: 0.0556
# Epoch 18/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1204 - accuracy: 0.9592 - mse: 0.0330 - val_loss: 0.1755 - val_accuracy: 0.9330 - val_mse: 0.0492
# Epoch 19/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1223 - accuracy: 0.9554 - mse: 0.0339 - val_loss: 0.1737 - val_accuracy: 0.9330 - val_mse: 0.0481
# Epoch 20/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0840 - accuracy: 0.9809 - mse: 0.0192 - val_loss: 0.1763 - val_accuracy: 0.9375 - val_mse: 0.0488
# Epoch 21/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0764 - accuracy: 0.9770 - mse: 0.0180 - val_loss: 0.1790 - val_accuracy: 0.9353 - val_mse: 0.0498
# Epoch 22/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0756 - accuracy: 0.9821 - mse: 0.0176 - val_loss: 0.1786 - val_accuracy: 0.9353 - val_mse: 0.0493
# Epoch 23/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0903 - accuracy: 0.9732 - mse: 0.0225 - val_loss: 0.1852 - val_accuracy: 0.9353 - val_mse: 0.0512
# Epoch 24/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0637 - accuracy: 0.9872 - mse: 0.0132 - val_loss: 0.1802 - val_accuracy: 0.9308 - val_mse: 0.0499
# Epoch 25/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0928 - accuracy: 0.9745 - mse: 0.0231 - val_loss: 0.1721 - val_accuracy: 0.9353 - val_mse: 0.0481
# Epoch 26/50
# 78/78 [==============================] - 21s 272ms/step - loss: 0.0850 - accuracy: 0.9732 - mse: 0.0214 - val_loss: 0.1672 - val_accuracy: 0.9375 - val_mse: 0.0471
# Epoch 27/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0772 - accuracy: 0.9809 - mse: 0.0182 - val_loss: 0.1745 - val_accuracy: 0.9308 - val_mse: 0.0487
# Epoch 28/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.0694 - accuracy: 0.9809 - mse: 0.0160 - val_loss: 0.1854 - val_accuracy: 0.9286 - val_mse: 0.0518
# Epoch 29/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.0602 - accuracy: 0.9872 - mse: 0.0125 - val_loss: 0.1779 - val_accuracy: 0.9286 - val_mse: 0.0496
# Epoch 30/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.0836 - accuracy: 0.9821 - mse: 0.0193 - val_loss: 0.1811 - val_accuracy: 0.9375 - val_mse: 0.0510
# Epoch 31/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.0638 - accuracy: 0.9860 - mse: 0.0138 - val_loss: 0.1751 - val_accuracy: 0.9330 - val_mse: 0.0496
# Epoch 32/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.0920 - accuracy: 0.9668 - mse: 0.0242 - val_loss: 0.1707 - val_accuracy: 0.9286 - val_mse: 0.0491
# Epoch 33/50
# 78/78 [==============================] - 21s 275ms/step - loss: 0.0702 - accuracy: 0.9834 - mse: 0.0164 - val_loss: 0.1744 - val_accuracy: 0.9308 - val_mse: 0.0500
# Epoch 34/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0571 - accuracy: 0.9885 - mse: 0.0115 - val_loss: 0.1644 - val_accuracy: 0.9420 - val_mse: 0.0467
# Epoch 35/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0647 - accuracy: 0.9809 - mse: 0.0151 - val_loss: 0.1932 - val_accuracy: 0.9308 - val_mse: 0.0531
# Epoch 36/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0509 - accuracy: 0.9911 - mse: 0.0103 - val_loss: 0.1787 - val_accuracy: 0.9397 - val_mse: 0.0506
# Epoch 37/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.1013 - accuracy: 0.9681 - mse: 0.0267 - val_loss: 0.1715 - val_accuracy: 0.9397 - val_mse: 0.0486
# Epoch 38/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.0475 - accuracy: 0.9923 - mse: 0.0090 - val_loss: 0.1765 - val_accuracy: 0.9286 - val_mse: 0.0506
# Epoch 39/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0519 - accuracy: 0.9885 - mse: 0.0113 - val_loss: 0.1724 - val_accuracy: 0.9375 - val_mse: 0.0486
# Epoch 40/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.0543 - accuracy: 0.9872 - mse: 0.0119 - val_loss: 0.1917 - val_accuracy: 0.9330 - val_mse: 0.0542
# Epoch 41/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0489 - accuracy: 0.9936 - mse: 0.0103 - val_loss: 0.1764 - val_accuracy: 0.9375 - val_mse: 0.0501
# Epoch 42/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0631 - accuracy: 0.9860 - mse: 0.0146 - val_loss: 0.1791 - val_accuracy: 0.9375 - val_mse: 0.0502
# Epoch 43/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0558 - accuracy: 0.9860 - mse: 0.0125 - val_loss: 0.1859 - val_accuracy: 0.9375 - val_mse: 0.0516
# Epoch 44/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0547 - accuracy: 0.9860 - mse: 0.0123 - val_loss: 0.1946 - val_accuracy: 0.9286 - val_mse: 0.0528
# Epoch 45/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.0499 - accuracy: 0.9923 - mse: 0.0103 - val_loss: 0.1697 - val_accuracy: 0.9397 - val_mse: 0.0479
# Epoch 46/50
# 78/78 [==============================] - 21s 274ms/step - loss: 0.0576 - accuracy: 0.9821 - mse: 0.0144 - val_loss: 0.1643 - val_accuracy: 0.9397 - val_mse: 0.0460
# Epoch 47/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0464 - accuracy: 0.9885 - mse: 0.0104 - val_loss: 0.1803 - val_accuracy: 0.9353 - val_mse: 0.0499
# Epoch 48/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0554 - accuracy: 0.9847 - mse: 0.0132 - val_loss: 0.1678 - val_accuracy: 0.9353 - val_mse: 0.0480
# Epoch 49/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0463 - accuracy: 0.9923 - mse: 0.0098 - val_loss: 0.1811 - val_accuracy: 0.9330 - val_mse: 0.0514
# Epoch 50/50
# 78/78 [==============================] - 21s 273ms/step - loss: 0.0624 - accuracy: 0.9847 - mse: 0.0155 - val_loss: 0.1654 - val_accuracy: 0.9353 - val_mse: 0.0466
# Execution Time :  1084.274442911148

# %%
model2.save('SavedModels/IEEE Updated/Tuned/D169.h5')

# %%
acc = history_2.history['accuracy']
val_acc = history_2.history['val_accuracy']

loss = history_2.history['loss']
val_loss = history_2.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
start=time.time()
test_output_2= model2.evaluate(test_generator, steps=test_generator.samples/test_generator.batch_size, verbose=1)
end=time.time()
print(model2.metrics_names)
print(test_output_2)
print("testing time : "+ str(end-start))
# Out:
# 17/17 [==============================] - 3s 140ms/step - loss: 0.0646 - accuracy: 0.9825 - mse: 0.0148
# ['loss', 'accuracy', 'mse']
# [0.06464745104312897, 0.9824561476707458, 0.014809038490056992]
# testing time : 2.748819351196289

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


#Y_pred = model1.predict_generator(validation_generator, 171 // batch_size+1)
Y_pred=model2.predict(test_generator,test_generator.samples//batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
conf=confusion_matrix(test_generator.classes, y_pred)
print(conf)
print('Classification Report')
target_names = ['Gluacoma', 'Normal']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# 18/18 [==============================] - 3s 144ms/step
# Confusion Matrix
# [[86  1]
#  [ 2 82]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Gluacoma       0.98      0.99      0.98        87
#       Normal       0.99      0.98      0.98        84
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171

# %%
classes = [0, 1]
# plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.BuGn)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %% [markdown]
# ### 3. VGG-19

# %%
fine_tune_epochs = 25
initial_epochs=25
batch_size=10
total_epochs =  initial_epochs + fine_tune_epochs

history_fine3 = model3.fit(train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=total_epochs, batch_size =batch_size,
      validation_data=validation_generator,
     #initial_epoch=50,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
# Out:
# Epoch 1/50
# 78/78 [==============================] - 48s 607ms/step - loss: 0.2133 - accuracy: 0.9439 - val_loss: 1.1204 - val_accuracy: 0.3125
# Epoch 2/50
# 78/78 [==============================] - 47s 596ms/step - loss: 0.2037 - accuracy: 0.9324 - val_loss: 0.9291 - val_accuracy: 0.3616
# Epoch 3/50
# 78/78 [==============================] - 47s 604ms/step - loss: 0.1777 - accuracy: 0.9388 - val_loss: 0.5315 - val_accuracy: 0.7299
# Epoch 4/50
# 78/78 [==============================] - 47s 608ms/step - loss: 0.1755 - accuracy: 0.9452 - val_loss: 0.3643 - val_accuracy: 0.8527
# Epoch 5/50
# 78/78 [==============================] - 47s 607ms/step - loss: 0.1473 - accuracy: 0.9515 - val_loss: 0.2654 - val_accuracy: 0.9152
# Epoch 6/50
# 78/78 [==============================] - 47s 606ms/step - loss: 0.1581 - accuracy: 0.9464 - val_loss: 0.2722 - val_accuracy: 0.9129
# Epoch 7/50
# 78/78 [==============================] - 47s 605ms/step - loss: 0.1396 - accuracy: 0.9617 - val_loss: 0.2245 - val_accuracy: 0.9286
# Epoch 8/50
# 78/78 [==============================] - 47s 601ms/step - loss: 0.1272 - accuracy: 0.9605 - val_loss: 0.1818 - val_accuracy: 0.9397
# Epoch 9/50
# 78/78 [==============================] - 47s 597ms/step - loss: 0.1328 - accuracy: 0.9592 - val_loss: 0.1788 - val_accuracy: 0.9420
# Epoch 10/50
# 78/78 [==============================] - 47s 597ms/step - loss: 0.1136 - accuracy: 0.9681 - val_loss: 0.2049 - val_accuracy: 0.9286
# Epoch 11/50
# 78/78 [==============================] - 47s 597ms/step - loss: 0.1181 - accuracy: 0.9656 - val_loss: 0.2086 - val_accuracy: 0.9330
# Epoch 12/50
# 78/78 [==============================] - 47s 597ms/step - loss: 0.1182 - accuracy: 0.9630 - val_loss: 0.1964 - val_accuracy: 0.9420
# Epoch 13/50
# 78/78 [==============================] - 47s 596ms/step - loss: 0.1206 - accuracy: 0.9630 - val_loss: 0.2020 - val_accuracy: 0.9397
# Epoch 14/50
# 78/78 [==============================] - 47s 596ms/step - loss: 0.1192 - accuracy: 0.9643 - val_loss: 0.2090 - val_accuracy: 0.9375
# Epoch 15/50
# 78/78 [==============================] - 48s 614ms/step - loss: 0.1012 - accuracy: 0.9745 - val_loss: 0.2025 - val_accuracy: 0.9420
# Epoch 16/50
# 78/78 [==============================] - 47s 605ms/step - loss: 0.1093 - accuracy: 0.9694 - val_loss: 0.2282 - val_accuracy: 0.9375
# Epoch 17/50
# 78/78 [==============================] - 47s 603ms/step - loss: 0.0916 - accuracy: 0.9758 - val_loss: 0.2102 - val_accuracy: 0.9375
# Epoch 18/50
# 78/78 [==============================] - 47s 597ms/step - loss: 0.0922 - accuracy: 0.9758 - val_loss: 0.2484 - val_accuracy: 0.9263
# Epoch 19/50
# 78/78 [==============================] - 47s 603ms/step - loss: 0.0960 - accuracy: 0.9707 - val_loss: 0.2411 - val_accuracy: 0.9330
# Epoch 20/50
# 78/78 [==============================] - 47s 602ms/step - loss: 0.1079 - accuracy: 0.9732 - val_loss: 0.1942 - val_accuracy: 0.9509
# Epoch 21/50
# 78/78 [==============================] - 46s 595ms/step - loss: 0.0800 - accuracy: 0.9809 - val_loss: 0.2367 - val_accuracy: 0.9353
# Epoch 22/50
# 78/78 [==============================] - 46s 595ms/step - loss: 0.0962 - accuracy: 0.9758 - val_loss: 0.2337 - val_accuracy: 0.9353
# Epoch 23/50
# 78/78 [==============================] - 47s 595ms/step - loss: 0.0872 - accuracy: 0.9758 - val_loss: 0.2324 - val_accuracy: 0.9353
# Epoch 24/50
# 78/78 [==============================] - 47s 596ms/step - loss: 0.0782 - accuracy: 0.9783 - val_loss: 0.2499 - val_accuracy: 0.9308
# Epoch 25/50
# 78/78 [==============================] - 47s 596ms/step - loss: 0.0880 - accuracy: 0.9796 - val_loss: 0.2348 - val_accuracy: 0.9353
# Epoch 26/50
# 78/78 [==============================] - 47s 595ms/step - loss: 0.0978 - accuracy: 0.9770 - val_loss: 0.1802 - val_accuracy: 0.9531
# Epoch 27/50
# 78/78 [==============================] - 47s 596ms/step - loss: 0.0758 - accuracy: 0.9847 - val_loss: 0.1864 - val_accuracy: 0.9576
# Epoch 28/50
# 78/78 [==============================] - 46s 595ms/step - loss: 0.0601 - accuracy: 0.9872 - val_loss: 0.2374 - val_accuracy: 0.9375
# Epoch 29/50
# 78/78 [==============================] - 46s 595ms/step - loss: 0.0776 - accuracy: 0.9770 - val_loss: 0.1912 - val_accuracy: 0.9554
# Epoch 30/50
# 78/78 [==============================] - 47s 596ms/step - loss: 0.0703 - accuracy: 0.9821 - val_loss: 0.2425 - val_accuracy: 0.9420
# Epoch 31/50
# 78/78 [==============================] - 47s 595ms/step - loss: 0.0785 - accuracy: 0.9834 - val_loss: 0.2161 - val_accuracy: 0.9397
# Epoch 32/50
# 78/78 [==============================] - 47s 595ms/step - loss: 0.0525 - accuracy: 0.9898 - val_loss: 0.2459 - val_accuracy: 0.9353
# Epoch 33/50
# 78/78 [==============================] - 46s 595ms/step - loss: 0.0722 - accuracy: 0.9809 - val_loss: 0.2488 - val_accuracy: 0.9353
# Epoch 34/50
# 78/78 [==============================] - 46s 595ms/step - loss: 0.0741 - accuracy: 0.9770 - val_loss: 0.1881 - val_accuracy: 0.9598
# Epoch 35/50
# 78/78 [==============================] - 47s 598ms/step - loss: 0.0666 - accuracy: 0.9821 - val_loss: 0.2607 - val_accuracy: 0.9353
# Epoch 36/50
# 78/78 [==============================] - 47s 604ms/step - loss: 0.0675 - accuracy: 0.9821 - val_loss: 0.2378 - val_accuracy: 0.9420
# Epoch 37/50
# 78/78 [==============================] - 47s 597ms/step - loss: 0.0725 - accuracy: 0.9758 - val_loss: 0.2655 - val_accuracy: 0.9420
# Epoch 38/50
# 78/78 [==============================] - 47s 598ms/step - loss: 0.0665 - accuracy: 0.9809 - val_loss: 0.2139 - val_accuracy: 0.9531
# Epoch 39/50
# 78/78 [==============================] - 47s 598ms/step - loss: 0.0703 - accuracy: 0.9770 - val_loss: 0.2661 - val_accuracy: 0.9375
# Epoch 40/50
# 78/78 [==============================] - 47s 597ms/step - loss: 0.0460 - accuracy: 0.9872 - val_loss: 0.3079 - val_accuracy: 0.9308
# Epoch 41/50
# 78/78 [==============================] - 47s 598ms/step - loss: 0.0451 - accuracy: 0.9898 - val_loss: 0.2664 - val_accuracy: 0.9375
# Epoch 42/50
# 78/78 [==============================] - 47s 598ms/step - loss: 0.0721 - accuracy: 0.9783 - val_loss: 0.2208 - val_accuracy: 0.9487
# Epoch 43/50
# 78/78 [==============================] - 47s 598ms/step - loss: 0.0468 - accuracy: 0.9898 - val_loss: 0.2390 - val_accuracy: 0.9420
# Epoch 44/50
# 78/78 [==============================] - 47s 598ms/step - loss: 0.0651 - accuracy: 0.9796 - val_loss: 0.2285 - val_accuracy: 0.9487
# Epoch 45/50
# 78/78 [==============================] - 47s 598ms/step - loss: 0.0466 - accuracy: 0.9847 - val_loss: 0.2035 - val_accuracy: 0.9554
# Epoch 46/50
# 78/78 [==============================] - 47s 600ms/step - loss: 0.0750 - accuracy: 0.9758 - val_loss: 0.2036 - val_accuracy: 0.9531
# Epoch 47/50
# 78/78 [==============================] - 47s 597ms/step - loss: 0.0388 - accuracy: 0.9898 - val_loss: 0.2620 - val_accuracy: 0.9397
# Epoch 48/50
# 78/78 [==============================] - 47s 597ms/step - loss: 0.0513 - accuracy: 0.9860 - val_loss: 0.2178 - val_accuracy: 0.9487
# Epoch 49/50
# 78/78 [==============================] - 47s 598ms/step - loss: 0.0566 - accuracy: 0.9885 - val_loss: 0.2082 - val_accuracy: 0.9531
# Epoch 50/50
# 78/78 [==============================] - 47s 598ms/step - loss: 0.0532 - accuracy: 0.9834 - val_loss: 0.1944 - val_accuracy: 0.9598

# %%
model3.save('SavedModels/IEEE Updated/Tuned/VGG19.h5')

# %%
acc = history_fine3.history['accuracy']
val_acc = history_fine3.history['val_accuracy']

loss = history_fine3.history['loss']
val_loss = history_fine3.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.suptitle('VGG19 on IEEE Updated(Tuned)', fontsize=14, fontweight='bold')
plt.xlabel('epoch')
plt.show()

# %%
start=time.time()
test_output_3= model3.evaluate(test_generator, steps=test_generator.samples/test_generator.batch_size, verbose=1)
end=time.time()
print(model3.metrics_names)
print(test_output_3)
print("testing time : "+ str(end-start))
# Out:
# 17/17 [==============================] - 4s 207ms/step - loss: 0.0871 - accuracy: 0.9474
# ['loss', 'accuracy']
# [0.08709820359945297, 0.9473684430122375]
# testing time : 3.735966444015503

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


#Y_pred = model1.predict_generator(validation_generator, 171 // batch_size+1)
Y_pred=model3.predict(test_generator,test_generator.samples//batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
conf=confusion_matrix(test_generator.classes, y_pred)
print(conf)
print('Classification Report')
target_names = ['Gluacoma', 'Normal']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# 18/18 [==============================] - 5s 296ms/step
# Confusion Matrix
# [[87  0]
#  [ 9 75]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Gluacoma       0.91      1.00      0.95        87
#       Normal       1.00      0.89      0.94        84
#
#     accuracy                           0.95       171
#    macro avg       0.95      0.95      0.95       171
# weighted avg       0.95      0.95      0.95       171

# %%
import itertools
classes = [0, 1]
# plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.BuGn)
plt.title("Confusion Matrix Tuned IEEE_Updated VGG19")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %% [markdown]
# ### 4. MobileNet V2

# %%
fine_tune_epochs = 25
initial_epochs=25
batch_size=10
total_epochs =  initial_epochs + fine_tune_epochs

history_fine4 = model4.fit(train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=total_epochs, batch_size =batch_size,
      validation_data=validation_generator,
     #initial_epoch=50,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
# Out:
# Epoch 1/50
# 78/78 [==============================] - 22s 222ms/step - loss: 0.4005 - accuracy: 0.8367 - val_loss: 0.5574 - val_accuracy: 0.6942
# Epoch 2/50
# 78/78 [==============================] - 14s 185ms/step - loss: 0.1928 - accuracy: 0.9503 - val_loss: 0.4488 - val_accuracy: 0.7455
# Epoch 3/50
# 78/78 [==============================] - 14s 185ms/step - loss: 0.1629 - accuracy: 0.9464 - val_loss: 0.3458 - val_accuracy: 0.8304
# Epoch 4/50
# 78/78 [==============================] - 14s 184ms/step - loss: 0.1351 - accuracy: 0.9541 - val_loss: 0.2621 - val_accuracy: 0.9040
# Epoch 5/50
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0998 - accuracy: 0.9668 - val_loss: 0.2115 - val_accuracy: 0.9286
# Epoch 6/50
# 78/78 [==============================] - 14s 185ms/step - loss: 0.1106 - accuracy: 0.9681 - val_loss: 0.1781 - val_accuracy: 0.9420
# Epoch 7/50
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0956 - accuracy: 0.9719 - val_loss: 0.1521 - val_accuracy: 0.9554
# Epoch 8/50
# 78/78 [==============================] - 14s 185ms/step - loss: 0.0686 - accuracy: 0.9885 - val_loss: 0.1345 - val_accuracy: 0.9554
# Epoch 9/50
# 78/78 [==============================] - 14s 185ms/step - loss: 0.0926 - accuracy: 0.9745 - val_loss: 0.1137 - val_accuracy: 0.9665
# Epoch 10/50
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0857 - accuracy: 0.9707 - val_loss: 0.1045 - val_accuracy: 0.9688
# Epoch 11/50
# 78/78 [==============================] - 14s 185ms/step - loss: 0.0805 - accuracy: 0.9783 - val_loss: 0.0905 - val_accuracy: 0.9732
# Epoch 12/50
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0577 - accuracy: 0.9847 - val_loss: 0.0841 - val_accuracy: 0.9710
# Epoch 13/50
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0512 - accuracy: 0.9809 - val_loss: 0.0800 - val_accuracy: 0.9754
# Epoch 14/50
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0417 - accuracy: 0.9860 - val_loss: 0.0739 - val_accuracy: 0.9754
# Epoch 15/50
# 78/78 [==============================] - 15s 187ms/step - loss: 0.0639 - accuracy: 0.9834 - val_loss: 0.0730 - val_accuracy: 0.9799
# Epoch 16/50
# 78/78 [==============================] - 15s 191ms/step - loss: 0.0433 - accuracy: 0.9911 - val_loss: 0.0715 - val_accuracy: 0.9777
# Epoch 17/50
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0515 - accuracy: 0.9847 - val_loss: 0.0722 - val_accuracy: 0.9754
# Epoch 18/50
# 78/78 [==============================] - 15s 188ms/step - loss: 0.0380 - accuracy: 0.9936 - val_loss: 0.0703 - val_accuracy: 0.9777
# Epoch 19/50
# 78/78 [==============================] - 14s 185ms/step - loss: 0.0390 - accuracy: 0.9885 - val_loss: 0.0732 - val_accuracy: 0.9754
# Epoch 20/50
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0240 - accuracy: 0.9987 - val_loss: 0.0725 - val_accuracy: 0.9710
# Epoch 21/50
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0391 - accuracy: 0.9898 - val_loss: 0.0684 - val_accuracy: 0.9732
# Epoch 22/50
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0426 - accuracy: 0.9847 - val_loss: 0.0687 - val_accuracy: 0.9754
# Epoch 23/50
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0315 - accuracy: 0.9898 - val_loss: 0.0694 - val_accuracy: 0.9754
# Epoch 24/50
# 78/78 [==============================] - 14s 183ms/step - loss: 0.0186 - accuracy: 0.9987 - val_loss: 0.0709 - val_accuracy: 0.9754
# Epoch 25/50
# 78/78 [==============================] - 14s 183ms/step - loss: 0.0304 - accuracy: 0.9936 - val_loss: 0.0710 - val_accuracy: 0.9732
# Epoch 26/50
# 78/78 [==============================] - 14s 183ms/step - loss: 0.0511 - accuracy: 0.9821 - val_loss: 0.0668 - val_accuracy: 0.9710
# Epoch 27/50
# 78/78 [==============================] - 14s 183ms/step - loss: 0.0549 - accuracy: 0.9783 - val_loss: 0.0648 - val_accuracy: 0.9754
# Epoch 28/50
# 78/78 [==============================] - 14s 183ms/step - loss: 0.0195 - accuracy: 0.9949 - val_loss: 0.0667 - val_accuracy: 0.9710
# Epoch 29/50
# 78/78 [==============================] - 14s 183ms/step - loss: 0.0180 - accuracy: 0.9987 - val_loss: 0.0684 - val_accuracy: 0.9732
# Epoch 30/50
# 78/78 [==============================] - 14s 183ms/step - loss: 0.0296 - accuracy: 0.9936 - val_loss: 0.0691 - val_accuracy: 0.9710
# Epoch 31/50
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0314 - accuracy: 0.9911 - val_loss: 0.0829 - val_accuracy: 0.9710
# Epoch 32/50
# 78/78 [==============================] - 15s 187ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.0835 - val_accuracy: 0.9710
# Epoch 33/50
# 78/78 [==============================] - 15s 189ms/step - loss: 0.0333 - accuracy: 0.9898 - val_loss: 0.0750 - val_accuracy: 0.9732
# Epoch 34/50
# 78/78 [==============================] - 14s 185ms/step - loss: 0.0467 - accuracy: 0.9834 - val_loss: 0.0761 - val_accuracy: 0.9732
# Epoch 35/50
# 78/78 [==============================] - 15s 191ms/step - loss: 0.0152 - accuracy: 0.9987 - val_loss: 0.0809 - val_accuracy: 0.9732
# Epoch 36/50
# 78/78 [==============================] - 15s 189ms/step - loss: 0.0425 - accuracy: 0.9911 - val_loss: 0.0842 - val_accuracy: 0.9710
# Epoch 37/50
# 78/78 [==============================] - 15s 187ms/step - loss: 0.0217 - accuracy: 0.9949 - val_loss: 0.1001 - val_accuracy: 0.9710
# Epoch 38/50
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0196 - accuracy: 0.9962 - val_loss: 0.1032 - val_accuracy: 0.9710
# Epoch 39/50
# 78/78 [==============================] - 15s 187ms/step - loss: 0.0357 - accuracy: 0.9898 - val_loss: 0.0892 - val_accuracy: 0.9710
# Epoch 40/50
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0301 - accuracy: 0.9872 - val_loss: 0.0890 - val_accuracy: 0.9732
# Epoch 41/50
# 78/78 [==============================] - 15s 187ms/step - loss: 0.0372 - accuracy: 0.9885 - val_loss: 0.0997 - val_accuracy: 0.9688
# Epoch 42/50
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0282 - accuracy: 0.9923 - val_loss: 0.1233 - val_accuracy: 0.9643
# Epoch 43/50
# 78/78 [==============================] - 15s 187ms/step - loss: 0.0106 - accuracy: 0.9974 - val_loss: 0.1200 - val_accuracy: 0.9665
# Epoch 44/50
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0281 - accuracy: 0.9898 - val_loss: 0.1096 - val_accuracy: 0.9688
# Epoch 45/50
# 78/78 [==============================] - 15s 187ms/step - loss: 0.0157 - accuracy: 0.9962 - val_loss: 0.1223 - val_accuracy: 0.9665
# Epoch 46/50
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0292 - accuracy: 0.9885 - val_loss: 0.1113 - val_accuracy: 0.9688
# Epoch 47/50
# 78/78 [==============================] - 15s 186ms/step - loss: 0.0106 - accuracy: 0.9987 - val_loss: 0.1145 - val_accuracy: 0.9665
# Epoch 48/50
# 78/78 [==============================] - 15s 187ms/step - loss: 0.0104 - accuracy: 0.9974 - val_loss: 0.1156 - val_accuracy: 0.9665
# Epoch 49/50
# 78/78 [==============================] - 15s 187ms/step - loss: 0.0052 - accuracy: 0.9987 - val_loss: 0.1122 - val_accuracy: 0.9688
# Epoch 50/50
# 78/78 [==============================] - 15s 187ms/step - loss: 0.0387 - accuracy: 0.9860 - val_loss: 0.1125 - val_accuracy: 0.9688

# %%
model4.save('SavedModels/IEEE Updated/Tuned/MobileNet.h5')

# %%
acc = history_fine4.history['accuracy']
val_acc = history_fine4.history['val_accuracy']

loss = history_fine4.history['loss']
val_loss = history_fine4.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.suptitle('MobileNet V2 on IEEE Updated(Tuned)', fontsize=14, fontweight='bold')
plt.xlabel('epoch')
plt.show()

# %%
start=time.time()
test_output_4= model4.evaluate(test_generator, steps=test_generator.samples/test_generator.batch_size, verbose=1)
end=time.time()
print(model4.metrics_names)
print(test_output_4)
print("testing time : "+ str(end-start))
# Out:
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0292 - accuracy: 0.9942
# ['loss', 'accuracy']
# [0.029156522825360298, 0.9941520690917969]
# testing time : 1.8445706367492676

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


#Y_pred = model1.predict_generator(validation_generator, 171 // batch_size+1)
Y_pred=model4.predict(test_generator,test_generator.samples//batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
conf=confusion_matrix(test_generator.classes, y_pred)
print(conf)
print('Classification Report')
target_names = ['Gluacoma', 'Normal']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# 18/18 [==============================] - 2s 61ms/step
# Confusion Matrix
# [[86  1]
#  [ 0 84]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Gluacoma       1.00      0.99      0.99        87
#       Normal       0.99      1.00      0.99        84
#
#     accuracy                           0.99       171
#    macro avg       0.99      0.99      0.99       171
# weighted avg       0.99      0.99      0.99       171

# %%
classes = [0, 1]
# plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.BuGn)
plt.title("Confusion Matrix Tuned IEEE Updated MobileNetV2 ")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %% [markdown]
# ## ResNet50

# %%
fine_tune_epochs = 25
initial_epochs=25
batch_size=10
total_epochs =  initial_epochs + fine_tune_epochs

history_fine5 = model5.fit(train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=total_epochs, batch_size =batch_size,
      validation_data=validation_generator,
     #initial_epoch=50,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
# Out:
# Epoch 1/50
# 78/78 [==============================] - 45s 422ms/step - loss: 0.3810 - accuracy: 0.8406 - val_loss: 0.9807 - val_accuracy: 0.3125
# Epoch 2/50
# 78/78 [==============================] - 32s 410ms/step - loss: 0.3026 - accuracy: 0.8878 - val_loss: 1.0956 - val_accuracy: 0.3125
# Epoch 3/50
# 78/78 [==============================] - 33s 417ms/step - loss: 0.2205 - accuracy: 0.9171 - val_loss: 1.4110 - val_accuracy: 0.3125
# Epoch 4/50
# 78/78 [==============================] - 33s 417ms/step - loss: 0.1896 - accuracy: 0.9298 - val_loss: 2.2314 - val_accuracy: 0.3125
# Epoch 5/50
# 78/78 [==============================] - 33s 417ms/step - loss: 0.2013 - accuracy: 0.9273 - val_loss: 2.0849 - val_accuracy: 0.3125
# Epoch 6/50
# 78/78 [==============================] - 33s 417ms/step - loss: 0.1955 - accuracy: 0.9235 - val_loss: 0.5804 - val_accuracy: 0.7076
# Epoch 7/50
# 78/78 [==============================] - 33s 416ms/step - loss: 0.1609 - accuracy: 0.9464 - val_loss: 4.1500 - val_accuracy: 0.3125
# Epoch 8/50
# 78/78 [==============================] - 33s 416ms/step - loss: 0.1750 - accuracy: 0.9337 - val_loss: 7.5994 - val_accuracy: 0.3125
# Epoch 9/50
# 78/78 [==============================] - 33s 416ms/step - loss: 0.1808 - accuracy: 0.9413 - val_loss: 1.5461 - val_accuracy: 0.3884
# Epoch 10/50
# 78/78 [==============================] - 33s 416ms/step - loss: 0.1616 - accuracy: 0.9362 - val_loss: 10.4917 - val_accuracy: 0.3125
# Epoch 11/50
# 78/78 [==============================] - 33s 416ms/step - loss: 0.1347 - accuracy: 0.9515 - val_loss: 0.9475 - val_accuracy: 0.5737
# Epoch 12/50
# 78/78 [==============================] - 33s 417ms/step - loss: 0.1335 - accuracy: 0.9592 - val_loss: 12.3558 - val_accuracy: 0.3125
# Epoch 13/50
# 78/78 [==============================] - 33s 417ms/step - loss: 0.1478 - accuracy: 0.9503 - val_loss: 0.5920 - val_accuracy: 0.6987
# Epoch 14/50
# 78/78 [==============================] - 33s 416ms/step - loss: 0.1377 - accuracy: 0.9541 - val_loss: 1.3558 - val_accuracy: 0.6830
# Epoch 15/50
# 78/78 [==============================] - 33s 416ms/step - loss: 0.1244 - accuracy: 0.9630 - val_loss: 0.5743 - val_accuracy: 0.8259
# Epoch 16/50
# 78/78 [==============================] - 33s 417ms/step - loss: 0.1609 - accuracy: 0.9503 - val_loss: 4.7021 - val_accuracy: 0.3125
# Epoch 17/50
# 78/78 [==============================] - 33s 416ms/step - loss: 0.0906 - accuracy: 0.9656 - val_loss: 18.4042 - val_accuracy: 0.3125
# Epoch 18/50
# 78/78 [==============================] - 33s 416ms/step - loss: 0.1258 - accuracy: 0.9605 - val_loss: 2.5368 - val_accuracy: 0.3125
# Epoch 19/50
# 78/78 [==============================] - 33s 416ms/step - loss: 0.1261 - accuracy: 0.9566 - val_loss: 0.4289 - val_accuracy: 0.8304
# Epoch 20/50
# 78/78 [==============================] - 33s 416ms/step - loss: 0.0570 - accuracy: 0.9770 - val_loss: 0.6876 - val_accuracy: 0.7589
# Epoch 21/50
# 78/78 [==============================] - 33s 417ms/step - loss: 0.1405 - accuracy: 0.9528 - val_loss: 2.2555 - val_accuracy: 0.6875
# Epoch 22/50
# 78/78 [==============================] - 33s 416ms/step - loss: 0.0852 - accuracy: 0.9783 - val_loss: 0.3103 - val_accuracy: 0.9531
# Epoch 23/50
# 78/78 [==============================] - 33s 417ms/step - loss: 0.1197 - accuracy: 0.9579 - val_loss: 0.2403 - val_accuracy: 0.9487
# Epoch 24/50
# 78/78 [==============================] - 33s 416ms/step - loss: 0.1063 - accuracy: 0.9605 - val_loss: 2.6859 - val_accuracy: 0.6875
# Epoch 25/50
# 78/78 [==============================] - 33s 417ms/step - loss: 0.1129 - accuracy: 0.9605 - val_loss: 0.3443 - val_accuracy: 0.8661
# Epoch 26/50
# 78/78 [==============================] - 33s 416ms/step - loss: 0.0772 - accuracy: 0.9656 - val_loss: 0.3584 - val_accuracy: 0.8884
# Epoch 27/50
# 78/78 [==============================] - 33s 416ms/step - loss: 0.0779 - accuracy: 0.9694 - val_loss: 10.6092 - val_accuracy: 0.3125
# Epoch 28/50
# 78/78 [==============================] - 33s 417ms/step - loss: 0.1184 - accuracy: 0.9694 - val_loss: 9.4047 - val_accuracy: 0.3125
# Epoch 29/50
# 78/78 [==============================] - 33s 416ms/step - loss: 0.1251 - accuracy: 0.9554 - val_loss: 0.6375 - val_accuracy: 0.7121
# Epoch 30/50
# 78/78 [==============================] - 33s 417ms/step - loss: 0.0780 - accuracy: 0.9745 - val_loss: 0.1841 - val_accuracy: 0.9509
# Epoch 31/50
# 78/78 [==============================] - 33s 417ms/step - loss: 0.0582 - accuracy: 0.9745 - val_loss: 5.0057 - val_accuracy: 0.3214
# Epoch 32/50
# 78/78 [==============================] - 33s 417ms/step - loss: 0.0657 - accuracy: 0.9758 - val_loss: 11.8654 - val_accuracy: 0.3125
# Epoch 33/50
# 78/78 [==============================] - 33s 417ms/step - loss: 0.0801 - accuracy: 0.9719 - val_loss: 1.4322 - val_accuracy: 0.3996
# Epoch 34/50
# 78/78 [==============================] - 33s 417ms/step - loss: 0.0999 - accuracy: 0.9681 - val_loss: 24.1528 - val_accuracy: 0.3125
# Epoch 35/50
# 78/78 [==============================] - 33s 418ms/step - loss: 0.1113 - accuracy: 0.9579 - val_loss: 0.2850 - val_accuracy: 0.9531
# Epoch 36/50
# 78/78 [==============================] - 33s 419ms/step - loss: 0.0858 - accuracy: 0.9719 - val_loss: 0.3663 - val_accuracy: 0.9241
# Epoch 37/50
# 78/78 [==============================] - 33s 418ms/step - loss: 0.1531 - accuracy: 0.9490 - val_loss: 12.6585 - val_accuracy: 0.3125
# Epoch 38/50
# 78/78 [==============================] - 33s 418ms/step - loss: 0.1014 - accuracy: 0.9630 - val_loss: 23.8668 - val_accuracy: 0.3125
# Epoch 39/50
# 78/78 [==============================] - 33s 418ms/step - loss: 0.0556 - accuracy: 0.9809 - val_loss: 23.5019 - val_accuracy: 0.3125
# Epoch 40/50
# 78/78 [==============================] - 33s 418ms/step - loss: 0.1154 - accuracy: 0.9617 - val_loss: 0.3095 - val_accuracy: 0.9241
# Epoch 41/50
# 78/78 [==============================] - 33s 418ms/step - loss: 0.1342 - accuracy: 0.9541 - val_loss: 25.0326 - val_accuracy: 0.3125
# Epoch 42/50
# 78/78 [==============================] - 33s 418ms/step - loss: 0.0747 - accuracy: 0.9834 - val_loss: 0.2689 - val_accuracy: 0.9129
# Epoch 43/50
# 78/78 [==============================] - 33s 418ms/step - loss: 0.1375 - accuracy: 0.9694 - val_loss: 15.4069 - val_accuracy: 0.3125
# Epoch 44/50
# 78/78 [==============================] - 33s 418ms/step - loss: 0.0948 - accuracy: 0.9719 - val_loss: 17.4564 - val_accuracy: 0.3125
# Epoch 45/50
# 78/78 [==============================] - 33s 418ms/step - loss: 0.0685 - accuracy: 0.9732 - val_loss: 0.1545 - val_accuracy: 0.9509
# Epoch 46/50
# 78/78 [==============================] - 33s 418ms/step - loss: 0.0920 - accuracy: 0.9668 - val_loss: 9.8109 - val_accuracy: 0.3125
# Epoch 47/50
# 78/78 [==============================] - 33s 417ms/step - loss: 0.0992 - accuracy: 0.9732 - val_loss: 0.6309 - val_accuracy: 0.7545
# Epoch 48/50
# 78/78 [==============================] - 33s 418ms/step - loss: 0.0936 - accuracy: 0.9719 - val_loss: 1.1103 - val_accuracy: 0.6384
# Epoch 49/50
# 78/78 [==============================] - 33s 417ms/step - loss: 0.0828 - accuracy: 0.9668 - val_loss: 18.4239 - val_accuracy: 0.3125
# Epoch 50/50
# 78/78 [==============================] - 33s 419ms/step - loss: 0.0684 - accuracy: 0.9796 - val_loss: 0.1200 - val_accuracy: 0.9665

# %%
model5.save('SavedModels/IEEE Updated/Tuned/ResNet.h5')

# %%
acc = history_fine5.history['accuracy']
val_acc = history_fine5.history['val_accuracy']

loss = history_fine5.history['loss']
val_loss = history_fine5.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.suptitle('ResNet50 on IEEE Updated(Tuned)', fontsize=14, fontweight='bold')
plt.xlabel('epoch')
plt.show()

# %%
start=time.time()
test_output_5= model5.evaluate(test_generator, steps=test_generator.samples/test_generator.batch_size, verbose=1)
end=time.time()
print(model5.metrics_names)
print(test_output_5)
print("testing time : "+ str(end-start))
# Out:
# 17/17 [==============================] - 3s 190ms/step - loss: 0.0939 - accuracy: 0.9825
# ['loss', 'accuracy']
# [0.09392711520195007, 0.9824561476707458]
# testing time : 3.2704808712005615

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


#Y_pred = model1.predict_generator(validation_generator, 171 // batch_size+1)
Y_pred=model5.predict(test_generator,test_generator.samples//batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
conf=confusion_matrix(test_generator.classes, y_pred)
print(conf)
print('Classification Report')
target_names = ['Gluacoma', 'Normal']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# 18/18 [==============================] - 3s 140ms/step
# Confusion Matrix
# [[86  1]
#  [ 2 82]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Gluacoma       0.98      0.99      0.98        87
#       Normal       0.99      0.98      0.98        84
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171

# %%
classes = [0, 1]
# plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.BuGn)
plt.title("Confusion Matrix Tuned IEEE Updated ResNet50")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 12>()
#      10 fmt = 'd'
#      11 thresh = conf.max() / 2.
# ---> 12 for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
#      13     plt.text(j, i, format(conf[i, j], fmt),
#      14              horizontalalignment="center",
#      15              color="white" if conf[i, j] > thresh else "black")
#      17 plt.tight_layout()
#
# NameError: name 'itertools' is not defined

# %% [markdown]
# ### 6. Inception V3

# %%
fine_tune_epochs = 25
initial_epochs=25
batch_size=10
total_epochs =  initial_epochs + fine_tune_epochs

history_fine6 = model6.fit(train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=total_epochs, batch_size =batch_size,
      validation_data=validation_generator,
     #initial_epoch=50,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
# Out:
# Epoch 1/50
# 78/78 [==============================] - 36s 371ms/step - loss: 0.5205 - accuracy: 0.7296 - val_loss: 0.4924 - val_accuracy: 0.7500
# Epoch 2/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.2711 - accuracy: 0.8890 - val_loss: 0.3236 - val_accuracy: 0.8996
# Epoch 3/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1923 - accuracy: 0.9260 - val_loss: 0.2314 - val_accuracy: 0.9196
# Epoch 4/50
# 78/78 [==============================] - 24s 310ms/step - loss: 0.1698 - accuracy: 0.9324 - val_loss: 0.2138 - val_accuracy: 0.9129
# Epoch 5/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.1239 - accuracy: 0.9617 - val_loss: 0.2239 - val_accuracy: 0.8996
# Epoch 6/50
# 78/78 [==============================] - 25s 315ms/step - loss: 0.1112 - accuracy: 0.9605 - val_loss: 0.2109 - val_accuracy: 0.9040
# Epoch 7/50
# 78/78 [==============================] - 25s 316ms/step - loss: 0.0965 - accuracy: 0.9656 - val_loss: 0.2272 - val_accuracy: 0.9018
# Epoch 8/50
# 78/78 [==============================] - 25s 319ms/step - loss: 0.0652 - accuracy: 0.9796 - val_loss: 0.1901 - val_accuracy: 0.9219
# Epoch 9/50
# 78/78 [==============================] - 25s 315ms/step - loss: 0.0785 - accuracy: 0.9770 - val_loss: 0.1756 - val_accuracy: 0.9174
# Epoch 10/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0629 - accuracy: 0.9758 - val_loss: 0.1821 - val_accuracy: 0.9241
# Epoch 11/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0245 - accuracy: 0.9974 - val_loss: 0.1886 - val_accuracy: 0.9241
# Epoch 12/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0606 - accuracy: 0.9821 - val_loss: 0.1996 - val_accuracy: 0.9196
# Epoch 13/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0481 - accuracy: 0.9847 - val_loss: 0.1767 - val_accuracy: 0.9263
# Epoch 14/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0346 - accuracy: 0.9898 - val_loss: 0.1850 - val_accuracy: 0.9241
# Epoch 15/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0523 - accuracy: 0.9796 - val_loss: 0.1871 - val_accuracy: 0.9286
# Epoch 16/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0309 - accuracy: 0.9911 - val_loss: 0.1732 - val_accuracy: 0.9397
# Epoch 17/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0417 - accuracy: 0.9860 - val_loss: 0.1711 - val_accuracy: 0.9353
# Epoch 18/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0553 - accuracy: 0.9796 - val_loss: 0.1912 - val_accuracy: 0.9241
# Epoch 19/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0257 - accuracy: 0.9936 - val_loss: 0.1760 - val_accuracy: 0.9375
# Epoch 20/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0382 - accuracy: 0.9898 - val_loss: 0.1812 - val_accuracy: 0.9375
# Epoch 21/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0422 - accuracy: 0.9834 - val_loss: 0.1663 - val_accuracy: 0.9442
# Epoch 22/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0594 - accuracy: 0.9745 - val_loss: 0.1728 - val_accuracy: 0.9397
# Epoch 23/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0440 - accuracy: 0.9821 - val_loss: 0.1687 - val_accuracy: 0.9464
# Epoch 24/50
# 78/78 [==============================] - 24s 312ms/step - loss: 0.0262 - accuracy: 0.9962 - val_loss: 0.1536 - val_accuracy: 0.9487
# Epoch 25/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0532 - accuracy: 0.9796 - val_loss: 0.1497 - val_accuracy: 0.9554
# Epoch 26/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0235 - accuracy: 0.9949 - val_loss: 0.1551 - val_accuracy: 0.9487
# Epoch 27/50
# 78/78 [==============================] - 24s 312ms/step - loss: 0.0288 - accuracy: 0.9911 - val_loss: 0.1447 - val_accuracy: 0.9464
# Epoch 28/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0533 - accuracy: 0.9860 - val_loss: 0.1498 - val_accuracy: 0.9509
# Epoch 29/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0188 - accuracy: 0.9949 - val_loss: 0.1358 - val_accuracy: 0.9576
# Epoch 30/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0289 - accuracy: 0.9949 - val_loss: 0.1425 - val_accuracy: 0.9554
# Epoch 31/50
# 78/78 [==============================] - 24s 310ms/step - loss: 0.0130 - accuracy: 0.9962 - val_loss: 0.1296 - val_accuracy: 0.9598
# Epoch 32/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0308 - accuracy: 0.9860 - val_loss: 0.1312 - val_accuracy: 0.9509
# Epoch 33/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0402 - accuracy: 0.9847 - val_loss: 0.1345 - val_accuracy: 0.9531
# Epoch 34/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0340 - accuracy: 0.9872 - val_loss: 0.1265 - val_accuracy: 0.9554
# Epoch 35/50
# 78/78 [==============================] - 24s 312ms/step - loss: 0.0129 - accuracy: 0.9974 - val_loss: 0.1153 - val_accuracy: 0.9643
# Epoch 36/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0364 - accuracy: 0.9821 - val_loss: 0.1235 - val_accuracy: 0.9598
# Epoch 37/50
# 78/78 [==============================] - 25s 313ms/step - loss: 0.0438 - accuracy: 0.9834 - val_loss: 0.1130 - val_accuracy: 0.9643
# Epoch 38/50
# 78/78 [==============================] - 24s 311ms/step - loss: 0.0138 - accuracy: 0.9962 - val_loss: 0.1067 - val_accuracy: 0.9643
# Epoch 39/50
# 78/78 [==============================] - 24s 312ms/step - loss: 0.0264 - accuracy: 0.9911 - val_loss: 0.1132 - val_accuracy: 0.9665
# Epoch 40/50
# 78/78 [==============================] - 24s 312ms/step - loss: 0.0165 - accuracy: 0.9974 - val_loss: 0.1141 - val_accuracy: 0.9665
# Epoch 41/50
# 78/78 [==============================] - 24s 312ms/step - loss: 0.0128 - accuracy: 0.9974 - val_loss: 0.1143 - val_accuracy: 0.9665
# Epoch 42/50
# 78/78 [==============================] - 24s 312ms/step - loss: 0.0323 - accuracy: 0.9885 - val_loss: 0.1311 - val_accuracy: 0.9665
# Epoch 43/50
# 78/78 [==============================] - 24s 313ms/step - loss: 0.0504 - accuracy: 0.9758 - val_loss: 0.1214 - val_accuracy: 0.9665
# Epoch 44/50
# 78/78 [==============================] - 24s 313ms/step - loss: 0.0384 - accuracy: 0.9847 - val_loss: 0.1236 - val_accuracy: 0.9665
# Epoch 45/50
# 78/78 [==============================] - 24s 312ms/step - loss: 0.0188 - accuracy: 0.9936 - val_loss: 0.1254 - val_accuracy: 0.9665
# Epoch 46/50
# 78/78 [==============================] - 24s 313ms/step - loss: 0.0317 - accuracy: 0.9847 - val_loss: 0.1232 - val_accuracy: 0.9665
# Epoch 47/50
# 78/78 [==============================] - 24s 312ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.1196 - val_accuracy: 0.9665
# Epoch 48/50
# 78/78 [==============================] - 24s 312ms/step - loss: 0.0224 - accuracy: 0.9936 - val_loss: 0.1166 - val_accuracy: 0.9665
# Epoch 49/50
# 78/78 [==============================] - 24s 312ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.1102 - val_accuracy: 0.9688
# Epoch 50/50
# 78/78 [==============================] - 24s 313ms/step - loss: 0.0273 - accuracy: 0.9936 - val_loss: 0.1278 - val_accuracy: 0.9621

# %%
model6.save('SavedModels/IEEE Updated/Tuned/Inception.h5')

# %%
acc = history_fine6.history['accuracy']
val_acc = history_fine6.history['val_accuracy']

loss = history_fine6.history['loss']
val_loss = history_fine6.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.suptitle('InceptionV3 on IEEE Updated(Tuned)', fontsize=14, fontweight='bold')
plt.xlabel('epoch')
plt.show()

# %%
start=time.time()
test_output_6= model6.evaluate(test_generator, steps=test_generator.samples/test_generator.batch_size, verbose=1)
end=time.time()
print(model6.metrics_names)
print(test_output_6)
print("testing time : "+ str(end-start))
# Out:
# 17/17 [==============================] - 3s 177ms/step - loss: 0.0622 - accuracy: 0.9766
# ['loss', 'accuracy']
# [0.06224505230784416, 0.9766082167625427]
# testing time : 3.0259628295898438

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


#Y_pred = model1.predict_generator(validation_generator, 171 // batch_size+1)
Y_pred=model6.predict(test_generator,test_generator.samples//batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
conf=confusion_matrix(test_generator.classes, y_pred)
print(conf)
print('Classification Report')
target_names = ['Gluacoma', 'Normal']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# 18/18 [==============================] - 3s 95ms/step
# Confusion Matrix
# [[87  0]
#  [ 4 80]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Gluacoma       0.96      1.00      0.98        87
#       Normal       1.00      0.95      0.98        84
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171

# %%
import itertools
classes = [0, 1]
# plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.BuGn)
plt.title("Confusion Matrix Tuned IEEE Updated InceptionV3")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')
