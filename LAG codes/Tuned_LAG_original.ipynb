# %%
from keras.preprocessing.image import ImageDataGenerator
from tensorflow import keras

# %%
import tensorflow as tf
from keras.layers import Activation
from keras.utils.generic_utils import get_custom_objects
from keras import backend as K
from keras.layers import Conv2D, Lambda, MaxPooling2D, BatchNormalization, concatenate, GlobalAveragePooling2D, Dense
from keras.models import Model
from tensorflow.keras.optimizers import SGD
import matplotlib.pyplot as plt 
import time

# %%
from keras.preprocessing.image import ImageDataGenerator
train_dataset = ImageDataGenerator(rescale=1./255)
test_dataset = ImageDataGenerator(rescale=1./255)
validation_dataset = ImageDataGenerator(rescale=1./255)

batchsize = 10
train_generator=train_dataset.flow_from_directory('lagoriginal/train/', 
                                                  target_size=(224, 224), 
                                                  batch_size=batchsize, 
                                                  class_mode='categorical')
 
validation_generator = validation_dataset.flow_from_directory('lagoriginal/val',
        target_size=(224, 224),
        batch_size=batchsize,
        class_mode='categorical',
        shuffle=False)
test_generator = test_dataset.flow_from_directory('lagoriginal/test/',
       target_size=(224, 224),
       batch_size=batchsize,
       class_mode='categorical',
       shuffle=False)
# Out:
# Found 3420 images belonging to 2 classes.
# Found 972 images belonging to 2 classes.
# Found 472 images belonging to 2 classes.

# %% [markdown]
# # Model Creation
# VGG Net: VGG network has simplest structure with 3 x 3 filter in each convolutional layer. There are two variant available VGG-16 and VGG1-9. In the image above VGG network is presneted.
# Transfer Learning: The VGGNet pre-trained on ImageNet and Inception module for transfer learning, and trained the newly formed neural networks using new datasets. The approach combines the advantages of the VGGNet and Inception module.

# %%
#DENSENET121
base_model1=keras.applications.DenseNet121(
    include_top=True, weights="imagenet", input_tensor=None, 
    input_shape=None, pooling=None,classes=1000,
    #classifier_activation='softmax'
)

#DenseNet169
base_model2=keras.applications.DenseNet169(
    include_top=True, weights="imagenet", input_tensor=None, 
    input_shape=None, pooling=None,classes=1000,
    #classifier_activation='softmax'
)


#VGG19
base_model3=keras.applications.vgg19.VGG19(
    include_top=True, weights='imagenet', input_tensor=None,
    input_shape=None, pooling=None, classes=1000,
    classifier_activation='softmax'
)

#MobileNet
base_model4=tf.keras.applications.MobileNetV2(
    include_top=True, weights='imagenet', input_tensor=None,
    input_shape=None, pooling=None, classes=1000,
    classifier_activation='softmax'
)

#ResNet50 
base_model5 = tf.keras.applications.resnet50.ResNet50(
    include_top=True, weights='imagenet', input_tensor=None,
    input_shape=None, pooling=None, classes=1000,
    classifier_activation='softmax')

#Inception V3
base_model6=tf.keras.applications.InceptionV3(
    include_top=True, weights="imagenet", input_tensor=None,
    input_shape=None, pooling=None, classes=1000,
    classifier_activation="softmax",
)

# %% [markdown]
# ## setting all layers as non-trainable

# %%
for layer in base_model1.layers:
    layer.trainable=False
for layer in base_model2.layers:
    layer.trainable=False
for layer in base_model3.layers:
    layer.trainable=False
for layer in base_model4.layers:
    layer.trainable=False
for layer in base_model5.layers:
    layer.trainable=False
for layer in base_model6.layers:
    layer.trainable=False

# %% [markdown]
# ## Defining custom activation function
# As per the paper, custom activation function Swish is used in place of Relu in the model.

# %%
from keras.layers import Activation
from keras.utils.generic_utils import get_custom_objects
from keras import backend as K
def swish(x):
    return (K.sigmoid(x) * x)
get_custom_objects().update({'swish': Activation(swish)})

# %% [markdown]
# ## Defining convolution batch normalization function with Swish activation

# %%
def Conv2d_BN(x, nb_filter,kernel_size, padding='same',strides=(1,1)):   
    x = Conv2D(nb_filter,kernel_size,padding=padding,strides=strides)(x)
    x = Lambda(swish)(x)
    x = BatchNormalization(axis=3)(x)  
    return x

# %% [markdown]
# ## Defining Inception Block:
# Inception Modules are used in Convolutional Neural Networks to allow for more efficient computation and deeper Networks through a dimensionality reduction with stacked 1×1 convolutions. The modules were designed to solve the problem of computational expense, as well as overfitting, among other issues.

# %%
def Inception(x,nb_filter):  
    branch1x1 = Conv2d_BN(x,nb_filter,(1,1), padding='same',strides=(1,1))  
  
    branch3x3 = Conv2d_BN(x,nb_filter,(1,1), padding='same',strides=(1,1))  
    branch3x3 = Conv2d_BN(branch3x3,nb_filter,(3,3), padding='same',strides=(1,1))  
  
    branch5x5 = Conv2d_BN(x,nb_filter,(1,1), padding='same',strides=(1,1))  
    branch5x5 = Conv2d_BN(branch5x5,nb_filter,(3,3), padding='same',strides=(1,1))
    branch5x5 = Conv2d_BN(branch5x5,nb_filter,(3,3), padding='same',strides=(1,1))
  
    branchpool = MaxPooling2D(pool_size=(3,3),strides=(1,1),padding='same')(x)  
    branchpool = Conv2d_BN(branchpool,nb_filter,(1,1),padding='same',strides=(1,1))  
  
    x = concatenate([branch1x1,branch3x3,branch5x5,branchpool],axis=3)    
    return x

# %% [markdown]
# ## Adding new layers in model architechture
# Global Average Pooling
# Fully connected layers are replaced by a global pooling layer to conduct the dimension reduction of feature maps.

# %%
#DenseNet121
x = base_model1.layers[-6].output


x = Conv2d_BN(x,512,(3,3),strides=(1,1),padding='same')  
x = MaxPooling2D(pool_size=(2,2),strides=(1,1),padding='same')(x) 

x = Inception(x,512)  
x = Inception(x,512)  

x = GlobalAveragePooling2D()(x)
predictions_1 = Dense(2, activation='softmax')(x)
model1 = Model(inputs=base_model1.input, outputs=predictions_1)

# %%
#DenseNet169
x = base_model2.layers[-6].output


x = Conv2d_BN(x,512,(3,3),strides=(1,1),padding='same')  
x = MaxPooling2D(pool_size=(2,2),strides=(1,1),padding='same')(x) 

x = Inception(x,512)  
x = Inception(x,512)  

x = GlobalAveragePooling2D()(x)
predictions_2 = Dense(2, activation='softmax')(x)
model2 = Model(inputs=base_model2.input, outputs=predictions_2)

# %%
#VGG-19
x = base_model3.layers[-6].output


x = Conv2d_BN(x,512,(3,3),strides=(1,1),padding='same')  
x = MaxPooling2D(pool_size=(2,2),strides=(1,1),padding='same')(x) 

x = Inception(x,512)  
x = Inception(x,512)  

x = GlobalAveragePooling2D()(x)
predictions_3 = Dense(2, activation='softmax')(x)
model3 = Model(inputs=base_model3.input, outputs=predictions_3)

# %%
#MobileNet V2
x = base_model4.layers[-6].output


x = Conv2d_BN(x,512,(3,3),strides=(1,1),padding='same')  
x = MaxPooling2D(pool_size=(2,2),strides=(1,1),padding='same')(x) 

x = Inception(x,512)  
x = Inception(x,512)  

x = GlobalAveragePooling2D()(x)
predictions_4 = Dense(2, activation='softmax')(x)
model4 = Model(inputs=base_model4.input, outputs=predictions_4)

# %%
#ResNet 50
x = base_model5.layers[-6].output


x = Conv2d_BN(x,512,(3,3),strides=(1,1),padding='same')  
x = MaxPooling2D(pool_size=(2,2),strides=(1,1),padding='same')(x) 

x = Inception(x,512)  
x = Inception(x,512)  

x = GlobalAveragePooling2D()(x)
predictions_5 = Dense(2, activation='softmax')(x)
model5 = Model(inputs=base_model5.input, outputs=predictions_5)

# %%
#Inception V3
x = base_model6.layers[-6].output


x = Conv2d_BN(x,512,(3,3),strides=(1,1),padding='same')  
x = MaxPooling2D(pool_size=(2,2),strides=(1,1),padding='same')(x) 

x = Inception(x,512)  
x = Inception(x,512)  

x = GlobalAveragePooling2D()(x)
predictions_6 = Dense(2, activation='softmax')(x)
model6 = Model(inputs=base_model6.input, outputs=predictions_6)

# %%
model1.summary()
model2.summary()
model3.summary()
model4.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0          ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 112, 112, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 112, 112, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 114, 114, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 56, 56, 64)   0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 56, 56, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 56, 56, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 56, 56, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 56, 56, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 56, 56, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 56, 56, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 56, 56, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 56, 56, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 56, 56, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 56, 56, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 56, 56, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 56, 56, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 56, 56, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 56, 56, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 56, 56, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 56, 56, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 56, 56, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 56, 56, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 56, 56, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 56, 56, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 28, 28, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 28, 28, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 28, 28, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#  conv3_block2_0_relu (Activatio  (None, 28, 28, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 28, 28, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 28, 28, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 28, 28, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 28, 28, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 28, 28, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 28, 28, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 28, 28, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 28, 28, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 28, 28, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 28, 28, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 28, 28, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 28, 28, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 28, 28, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 28, 28, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 28, 28, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 28, 28, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 28, 28, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 28, 28, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 28, 28, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 28, 28, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 28, 28, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 28, 28, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 28, 28, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 28, 28, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 28, 28, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 28, 28, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 28, 28, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 28, 28, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 28, 28, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 28, 28, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 28, 28, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 28, 28, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 28, 28, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 28, 28, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 28, 28, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 28, 28, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 28, 28, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 28, 28, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 28, 28, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 28, 28, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 28, 28, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 14, 14, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 14, 14, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 14, 14, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 14, 14, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block2_1_relu[0][0]']
#  conv4_block2_concat (Concatena  (None, 14, 14, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 14, 14, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 14, 14, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 14, 14, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 14, 14, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 14, 14, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 14, 14, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 14, 14, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 14, 14, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 14, 14, 416)  0          ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 14, 14, 416)  1664       ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 14, 14, 416)  0          ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 128)  53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block6_1_bn[0][0]']
#  n)
# ...
#
#  conv5_block30_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 7, 7, 1600)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 7, 7, 1600)  6400        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 7, 7, 1600)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 7, 7, 128)    204800      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 7, 7, 1632)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 7, 7, 1632)  6528        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 7, 7, 1632)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 7, 7, 128)    208896      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 7, 7, 512)    147968      ['conv5_block32_2_conv[0][0]']
#
#  lambda_15 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_109[0][0]']
#
#  batch_normalization_109 (Batch  (None, 7, 7, 512)   2048        ['lambda_15[0][0]']
#  Normalization)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 7, 7, 512)   0           ['batch_normalization_109[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 7, 7, 512)    262656      ['max_pooling2d_7[0][0]']
#
#  lambda_19 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_113[0][0]']
#
#  batch_normalization_113 (Batch  (None, 7, 7, 512)   2048        ['lambda_19[0][0]']
#  Normalization)
#
#  conv2d_111 (Conv2D)            (None, 7, 7, 512)    262656      ['max_pooling2d_7[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_113[0][0]']
#
#  lambda_17 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_111[0][0]']
#
#  lambda_20 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_114[0][0]']
#  batch_normalization_111 (Batch  (None, 7, 7, 512)   2048        ['lambda_17[0][0]']
#  Normalization)
#
#  batch_normalization_114 (Batch  (None, 7, 7, 512)   2048        ['lambda_20[0][0]']
#  Normalization)
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 7, 7, 512)   0           ['max_pooling2d_7[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 7, 7, 512)    262656      ['max_pooling2d_7[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_111[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_114[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 7, 7, 512)    262656      ['max_pooling2d_8[0][0]']
#
#  lambda_16 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_110[0][0]']
#
#  lambda_18 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_112[0][0]']
#
#  lambda_21 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_115[0][0]']
#
#  lambda_22 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_116[0][0]']
#
#  batch_normalization_110 (Batch  (None, 7, 7, 512)   2048        ['lambda_16[0][0]']
#  Normalization)
#
#  batch_normalization_112 (Batch  (None, 7, 7, 512)   2048        ['lambda_18[0][0]']
#  Normalization)
#
#  batch_normalization_115 (Batch  (None, 7, 7, 512)   2048        ['lambda_21[0][0]']
#  Normalization)
#
#  batch_normalization_116 (Batch  (None, 7, 7, 512)   2048        ['lambda_22[0][0]']
#  Normalization)
#
#  concatenate_4 (Concatenate)    (None, 7, 7, 2048)   0           ['batch_normalization_110[0][0]',
#                                                                   'batch_normalization_112[0][0]',
#                                                                   'batch_normalization_115[0][0]',
#                                                                   'batch_normalization_116[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 7, 7, 512)    1049088     ['concatenate_4[0][0]']
#
#  lambda_26 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_120[0][0]']
#
#  batch_normalization_120 (Batch  (None, 7, 7, 512)   2048        ['lambda_26[0][0]']
#  Normalization)
#
#  conv2d_118 (Conv2D)            (None, 7, 7, 512)    1049088     ['concatenate_4[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_120[0][0]']
#
#  lambda_24 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_118[0][0]']
#
#  lambda_27 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_121[0][0]']
#
#  batch_normalization_118 (Batch  (None, 7, 7, 512)   2048        ['lambda_24[0][0]']
#  Normalization)
#
#  batch_normalization_121 (Batch  (None, 7, 7, 512)   2048        ['lambda_27[0][0]']
#  Normalization)
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 7, 7, 2048)  0           ['concatenate_4[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 7, 7, 512)    1049088     ['concatenate_4[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_118[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_121[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 7, 7, 512)    1049088     ['max_pooling2d_9[0][0]']
#
#  lambda_23 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_117[0][0]']
#
#  lambda_25 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_119[0][0]']
#
#  lambda_28 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_122[0][0]']
#
#  lambda_29 (Lambda)             (None, 7, 7, 512)    0           ['conv2d_123[0][0]']
#
#  batch_normalization_117 (Batch  (None, 7, 7, 512)   2048        ['lambda_23[0][0]']
#  Normalization)
#  batch_normalization_119 (Batch  (None, 7, 7, 512)   2048        ['lambda_25[0][0]']
#  Normalization)
#
#  batch_normalization_122 (Batch  (None, 7, 7, 512)   2048        ['lambda_28[0][0]']
#  Normalization)
#
#  batch_normalization_123 (Batch  (None, 7, 7, 512)   2048        ['lambda_29[0][0]']
#  Normalization)
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
base_model1.trainable = True
base_model2.trainable = True
base_model3.trainable = True
base_model4.trainable = True
base_model5.trainable = True
base_model6.trainable = True

# %%
fine_tune_at = 100

# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model1.layers[:fine_tune_at]:
    layer.trainable = False

for layer in base_model2.layers[:fine_tune_at]:
    layer.trainable = False


for layer in base_model3.layers[:fine_tune_at]:
    layer.trainable = False

for layer in base_model4.layers[:fine_tune_at]:
    layer.trainable = False


for layer in base_model5.layers[:fine_tune_at]:
    layer.trainable = False

for layer in base_model6.layers[:fine_tune_at]:
    layer.trainable = False

# %%
base_learning_rate=0.0001

# %%
model1.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer = tf.keras.optimizers.RMSprop(learning_rate=base_learning_rate/10),
              metrics=['accuracy'])

model2.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer = tf.keras.optimizers.RMSprop(learning_rate=base_learning_rate/10),
              metrics=['accuracy'])

# %%
def comp():
    learning_rate=0.0001
    decay=1e-6
    momentum=0.8
    nesterov=True
    sgd_optimizer= SGD(lr = learning_rate, decay = decay, momentum = momentum, nesterov = nesterov)
    models=['VGG-19','MobileNet','ResNet50','Inception']
    
    for i in models:
        if i=='VGG-19':
            model3.compile(loss='categorical_crossentropy',optimizer=sgd_optimizer,metrics=['accuracy'])
        elif i=='MobileNet':
            model4.compile(loss='categorical_crossentropy',optimizer=sgd_optimizer,metrics=['accuracy'])
        elif i=='ResNet50':
            model5.compile(loss='categorical_crossentropy',optimizer=sgd_optimizer,metrics=['accuracy'])
        else:
            model6.compile(loss='categorical_crossentropy',optimizer=sgd_optimizer,metrics=['accuracy'])

        
if __name__ == "__main__":
    comp()
# Out:
# D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %% [markdown]
# # Training the Models

# %% [markdown]
# ### 1.DenseNet-121

# %%
#DenseNet121
import time
epochs =50
batch_size = 10

start = time.time()
history_1 = model1.fit(
      train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=epochs, batch_size =batch_size,
      validation_data=validation_generator,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
end = time.time()
print("Execution Time : ", (end - start))
# Out:
# Epoch 1/50
# D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\backend.py:5674: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Sigmoid activation and thus does not represent logits. Was this intended?
#   output, from_logits, "Sigmoid", "binary_crossentropy"
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9896\1281793367.py in <module>
#      11       validation_data=validation_generator,
#      12       validation_steps=validation_generator.samples/validation_generator.batch_size,
# ---> 13       verbose=1)
#      14 end = time.time()
#      15 print("Execution Time : ", (end - start))
#
# D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# D:\Anaconda\envs\tf-gpu\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# NotFoundError: Graph execution error:
#
# Detected at node 'model/conv4_block24_1_conv/Conv2D' defined at (most recent call last):
#     File "D:\Anaconda\envs\tf-gpu\lib\runpy.py", line 193, in _run_module_as_main
#       "__main__", mod_spec)
#     File "D:\Anaconda\envs\tf-gpu\lib\runpy.py", line 85, in _run_code
#       exec(code, run_globals)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#       app.start()
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "D:\Anaconda\envs\tf-gpu\lib\asyncio\base_events.py", line 523, in run_forever
#       self._run_once()
#     File "D:\Anaconda\envs\tf-gpu\lib\asyncio\base_events.py", line 1758, in _run_once
#       handle._run()
#     File "D:\Anaconda\envs\tf-gpu\lib\asyncio\events.py", line 88, in _run
#       self._context.run(self._callback, *self._args)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\ipykernel\ipkernel.py", line 390, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2915, in run_cell
#       raw_cell, store_history, silent, shell_futures)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#       return runner(coro)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#       coro.send(None)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3186, in run_cell_async
#       interactivity=interactivity, compiler=compiler, result=result)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#       if (await self.run_code(code, result,  async_=asy)):
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\Harsh Raj\AppData\Local\Temp\ipykernel_9896\1281793367.py", line 13, in <module>
#       verbose=1)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\engine\training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\engine\training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\engine\training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\engine\training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\engine\training.py", line 993, in train_step
#       y_pred = self(x, training=True)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\layers\convolutional\base_conv.py", line 283, in call
#       outputs = self.convolution_op(inputs, self.kernel)
#     File "D:\Anaconda\envs\tf-gpu\lib\site-packages\keras\layers\convolutional\base_conv.py", line 262, in convolution_op
#       name=self.__class__.__name__,
# Node: 'model/conv4_block24_1_conv/Conv2D'
# No algorithm worked!  Error messages:
#   Profiling failure on CUDNN engine 1#TC: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 17287424 bytes.
#   Profiling failure on CUDNN engine 1: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 17287424 bytes.
#   Profiling failure on CUDNN engine 0#TC: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777216 bytes.
#   Profiling failure on CUDNN engine 0: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777216 bytes.
#   Profiling failure on CUDNN engine 2#TC: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 24554496 bytes.
#   Profiling failure on CUDNN engine 2: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 24554496 bytes.
#   Profiling failure on CUDNN engine 4#TC: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 332693504 bytes.
#   Profiling failure on CUDNN engine 4: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 332693504 bytes.
#   Profiling failure on CUDNN engine 5#TC: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 55370752 bytes.
#   Profiling failure on CUDNN engine 5: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 55370752 bytes.
# 	 [[{{node model/conv4_block24_1_conv/Conv2D}}]] [Op:__inference_train_function_62882]

# %%
model1.save('SavedModels/LAG original/D121.h5')

# %%
acc = history_1.history['accuracy']
val_acc = history_1.history['val_accuracy']

loss = history_1.history['loss']
val_loss = history_1.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
plt.suptitle('D121 on LAG original', fontsize=14, fontweight='bold')
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
start=time.time()
test_output_1= model1.evaluate(test_generator, steps=test_generator.samples/test_generator.batch_size, verbose=1)
end=time.time()
print(model1.metrics_names)
print(test_output_1)
print("testing time : "+ str(end-start))
# Out:
# 47/47 [==============================] - 4s 75ms/step - loss: 0.3355 - accuracy: 0.8919 - mse: 0.0842
# ['loss', 'accuracy', 'mse']
# [0.3355254530906677, 0.8919491767883301, 0.08419220894575119]
# testing time : 3.8594677448272705

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


#Y_pred = model1.predict_generator(validation_generator, 171 // batch_size+1)
Y_pred=model1.predict(test_generator,test_generator.samples//batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)

conf=confusion_matrix(test_generator.classes, y_pred)
print(conf)
print('Classification Report')
target_names = ['Gluacoma', 'Normal']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# 48/48 [==============================] - 4s 73ms/step
# [[137  24]
#  [ 27 284]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Gluacoma       0.84      0.85      0.84       161
#       Normal       0.92      0.91      0.92       311
#
#     accuracy                           0.89       472
#    macro avg       0.88      0.88      0.88       472
# weighted avg       0.89      0.89      0.89       472

# %%
import itertools

# %%
classes = [0, 1]
# plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.BuGn)
plt.title("CNF D121 LAG original")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %% [markdown]
# ### DenseNet-169

# %%
#DenseNet169
import time
epochs =50
batch_size = 10

start = time.time()
history_2 = model2.fit(
      train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=epochs, batch_size =batch_size,
      validation_data=validation_generator,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
end = time.time()
print("Execution Time : ", (end - start))
# Out:
# Epoch 1/50
# 342/342 [==============================] - 65s 166ms/step - loss: 0.5337 - accuracy: 0.7406 - mse: 0.1775 - val_loss: 0.6352 - val_accuracy: 0.6420 - val_mse: 0.2223
# Epoch 2/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.4326 - accuracy: 0.8161 - mse: 0.1369 - val_loss: 0.4400 - val_accuracy: 0.8323 - val_mse: 0.1362
# Epoch 3/50
# 342/342 [==============================] - 54s 156ms/step - loss: 0.3770 - accuracy: 0.8389 - mse: 0.1168 - val_loss: 0.3479 - val_accuracy: 0.8765 - val_mse: 0.1027
# Epoch 4/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.3401 - accuracy: 0.8655 - mse: 0.1031 - val_loss: 0.3371 - val_accuracy: 0.8796 - val_mse: 0.0994
# Epoch 5/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.3088 - accuracy: 0.8822 - mse: 0.0917 - val_loss: 0.3207 - val_accuracy: 0.8765 - val_mse: 0.0946
# Epoch 6/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.2820 - accuracy: 0.8985 - mse: 0.0822 - val_loss: 0.3147 - val_accuracy: 0.8817 - val_mse: 0.0923
# Epoch 7/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.2714 - accuracy: 0.8971 - mse: 0.0792 - val_loss: 0.3125 - val_accuracy: 0.8796 - val_mse: 0.0915
# Epoch 8/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.2520 - accuracy: 0.9105 - mse: 0.0720 - val_loss: 0.2875 - val_accuracy: 0.8909 - val_mse: 0.0846
# Epoch 9/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.2354 - accuracy: 0.9152 - mse: 0.0668 - val_loss: 0.2930 - val_accuracy: 0.8889 - val_mse: 0.0859
# Epoch 10/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.2073 - accuracy: 0.9307 - mse: 0.0570 - val_loss: 0.2919 - val_accuracy: 0.8899 - val_mse: 0.0850
# Epoch 11/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.2154 - accuracy: 0.9260 - mse: 0.0603 - val_loss: 0.2773 - val_accuracy: 0.8889 - val_mse: 0.0811
# Epoch 12/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.1901 - accuracy: 0.9389 - mse: 0.0515 - val_loss: 0.2804 - val_accuracy: 0.8920 - val_mse: 0.0821
# Epoch 13/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.1783 - accuracy: 0.9433 - mse: 0.0479 - val_loss: 0.2971 - val_accuracy: 0.8858 - val_mse: 0.0860
# Epoch 14/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.1767 - accuracy: 0.9374 - mse: 0.0480 - val_loss: 0.2862 - val_accuracy: 0.9012 - val_mse: 0.0823
# Epoch 15/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.1701 - accuracy: 0.9465 - mse: 0.0451 - val_loss: 0.2906 - val_accuracy: 0.8889 - val_mse: 0.0847
# Epoch 16/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.1632 - accuracy: 0.9523 - mse: 0.0434 - val_loss: 0.2642 - val_accuracy: 0.8971 - val_mse: 0.0767
# Epoch 17/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.1462 - accuracy: 0.9541 - mse: 0.0380 - val_loss: 0.2685 - val_accuracy: 0.8981 - val_mse: 0.0777
# Epoch 18/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.1395 - accuracy: 0.9567 - mse: 0.0359 - val_loss: 0.2621 - val_accuracy: 0.8940 - val_mse: 0.0754
# Epoch 19/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.1413 - accuracy: 0.9535 - mse: 0.0368 - val_loss: 0.2634 - val_accuracy: 0.9023 - val_mse: 0.0763
# Epoch 20/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.1294 - accuracy: 0.9646 - mse: 0.0327 - val_loss: 0.2719 - val_accuracy: 0.9033 - val_mse: 0.0774
# Epoch 21/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.1211 - accuracy: 0.9640 - mse: 0.0303 - val_loss: 0.3183 - val_accuracy: 0.8858 - val_mse: 0.0899
# Epoch 22/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.1163 - accuracy: 0.9652 - mse: 0.0295 - val_loss: 0.2743 - val_accuracy: 0.8971 - val_mse: 0.0791
# Epoch 23/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.1024 - accuracy: 0.9743 - mse: 0.0246 - val_loss: 0.2821 - val_accuracy: 0.8951 - val_mse: 0.0807
# Epoch 24/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.1128 - accuracy: 0.9684 - mse: 0.0284 - val_loss: 0.2753 - val_accuracy: 0.8940 - val_mse: 0.0780
# Epoch 25/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.1045 - accuracy: 0.9751 - mse: 0.0255 - val_loss: 0.2712 - val_accuracy: 0.8930 - val_mse: 0.0776
# Epoch 26/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.0935 - accuracy: 0.9749 - mse: 0.0227 - val_loss: 0.2693 - val_accuracy: 0.8961 - val_mse: 0.0763
# Epoch 27/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.0940 - accuracy: 0.9792 - mse: 0.0225 - val_loss: 0.2825 - val_accuracy: 0.8961 - val_mse: 0.0798
# Epoch 28/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.0903 - accuracy: 0.9778 - mse: 0.0218 - val_loss: 0.2710 - val_accuracy: 0.9053 - val_mse: 0.0755
# Epoch 29/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.0873 - accuracy: 0.9769 - mse: 0.0208 - val_loss: 0.2748 - val_accuracy: 0.8992 - val_mse: 0.0767
# Epoch 30/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.0883 - accuracy: 0.9751 - mse: 0.0219 - val_loss: 0.2888 - val_accuracy: 0.8951 - val_mse: 0.0812
# Epoch 31/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.0731 - accuracy: 0.9833 - mse: 0.0164 - val_loss: 0.2823 - val_accuracy: 0.9033 - val_mse: 0.0775
# Epoch 32/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.0689 - accuracy: 0.9857 - mse: 0.0153 - val_loss: 0.3001 - val_accuracy: 0.8961 - val_mse: 0.0806
# Epoch 33/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.0734 - accuracy: 0.9825 - mse: 0.0166 - val_loss: 0.2717 - val_accuracy: 0.9053 - val_mse: 0.0754
# Epoch 34/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.0594 - accuracy: 0.9883 - mse: 0.0125 - val_loss: 0.2760 - val_accuracy: 0.9023 - val_mse: 0.0750
# Epoch 35/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.0638 - accuracy: 0.9836 - mse: 0.0144 - val_loss: 0.2840 - val_accuracy: 0.9023 - val_mse: 0.0774
# Epoch 36/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.0665 - accuracy: 0.9851 - mse: 0.0154 - val_loss: 0.2837 - val_accuracy: 0.9053 - val_mse: 0.0757
# Epoch 37/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.0549 - accuracy: 0.9898 - mse: 0.0114 - val_loss: 0.2903 - val_accuracy: 0.9043 - val_mse: 0.0765
# Epoch 38/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.0596 - accuracy: 0.9836 - mse: 0.0136 - val_loss: 0.2918 - val_accuracy: 0.8961 - val_mse: 0.0783
# Epoch 39/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.0604 - accuracy: 0.9836 - mse: 0.0144 - val_loss: 0.2895 - val_accuracy: 0.8992 - val_mse: 0.0792
# Epoch 40/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.0553 - accuracy: 0.9860 - mse: 0.0121 - val_loss: 0.3127 - val_accuracy: 0.8981 - val_mse: 0.0819
# Epoch 41/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.0540 - accuracy: 0.9874 - mse: 0.0120 - val_loss: 0.3106 - val_accuracy: 0.9012 - val_mse: 0.0801
# Epoch 42/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.0467 - accuracy: 0.9901 - mse: 0.0101 - val_loss: 0.3043 - val_accuracy: 0.9002 - val_mse: 0.0793
# Epoch 43/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.0516 - accuracy: 0.9877 - mse: 0.0117 - val_loss: 0.2924 - val_accuracy: 0.9012 - val_mse: 0.0763
# Epoch 44/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.0473 - accuracy: 0.9906 - mse: 0.0103 - val_loss: 0.3418 - val_accuracy: 0.8837 - val_mse: 0.0891
# Epoch 45/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.0470 - accuracy: 0.9909 - mse: 0.0098 - val_loss: 0.3012 - val_accuracy: 0.8961 - val_mse: 0.0793
# Epoch 46/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.0437 - accuracy: 0.9901 - mse: 0.0092 - val_loss: 0.2872 - val_accuracy: 0.9012 - val_mse: 0.0764
# Epoch 47/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.0465 - accuracy: 0.9868 - mse: 0.0105 - val_loss: 0.3070 - val_accuracy: 0.8981 - val_mse: 0.0806
# Epoch 48/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.0426 - accuracy: 0.9898 - mse: 0.0091 - val_loss: 0.3104 - val_accuracy: 0.8961 - val_mse: 0.0795
# Epoch 49/50
# 342/342 [==============================] - 54s 158ms/step - loss: 0.0423 - accuracy: 0.9915 - mse: 0.0090 - val_loss: 0.2903 - val_accuracy: 0.9043 - val_mse: 0.0753
# Epoch 50/50
# 342/342 [==============================] - 54s 157ms/step - loss: 0.0464 - accuracy: 0.9868 - mse: 0.0107 - val_loss: 0.3362 - val_accuracy: 0.8889 - val_mse: 0.0884
# Execution Time :  2705.15816283226

# %%
model2.save('SavedModels/LAG original/D169.h5')

# %%
acc = history_2.history['accuracy']
val_acc = history_2.history['val_accuracy']

loss = history_2.history['loss']
val_loss = history_2.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
plt.suptitle('D169 on LAG original', fontsize=14, fontweight='bold')
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
start=time.time()
test_output_2= model2.evaluate(test_generator, steps=test_generator.samples/test_generator.batch_size, verbose=1)
end=time.time()
print(model2.metrics_names)
print(test_output_2)
print("testing time : "+ str(end-start))
# Out:
# 47/47 [==============================] - 5s 92ms/step - loss: 0.2948 - accuracy: 0.8962 - mse: 0.0759
# ['loss', 'accuracy', 'mse']
# [0.29481104016304016, 0.8961864113807678, 0.07587882876396179]
# testing time : 4.669625282287598

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


#Y_pred = model1.predict_generator(validation_generator, 171 // batch_size+1)
Y_pred=model2.predict(test_generator,test_generator.samples//batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
conf=confusion_matrix(test_generator.classes, y_pred)
print(conf)
print('Classification Report')
target_names = ['Gluacoma', 'Normal']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# 48/48 [==============================] - 6s 89ms/step
# Confusion Matrix
# [[149  12]
#  [ 37 274]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Gluacoma       0.80      0.93      0.86       161
#       Normal       0.96      0.88      0.92       311
#
#     accuracy                           0.90       472
#    macro avg       0.88      0.90      0.89       472
# weighted avg       0.90      0.90      0.90       472

# %%
classes = [0, 1]
# plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.BuGn)
plt.title("CNF D169 LAG original")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %% [markdown]
# ### 3. VGG-19

# %%
#Vgg-19
import time
epochs =50
batch_size = 10

start = time.time()
history_3 = model3.fit(
      train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=epochs, batch_size =batch_size,
      validation_data=validation_generator,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
end = time.time()
print("Execution Time : ", (end - start))
# Out:
# Epoch 1/50
# 342/342 [==============================] - 143s 406ms/step - loss: 0.4994 - accuracy: 0.7769 - val_loss: 0.5139 - val_accuracy: 0.7623
# Epoch 2/50
# 342/342 [==============================] - 183s 534ms/step - loss: 0.4026 - accuracy: 0.8336 - val_loss: 0.3470 - val_accuracy: 0.8693
# Epoch 3/50
# 342/342 [==============================] - 176s 515ms/step - loss: 0.3493 - accuracy: 0.8664 - val_loss: 0.3081 - val_accuracy: 0.8858
# Epoch 4/50
# 342/342 [==============================] - 178s 521ms/step - loss: 0.3227 - accuracy: 0.8754 - val_loss: 0.2921 - val_accuracy: 0.8889
# Epoch 5/50
# 342/342 [==============================] - 172s 502ms/step - loss: 0.2980 - accuracy: 0.8813 - val_loss: 0.2973 - val_accuracy: 0.8786
# Epoch 6/50
# 342/342 [==============================] - 179s 524ms/step - loss: 0.2752 - accuracy: 0.8959 - val_loss: 0.2631 - val_accuracy: 0.8940
# Epoch 7/50
# 342/342 [==============================] - 181s 529ms/step - loss: 0.2654 - accuracy: 0.8988 - val_loss: 0.3146 - val_accuracy: 0.8735
# Epoch 8/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.2426 - accuracy: 0.9096 - val_loss: 0.2479 - val_accuracy: 0.9033
# Epoch 9/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.2308 - accuracy: 0.9178 - val_loss: 0.2515 - val_accuracy: 0.9012
# Epoch 10/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.2204 - accuracy: 0.9187 - val_loss: 0.2446 - val_accuracy: 0.9053
# Epoch 11/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.2104 - accuracy: 0.9205 - val_loss: 0.2329 - val_accuracy: 0.9084
# Epoch 12/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.2086 - accuracy: 0.9266 - val_loss: 0.2359 - val_accuracy: 0.9084
# Epoch 13/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.1876 - accuracy: 0.9357 - val_loss: 0.4059 - val_accuracy: 0.8333
# Epoch 14/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.1815 - accuracy: 0.9363 - val_loss: 0.2256 - val_accuracy: 0.9126
# Epoch 15/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.1736 - accuracy: 0.9421 - val_loss: 0.2414 - val_accuracy: 0.9084
# Epoch 16/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.1832 - accuracy: 0.9339 - val_loss: 0.2176 - val_accuracy: 0.9146
# Epoch 17/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.1486 - accuracy: 0.9485 - val_loss: 0.2143 - val_accuracy: 0.9239
# Epoch 18/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.1542 - accuracy: 0.9459 - val_loss: 0.4053 - val_accuracy: 0.8447
# Epoch 19/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.1672 - accuracy: 0.9392 - val_loss: 0.2083 - val_accuracy: 0.9228
# Epoch 20/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.1380 - accuracy: 0.9573 - val_loss: 0.2116 - val_accuracy: 0.9208
# Epoch 21/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.1361 - accuracy: 0.9532 - val_loss: 0.2053 - val_accuracy: 0.9249
# Epoch 22/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.1357 - accuracy: 0.9529 - val_loss: 0.2189 - val_accuracy: 0.9167
# Epoch 23/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.1390 - accuracy: 0.9500 - val_loss: 0.3483 - val_accuracy: 0.8591
# Epoch 24/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.1279 - accuracy: 0.9596 - val_loss: 0.2068 - val_accuracy: 0.9290
# Epoch 25/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.1264 - accuracy: 0.9556 - val_loss: 0.2205 - val_accuracy: 0.9259
# Epoch 26/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.1190 - accuracy: 0.9626 - val_loss: 0.2022 - val_accuracy: 0.9280
# Epoch 27/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.1097 - accuracy: 0.9661 - val_loss: 0.4399 - val_accuracy: 0.8405
# Epoch 28/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.1146 - accuracy: 0.9637 - val_loss: 0.5793 - val_accuracy: 0.7469
# Epoch 29/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.1080 - accuracy: 0.9684 - val_loss: 0.2873 - val_accuracy: 0.8930
# Epoch 30/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.0992 - accuracy: 0.9640 - val_loss: 0.2352 - val_accuracy: 0.9074
# Epoch 31/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.1052 - accuracy: 0.9664 - val_loss: 0.2780 - val_accuracy: 0.9033
# Epoch 32/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.1000 - accuracy: 0.9699 - val_loss: 0.1953 - val_accuracy: 0.9290
# Epoch 33/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.0822 - accuracy: 0.9757 - val_loss: 0.2017 - val_accuracy: 0.9270
# Epoch 34/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.0884 - accuracy: 0.9728 - val_loss: 0.2087 - val_accuracy: 0.9270
# Epoch 35/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.0893 - accuracy: 0.9687 - val_loss: 0.2741 - val_accuracy: 0.8930
# Epoch 36/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.0793 - accuracy: 0.9775 - val_loss: 0.2442 - val_accuracy: 0.9136
# Epoch 37/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.0820 - accuracy: 0.9743 - val_loss: 0.2227 - val_accuracy: 0.9228
# Epoch 38/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.0739 - accuracy: 0.9778 - val_loss: 0.2241 - val_accuracy: 0.9249
# Epoch 39/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.0788 - accuracy: 0.9757 - val_loss: 0.6203 - val_accuracy: 0.8128
# Epoch 40/50
# 342/342 [==============================] - 174s 510ms/step - loss: 0.0734 - accuracy: 0.9807 - val_loss: 0.3673 - val_accuracy: 0.8796
# Epoch 41/50
# 342/342 [==============================] - 694s 2s/step - loss: 0.0760 - accuracy: 0.9763 - val_loss: 0.4869 - val_accuracy: 0.8374
# Epoch 42/50
# 342/342 [==============================] - 102s 298ms/step - loss: 0.0706 - accuracy: 0.9781 - val_loss: 0.5047 - val_accuracy: 0.8405
# Epoch 43/50
# 342/342 [==============================] - 102s 299ms/step - loss: 0.0644 - accuracy: 0.9813 - val_loss: 0.2038 - val_accuracy: 0.9290
# Epoch 44/50
# 342/342 [==============================] - 102s 299ms/step - loss: 0.0628 - accuracy: 0.9822 - val_loss: 0.2695 - val_accuracy: 0.9105
# Epoch 45/50
# 342/342 [==============================] - 102s 300ms/step - loss: 0.0647 - accuracy: 0.9804 - val_loss: 0.2834 - val_accuracy: 0.9156
# Epoch 46/50
# 342/342 [==============================] - 103s 300ms/step - loss: 0.0594 - accuracy: 0.9842 - val_loss: 0.2016 - val_accuracy: 0.9372
# Epoch 47/50
# 342/342 [==============================] - 102s 300ms/step - loss: 0.0551 - accuracy: 0.9854 - val_loss: 0.2280 - val_accuracy: 0.9228
# Epoch 48/50
# 342/342 [==============================] - 1252s 4s/step - loss: 0.0590 - accuracy: 0.9839 - val_loss: 0.2138 - val_accuracy: 0.9331
# Epoch 49/50
# 342/342 [==============================] - 107s 314ms/step - loss: 0.0504 - accuracy: 0.9848 - val_loss: 0.2530 - val_accuracy: 0.9105
# Epoch 50/50
# 342/342 [==============================] - 102s 299ms/step - loss: 0.0562 - accuracy: 0.9833 - val_loss: 0.5274 - val_accuracy: 0.8467
# Execution Time :  9735.560761928558

# %%
model3.save('SavedModels/LAG original/VGG19Tuned.h5')

# %%
acc = history_3.history['accuracy']
val_acc = history_3.history['val_accuracy']

loss = history_3.history['loss']
val_loss = history_3.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
plt.suptitle('Tuned VGG19 on LAG original', fontsize=14, fontweight='bold')
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
start=time.time()
test_output_3= model3.evaluate(test_generator, steps=test_generator.samples/test_generator.batch_size, verbose=1)
end=time.time()
print(model3.metrics_names)
print(test_output_3)
print("testing time : "+ str(end-start))
# Out:
# 47/47 [==============================] - 8s 167ms/step - loss: 0.3847 - accuracy: 0.8792
# ['loss', 'accuracy']
# [0.3846595585346222, 0.8792372941970825]
# testing time : 7.998158931732178

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


#Y_pred = model1.predict_generator(validation_generator, 171 // batch_size+1)
Y_pred=model3.predict(test_generator,test_generator.samples//batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
conf=confusion_matrix(test_generator.classes, y_pred)
print(conf)
print('Classification Report')
target_names = ['Gluacoma', 'Normal']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# 48/48 [==============================] - 8s 164ms/step
# Confusion Matrix
# [[104  57]
#  [  0 311]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Gluacoma       1.00      0.65      0.78       161
#       Normal       0.85      1.00      0.92       311
#
#     accuracy                           0.88       472
#    macro avg       0.92      0.82      0.85       472
# weighted avg       0.90      0.88      0.87       472

# %%
import itertools
classes = [0, 1]
# plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.BuGn)
plt.title("CNF Tuned VGG19 LAG original")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %% [markdown]
# ### 4. MobileNet V2

# %%
#MobileNet 
import time
epochs =50
batch_size = 10

start = time.time()
history_4 = model4.fit(
      train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=epochs, batch_size =batch_size,
      validation_data=validation_generator,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
end = time.time()
print("Execution Time : ", (end - start))
# Out:
# Epoch 1/50
# 342/342 [==============================] - 44s 114ms/step - loss: 0.5226 - accuracy: 0.7409 - val_loss: 0.4873 - val_accuracy: 0.7798
# Epoch 2/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.3752 - accuracy: 0.8374 - val_loss: 0.4065 - val_accuracy: 0.8395
# Epoch 3/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.3166 - accuracy: 0.8690 - val_loss: 0.3554 - val_accuracy: 0.8457
# Epoch 4/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.2710 - accuracy: 0.8906 - val_loss: 0.3024 - val_accuracy: 0.8776
# Epoch 5/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.2286 - accuracy: 0.9129 - val_loss: 0.2720 - val_accuracy: 0.8796
# Epoch 6/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.1875 - accuracy: 0.9307 - val_loss: 0.2502 - val_accuracy: 0.9023
# Epoch 7/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.1737 - accuracy: 0.9319 - val_loss: 0.2451 - val_accuracy: 0.8971
# Epoch 8/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.1636 - accuracy: 0.9404 - val_loss: 0.2455 - val_accuracy: 0.9053
# Epoch 9/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.1266 - accuracy: 0.9611 - val_loss: 0.2470 - val_accuracy: 0.8981
# Epoch 10/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.1361 - accuracy: 0.9556 - val_loss: 0.2395 - val_accuracy: 0.9064
# Epoch 11/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.1099 - accuracy: 0.9629 - val_loss: 0.2385 - val_accuracy: 0.9115
# Epoch 12/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.1050 - accuracy: 0.9661 - val_loss: 0.2346 - val_accuracy: 0.9115
# Epoch 13/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0992 - accuracy: 0.9661 - val_loss: 0.2333 - val_accuracy: 0.9167
# Epoch 14/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0826 - accuracy: 0.9746 - val_loss: 0.2460 - val_accuracy: 0.9146
# Epoch 15/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0835 - accuracy: 0.9737 - val_loss: 0.2328 - val_accuracy: 0.9167
# Epoch 16/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0666 - accuracy: 0.9833 - val_loss: 0.2426 - val_accuracy: 0.9146
# Epoch 17/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0562 - accuracy: 0.9827 - val_loss: 0.2461 - val_accuracy: 0.9146
# Epoch 18/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0612 - accuracy: 0.9819 - val_loss: 0.2455 - val_accuracy: 0.9208
# Epoch 19/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0567 - accuracy: 0.9845 - val_loss: 0.2483 - val_accuracy: 0.9146
# Epoch 20/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0573 - accuracy: 0.9822 - val_loss: 0.2587 - val_accuracy: 0.9115
# Epoch 21/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.0557 - accuracy: 0.9816 - val_loss: 0.2708 - val_accuracy: 0.9105
# Epoch 22/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0501 - accuracy: 0.9857 - val_loss: 0.2466 - val_accuracy: 0.9156
# Epoch 23/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0468 - accuracy: 0.9877 - val_loss: 0.2494 - val_accuracy: 0.9187
# Epoch 24/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0409 - accuracy: 0.9880 - val_loss: 0.2371 - val_accuracy: 0.9177
# Epoch 25/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0464 - accuracy: 0.9854 - val_loss: 0.2368 - val_accuracy: 0.9249
# Epoch 26/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0397 - accuracy: 0.9883 - val_loss: 0.2504 - val_accuracy: 0.9218
# Epoch 27/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0425 - accuracy: 0.9868 - val_loss: 0.2611 - val_accuracy: 0.9156
# Epoch 28/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.0426 - accuracy: 0.9854 - val_loss: 0.2592 - val_accuracy: 0.9167
# Epoch 29/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0351 - accuracy: 0.9892 - val_loss: 0.2470 - val_accuracy: 0.9228
# Epoch 30/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0363 - accuracy: 0.9871 - val_loss: 0.2488 - val_accuracy: 0.9208
# Epoch 31/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0426 - accuracy: 0.9868 - val_loss: 0.2669 - val_accuracy: 0.9187
# Epoch 32/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.0388 - accuracy: 0.9874 - val_loss: 0.2583 - val_accuracy: 0.9136
# Epoch 33/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.0412 - accuracy: 0.9857 - val_loss: 0.2539 - val_accuracy: 0.9239
# Epoch 34/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.0354 - accuracy: 0.9889 - val_loss: 0.2546 - val_accuracy: 0.9218
# Epoch 35/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.0314 - accuracy: 0.9921 - val_loss: 0.2540 - val_accuracy: 0.9218
# Epoch 36/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.0252 - accuracy: 0.9927 - val_loss: 0.2520 - val_accuracy: 0.9228
# Epoch 37/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.0290 - accuracy: 0.9924 - val_loss: 0.2571 - val_accuracy: 0.9249
# Epoch 38/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.0259 - accuracy: 0.9927 - val_loss: 0.2721 - val_accuracy: 0.9259
# Epoch 39/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.0317 - accuracy: 0.9901 - val_loss: 0.2614 - val_accuracy: 0.9218
# Epoch 40/50
# 342/342 [==============================] - 38s 110ms/step - loss: 0.0294 - accuracy: 0.9915 - val_loss: 0.2419 - val_accuracy: 0.9270
# Epoch 41/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.0293 - accuracy: 0.9901 - val_loss: 0.2542 - val_accuracy: 0.9321
# Epoch 42/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.0278 - accuracy: 0.9904 - val_loss: 0.2472 - val_accuracy: 0.9239
# Epoch 43/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0228 - accuracy: 0.9939 - val_loss: 0.2578 - val_accuracy: 0.9218
# Epoch 44/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0266 - accuracy: 0.9909 - val_loss: 0.2643 - val_accuracy: 0.9218
# Epoch 45/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0253 - accuracy: 0.9909 - val_loss: 0.2577 - val_accuracy: 0.9280
# Epoch 46/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0209 - accuracy: 0.9936 - val_loss: 0.2560 - val_accuracy: 0.9270
# Epoch 47/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0302 - accuracy: 0.9898 - val_loss: 0.2591 - val_accuracy: 0.9270
# Epoch 48/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.0296 - accuracy: 0.9898 - val_loss: 0.2562 - val_accuracy: 0.9259
# Epoch 49/50
# 342/342 [==============================] - 37s 109ms/step - loss: 0.0217 - accuracy: 0.9939 - val_loss: 0.2574 - val_accuracy: 0.9259
# Epoch 50/50
# 342/342 [==============================] - 37s 108ms/step - loss: 0.0237 - accuracy: 0.9915 - val_loss: 0.2478 - val_accuracy: 0.9280
# Execution Time :  1865.3972191810608

# %%
model4.save('SavedModels/LAG original/MobileNetTuned.h5')

# %%
acc = history_4.history['accuracy']
val_acc = history_4.history['val_accuracy']

loss = history_4.history['loss']
val_loss = history_4.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
plt.suptitle('MobileNet on LAG original', fontsize=14, fontweight='bold')
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
start=time.time()
test_output_4= model4.evaluate(test_generator, steps=test_generator.samples/test_generator.batch_size, verbose=1)
end=time.time()
print(model4.metrics_names)
print(test_output_4)
print("testing time : "+ str(end-start))
# Out:
# 47/47 [==============================] - 2s 42ms/step - loss: 0.2418 - accuracy: 0.9153
# ['loss', 'accuracy']
# [0.24179096519947052, 0.9152542352676392]
# testing time : 2.1052916049957275

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


#Y_pred = model1.predict_generator(validation_generator, 171 // batch_size+1)
Y_pred=model4.predict(test_generator,test_generator.samples//batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
conf=confusion_matrix(test_generator.classes, y_pred)
print(conf)
print('Classification Report')
target_names = ['Gluacoma', 'Normal']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# 48/48 [==============================] - 3s 38ms/step
# Confusion Matrix
# [[144  17]
#  [ 23 288]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Gluacoma       0.86      0.89      0.88       161
#       Normal       0.94      0.93      0.94       311
#
#     accuracy                           0.92       472
#    macro avg       0.90      0.91      0.91       472
# weighted avg       0.92      0.92      0.92       472

# %%
classes = [0, 1]
# plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.BuGn)
plt.title("CNF MobileNet LAG original")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %% [markdown]
# ## ResNet50

# %%
#ResNet 50
import time
epochs =50
batch_size = 10

start = time.time()
history_5 = model5.fit(
      train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=epochs, batch_size =batch_size,
      validation_data=validation_generator,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
end = time.time()
print("Execution Time : ", (end - start))
# Out:
# Epoch 1/50
# 342/342 [==============================] - 140s 379ms/step - loss: 0.5619 - accuracy: 0.7056 - val_loss: 0.6501 - val_accuracy: 0.6420
# Epoch 2/50
# 342/342 [==============================] - 95s 278ms/step - loss: 0.4650 - accuracy: 0.7912 - val_loss: 0.4255 - val_accuracy: 0.8508
# Epoch 3/50
# 342/342 [==============================] - 123s 360ms/step - loss: 0.4214 - accuracy: 0.8143 - val_loss: 0.5479 - val_accuracy: 0.7531
# Epoch 4/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.3811 - accuracy: 0.8348 - val_loss: 1.8573 - val_accuracy: 0.6420
# Epoch 5/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.3616 - accuracy: 0.8450 - val_loss: 6.5532 - val_accuracy: 0.3580
# Epoch 6/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.3308 - accuracy: 0.8637 - val_loss: 1.9069 - val_accuracy: 0.6420
# Epoch 7/50
# 342/342 [==============================] - 128s 375ms/step - loss: 0.3250 - accuracy: 0.8591 - val_loss: 0.6016 - val_accuracy: 0.7099
# Epoch 8/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.3105 - accuracy: 0.8661 - val_loss: 1.1624 - val_accuracy: 0.4270
# Epoch 9/50
# 342/342 [==============================] - 128s 375ms/step - loss: 0.2948 - accuracy: 0.8740 - val_loss: 2.3934 - val_accuracy: 0.6420
# Epoch 10/50
# 342/342 [==============================] - 128s 375ms/step - loss: 0.2873 - accuracy: 0.8819 - val_loss: 11.5917 - val_accuracy: 0.3580
# Epoch 11/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.2883 - accuracy: 0.8825 - val_loss: 0.4245 - val_accuracy: 0.8457
# Epoch 12/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.2799 - accuracy: 0.8819 - val_loss: 0.2650 - val_accuracy: 0.8889
# Epoch 13/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.2636 - accuracy: 0.8868 - val_loss: 6.7803 - val_accuracy: 0.3580
# Epoch 14/50
# 342/342 [==============================] - 128s 375ms/step - loss: 0.2484 - accuracy: 0.8953 - val_loss: 0.7110 - val_accuracy: 0.6811
# Epoch 15/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.2470 - accuracy: 0.9026 - val_loss: 12.1227 - val_accuracy: 0.3580
# Epoch 16/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.2425 - accuracy: 0.8980 - val_loss: 3.8495 - val_accuracy: 0.3580
# Epoch 17/50
# 342/342 [==============================] - 128s 375ms/step - loss: 0.2450 - accuracy: 0.9026 - val_loss: 2.9173 - val_accuracy: 0.6420
# Epoch 18/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.2339 - accuracy: 0.9073 - val_loss: 0.4077 - val_accuracy: 0.8354
# Epoch 19/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.2348 - accuracy: 0.9032 - val_loss: 2.7191 - val_accuracy: 0.6420
# Epoch 20/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.2166 - accuracy: 0.9152 - val_loss: 0.4571 - val_accuracy: 0.8302
# Epoch 21/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.2207 - accuracy: 0.9181 - val_loss: 6.9155 - val_accuracy: 0.3580
# Epoch 22/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.2072 - accuracy: 0.9199 - val_loss: 2.8186 - val_accuracy: 0.6420
# Epoch 23/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.2109 - accuracy: 0.9146 - val_loss: 2.8536 - val_accuracy: 0.6420
# Epoch 24/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.2035 - accuracy: 0.9146 - val_loss: 0.3733 - val_accuracy: 0.8148
# Epoch 25/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.2256 - accuracy: 0.9108 - val_loss: 1.3532 - val_accuracy: 0.4640
# Epoch 26/50
# 342/342 [==============================] - 128s 375ms/step - loss: 0.2048 - accuracy: 0.9187 - val_loss: 2.5970 - val_accuracy: 0.3817
# Epoch 27/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.2045 - accuracy: 0.9102 - val_loss: 0.4703 - val_accuracy: 0.7881
# Epoch 28/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.2027 - accuracy: 0.9164 - val_loss: 23.5174 - val_accuracy: 0.3580
# Epoch 29/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.2045 - accuracy: 0.9155 - val_loss: 0.2717 - val_accuracy: 0.8930
# Epoch 30/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.1974 - accuracy: 0.9190 - val_loss: 0.7100 - val_accuracy: 0.7407
# Epoch 31/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.1973 - accuracy: 0.9187 - val_loss: 0.7924 - val_accuracy: 0.7078
# Epoch 32/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.1931 - accuracy: 0.9228 - val_loss: 6.3357 - val_accuracy: 0.3580
# Epoch 33/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.1742 - accuracy: 0.9292 - val_loss: 1.0198 - val_accuracy: 0.6883
# Epoch 34/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.1807 - accuracy: 0.9310 - val_loss: 0.6371 - val_accuracy: 0.7366
# Epoch 35/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.1733 - accuracy: 0.9301 - val_loss: 5.3305 - val_accuracy: 0.6420
# Epoch 36/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.1745 - accuracy: 0.9327 - val_loss: 0.9170 - val_accuracy: 0.6842
# Epoch 37/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.1653 - accuracy: 0.9365 - val_loss: 6.0094 - val_accuracy: 0.3580
# Epoch 38/50
# 342/342 [==============================] - 128s 375ms/step - loss: 0.1822 - accuracy: 0.9216 - val_loss: 1.0481 - val_accuracy: 0.7088
# Epoch 39/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.1638 - accuracy: 0.9345 - val_loss: 4.3339 - val_accuracy: 0.6420
# Epoch 40/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.1641 - accuracy: 0.9363 - val_loss: 5.1954 - val_accuracy: 0.6420
# Epoch 41/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.1849 - accuracy: 0.9275 - val_loss: 0.8565 - val_accuracy: 0.6440
# Epoch 42/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.1680 - accuracy: 0.9304 - val_loss: 4.4341 - val_accuracy: 0.6420
# Epoch 43/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.1649 - accuracy: 0.9348 - val_loss: 0.4764 - val_accuracy: 0.7870
# Epoch 44/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.1566 - accuracy: 0.9380 - val_loss: 6.2765 - val_accuracy: 0.6420
# Epoch 45/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.1588 - accuracy: 0.9401 - val_loss: 1.1813 - val_accuracy: 0.5792
# Epoch 46/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.1730 - accuracy: 0.9287 - val_loss: 4.8710 - val_accuracy: 0.6420
# Epoch 47/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.1535 - accuracy: 0.9389 - val_loss: 3.7605 - val_accuracy: 0.6420
# Epoch 48/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.1393 - accuracy: 0.9444 - val_loss: 20.0695 - val_accuracy: 0.3580
# Epoch 49/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.1628 - accuracy: 0.9325 - val_loss: 12.5579 - val_accuracy: 0.3580
# Epoch 50/50
# 342/342 [==============================] - 128s 374ms/step - loss: 0.1530 - accuracy: 0.9433 - val_loss: 1.0772 - val_accuracy: 0.5988
# Execution Time :  6376.57906627655

# %%
model5.save('SavedModels/LAG original/ResNetTuned.h5')

# %%
acc = history_5.history['accuracy']
val_acc = history_5.history['val_accuracy']

loss = history_5.history['loss']
val_loss = history_5.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
plt.suptitle('Tuned ResNet on LAG original', fontsize=14, fontweight='bold')
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
start=time.time()
test_output_5= model5.evaluate(test_generator, steps=test_generator.samples/test_generator.batch_size, verbose=1)
end=time.time()
print(model5.metrics_names)
print(test_output_5)
print("testing time : "+ str(end-start))
# Out:
# 47/47 [==============================] - 7s 146ms/step - loss: 1.0331 - accuracy: 0.6462
# ['loss', 'accuracy']
# [1.033127784729004, 0.6461864113807678]
# testing time : 7.006923675537109

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


#Y_pred = model1.predict_generator(validation_generator, 171 // batch_size+1)
Y_pred=model5.predict(test_generator,test_generator.samples//batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
conf=confusion_matrix(test_generator.classes, y_pred)
print(conf)
print('Classification Report')
target_names = ['Gluacoma', 'Normal']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# 48/48 [==============================] - 8s 140ms/step
# Confusion Matrix
# [[161   0]
#  [167 144]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Gluacoma       0.49      1.00      0.66       161
#       Normal       1.00      0.46      0.63       311
#
#     accuracy                           0.65       472
#    macro avg       0.75      0.73      0.65       472
# weighted avg       0.83      0.65      0.64       472

# %%
import itertools
classes = [0, 1]
# plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.BuGn)
plt.title("CNF Tuned ResNet LAG original")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %% [markdown]
# ### 6. Inception V3

# %%
#Inception V3
import time
epochs =50
batch_size = 10

start = time.time()
history_6 = model6.fit(
      train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=epochs, batch_size =batch_size,
      validation_data=validation_generator,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
end = time.time()
print("Execution Time : ", (end - start))
# Out:
# Epoch 1/50
# 342/342 [==============================] - 119s 324ms/step - loss: 0.5674 - accuracy: 0.7114 - val_loss: 0.5049 - val_accuracy: 0.7469
# Epoch 2/50
# 342/342 [==============================] - 114s 332ms/step - loss: 0.4333 - accuracy: 0.8076 - val_loss: 0.4622 - val_accuracy: 0.7788
# Epoch 3/50
# 342/342 [==============================] - 115s 337ms/step - loss: 0.3521 - accuracy: 0.8474 - val_loss: 0.4162 - val_accuracy: 0.8128
# Epoch 4/50
# 342/342 [==============================] - 112s 328ms/step - loss: 0.2773 - accuracy: 0.8904 - val_loss: 0.4037 - val_accuracy: 0.8241
# Epoch 5/50
# 342/342 [==============================] - 112s 328ms/step - loss: 0.2368 - accuracy: 0.9050 - val_loss: 0.3878 - val_accuracy: 0.8364
# Epoch 6/50
# 342/342 [==============================] - 114s 333ms/step - loss: 0.1940 - accuracy: 0.9275 - val_loss: 0.3688 - val_accuracy: 0.8539
# Epoch 7/50
# 342/342 [==============================] - 114s 332ms/step - loss: 0.1764 - accuracy: 0.9342 - val_loss: 0.3984 - val_accuracy: 0.8570
# Epoch 8/50
# 342/342 [==============================] - 116s 338ms/step - loss: 0.1470 - accuracy: 0.9453 - val_loss: 0.3691 - val_accuracy: 0.8663
# Epoch 9/50
# 342/342 [==============================] - 115s 338ms/step - loss: 0.1403 - accuracy: 0.9480 - val_loss: 0.4088 - val_accuracy: 0.8570
# Epoch 10/50
# 342/342 [==============================] - 114s 334ms/step - loss: 0.1189 - accuracy: 0.9591 - val_loss: 0.3942 - val_accuracy: 0.8632
# Epoch 11/50
# 342/342 [==============================] - 113s 329ms/step - loss: 0.0974 - accuracy: 0.9667 - val_loss: 0.3808 - val_accuracy: 0.8724
# Epoch 12/50
# 342/342 [==============================] - 104s 305ms/step - loss: 0.0920 - accuracy: 0.9702 - val_loss: 0.3728 - val_accuracy: 0.8786
# Epoch 13/50
# 342/342 [==============================] - 99s 290ms/step - loss: 0.0857 - accuracy: 0.9684 - val_loss: 0.3567 - val_accuracy: 0.8807
# Epoch 14/50
# 342/342 [==============================] - 99s 290ms/step - loss: 0.0777 - accuracy: 0.9728 - val_loss: 0.3883 - val_accuracy: 0.8704
# Epoch 15/50
# 342/342 [==============================] - 99s 290ms/step - loss: 0.0703 - accuracy: 0.9766 - val_loss: 0.4264 - val_accuracy: 0.8755
# Epoch 16/50
# 342/342 [==============================] - 99s 289ms/step - loss: 0.0876 - accuracy: 0.9664 - val_loss: 0.3901 - val_accuracy: 0.8827
# Epoch 17/50
# 342/342 [==============================] - 99s 289ms/step - loss: 0.0756 - accuracy: 0.9722 - val_loss: 0.3545 - val_accuracy: 0.8848
# Epoch 18/50
# 342/342 [==============================] - 99s 289ms/step - loss: 0.0598 - accuracy: 0.9795 - val_loss: 0.3607 - val_accuracy: 0.8889
# Epoch 19/50
# 342/342 [==============================] - 99s 290ms/step - loss: 0.0665 - accuracy: 0.9789 - val_loss: 0.3396 - val_accuracy: 0.8951
# Epoch 20/50
# 342/342 [==============================] - 99s 289ms/step - loss: 0.0542 - accuracy: 0.9804 - val_loss: 0.3410 - val_accuracy: 0.8930
# Epoch 21/50
# 342/342 [==============================] - 99s 290ms/step - loss: 0.0608 - accuracy: 0.9784 - val_loss: 0.3552 - val_accuracy: 0.8951
# Epoch 22/50
# 342/342 [==============================] - 99s 289ms/step - loss: 0.0424 - accuracy: 0.9880 - val_loss: 0.3592 - val_accuracy: 0.8899
# Epoch 23/50
# 342/342 [==============================] - 99s 289ms/step - loss: 0.0501 - accuracy: 0.9863 - val_loss: 0.3854 - val_accuracy: 0.8940
# Epoch 24/50
# 342/342 [==============================] - 99s 289ms/step - loss: 0.0420 - accuracy: 0.9845 - val_loss: 0.3912 - val_accuracy: 0.8971
# Epoch 25/50
# 342/342 [==============================] - 99s 290ms/step - loss: 0.0408 - accuracy: 0.9877 - val_loss: 0.3743 - val_accuracy: 0.8992
# Epoch 26/50
# 342/342 [==============================] - 99s 290ms/step - loss: 0.0551 - accuracy: 0.9816 - val_loss: 0.3871 - val_accuracy: 0.8930
# Epoch 27/50
# 342/342 [==============================] - 102s 297ms/step - loss: 0.0442 - accuracy: 0.9845 - val_loss: 0.3682 - val_accuracy: 0.8971
# Epoch 28/50
# 342/342 [==============================] - 112s 327ms/step - loss: 0.0468 - accuracy: 0.9836 - val_loss: 0.3904 - val_accuracy: 0.8992
# Epoch 29/50
# 342/342 [==============================] - 112s 327ms/step - loss: 0.0431 - accuracy: 0.9854 - val_loss: 0.3652 - val_accuracy: 0.8940
# Epoch 30/50
# 342/342 [==============================] - 111s 325ms/step - loss: 0.0396 - accuracy: 0.9880 - val_loss: 0.3836 - val_accuracy: 0.8951
# Epoch 31/50
# 342/342 [==============================] - 111s 325ms/step - loss: 0.0287 - accuracy: 0.9909 - val_loss: 0.3984 - val_accuracy: 0.8920
# Epoch 32/50
# 342/342 [==============================] - 111s 326ms/step - loss: 0.0383 - accuracy: 0.9860 - val_loss: 0.3612 - val_accuracy: 0.8992
# Epoch 33/50
# 342/342 [==============================] - 321s 940ms/step - loss: 0.0319 - accuracy: 0.9901 - val_loss: 0.3709 - val_accuracy: 0.8951
# Epoch 34/50
# 342/342 [==============================] - 60s 175ms/step - loss: 0.0346 - accuracy: 0.9883 - val_loss: 0.3555 - val_accuracy: 0.9023
# Epoch 35/50
# 342/342 [==============================] - 60s 176ms/step - loss: 0.0335 - accuracy: 0.9892 - val_loss: 0.3554 - val_accuracy: 0.9053
# Epoch 36/50
# 342/342 [==============================] - 60s 175ms/step - loss: 0.0403 - accuracy: 0.9845 - val_loss: 0.3545 - val_accuracy: 0.9074
# Epoch 37/50
# 342/342 [==============================] - 60s 175ms/step - loss: 0.0374 - accuracy: 0.9868 - val_loss: 0.3419 - val_accuracy: 0.9084
# Epoch 38/50
# 342/342 [==============================] - 97s 284ms/step - loss: 0.0283 - accuracy: 0.9921 - val_loss: 0.3688 - val_accuracy: 0.9012
# Epoch 39/50
# 342/342 [==============================] - 99s 289ms/step - loss: 0.0369 - accuracy: 0.9889 - val_loss: 0.3628 - val_accuracy: 0.9043
# Epoch 40/50
# 342/342 [==============================] - 100s 292ms/step - loss: 0.0365 - accuracy: 0.9883 - val_loss: 0.3576 - val_accuracy: 0.9126
# Epoch 41/50
# 342/342 [==============================] - 101s 294ms/step - loss: 0.0301 - accuracy: 0.9892 - val_loss: 0.3365 - val_accuracy: 0.9115
# Epoch 42/50
# 342/342 [==============================] - 98s 288ms/step - loss: 0.0452 - accuracy: 0.9842 - val_loss: 0.3398 - val_accuracy: 0.9115
# Epoch 43/50
# 342/342 [==============================] - 99s 288ms/step - loss: 0.0260 - accuracy: 0.9924 - val_loss: 0.3557 - val_accuracy: 0.9136
# Epoch 44/50
# 342/342 [==============================] - 99s 288ms/step - loss: 0.0260 - accuracy: 0.9924 - val_loss: 0.3671 - val_accuracy: 0.9146
# Epoch 45/50
# 342/342 [==============================] - 99s 288ms/step - loss: 0.0221 - accuracy: 0.9930 - val_loss: 0.3635 - val_accuracy: 0.9177
# Epoch 46/50
# 342/342 [==============================] - 99s 288ms/step - loss: 0.0360 - accuracy: 0.9877 - val_loss: 0.3713 - val_accuracy: 0.9105
# Epoch 47/50
# 342/342 [==============================] - 99s 288ms/step - loss: 0.0226 - accuracy: 0.9918 - val_loss: 0.3507 - val_accuracy: 0.9156
# Epoch 48/50
# 342/342 [==============================] - 99s 288ms/step - loss: 0.0270 - accuracy: 0.9909 - val_loss: 0.3592 - val_accuracy: 0.9167
# Epoch 49/50
# 342/342 [==============================] - 99s 288ms/step - loss: 0.0286 - accuracy: 0.9906 - val_loss: 0.3545 - val_accuracy: 0.9146
# Epoch 50/50
# 342/342 [==============================] - 99s 288ms/step - loss: 0.0244 - accuracy: 0.9924 - val_loss: 0.3681 - val_accuracy: 0.9095
# Execution Time :  5252.918821573257

# %%
model6.save('SavedModels/LAG original/Inception Tuned.h5')

# %%
acc = history_6.history['accuracy']
val_acc = history_6.history['val_accuracy']

loss = history_6.history['loss']
val_loss = history_6.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
plt.suptitle("Tuned Inception V3 on LAG original", fontsize=14, fontweight='bold')
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
start=time.time()
test_output_6= model6.evaluate(test_generator, steps=test_generator.samples/test_generator.batch_size, verbose=1)
end=time.time()
print(model6.metrics_names)
print(test_output_6)
print("testing time : "+ str(end-start))
# Out:
# 47/47 [==============================] - 5s 102ms/step - loss: 0.2610 - accuracy: 0.9174
# ['loss', 'accuracy']
# [0.2610147297382355, 0.9173728823661804]
# testing time : 4.956293106079102

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix


#Y_pred = model1.predict_generator(validation_generator, 171 // batch_size+1)
Y_pred=model6.predict(test_generator,test_generator.samples//batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
conf=confusion_matrix(test_generator.classes, y_pred)
print(conf)
print('Classification Report')
target_names = ['Gluacoma', 'Normal']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# 48/48 [==============================] - 6s 96ms/step
# Confusion Matrix
# [[148  13]
#  [ 26 285]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Gluacoma       0.85      0.92      0.88       161
#       Normal       0.96      0.92      0.94       311
#
#     accuracy                           0.92       472
#    macro avg       0.90      0.92      0.91       472
# weighted avg       0.92      0.92      0.92       472

# %%
classes = [0, 1]
# plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.BuGn)
plt.title("CNF Tuned Inception V3 on LAG original")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')
